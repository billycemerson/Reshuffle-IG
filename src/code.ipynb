# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Data

# %%
# read data
data = pd.read_csv('../data/comments_data.csv')

# ignore columns parent_id
data = data.drop(columns=['parent_id'])
data.head()
# Out:
#                                        link         comment_id  \
# 0  https://www.instagram.com/p/DOV0Rn2DNf-/  17916292923173899
# 1  https://www.instagram.com/p/DOV0Rn2DNf-/  18095910739726736
# 2  https://www.instagram.com/p/DOV0Rn2DNf-/  17980524434883939
# 3  https://www.instagram.com/p/DOV0Rn2DNf-/  18173137474359052
# 4  https://www.instagram.com/p/DOV0Rn2DNf-/  18038689634666892
#
#          username                                               text  \
# 0     lorenzoabim                   Anjir Dahnil kebagian kue nya :)
# 1          fndnrz  @risqi_aguspianto hahaha bukan pendukung prabo...
# 2   muchlizdarma1                @lorenzoabim kerjanya setaun sekali
# 3  ikbarsinaga999                  @al_hazhouse.land Kaesang hahahha
# 4    rahmadsejati  harapan rakyat sederhana 🙏 kerja nyata, hasil ...
#
#    created_at  like_count  reply_count
# 0  1757333808         192           16
# 1  1757372912           0            0
# 2  1757387323           0            0
# 3  1757676329           0            0
# 4  1757334122         757            2

# %%
# convert comment_time to datetime
data['created_at'] = pd.to_datetime(data['created_at'], unit='s')

# extract date from comment_time
data['date'] = data['created_at'].dt.date
data.head()
# Out:
#                                        link         comment_id  \
# 0  https://www.instagram.com/p/DOV0Rn2DNf-/  17916292923173899
# 1  https://www.instagram.com/p/DOV0Rn2DNf-/  18095910739726736
# 2  https://www.instagram.com/p/DOV0Rn2DNf-/  17980524434883939
# 3  https://www.instagram.com/p/DOV0Rn2DNf-/  18173137474359052
# 4  https://www.instagram.com/p/DOV0Rn2DNf-/  18038689634666892
#
#          username                                               text  \
# 0     lorenzoabim                   Anjir Dahnil kebagian kue nya :)
# 1          fndnrz  @risqi_aguspianto hahaha bukan pendukung prabo...
# 2   muchlizdarma1                @lorenzoabim kerjanya setaun sekali
# 3  ikbarsinaga999                  @al_hazhouse.land Kaesang hahahha
# 4    rahmadsejati  harapan rakyat sederhana 🙏 kerja nyata, hasil ...
#
#            created_at  like_count  reply_count        date
# 0 2025-09-08 12:16:48         192           16  2025-09-08
# 1 2025-09-08 23:08:32           0            0  2025-09-08
# 2 2025-09-09 03:08:43           0            0  2025-09-09
# 3 2025-09-12 11:25:29           0            0  2025-09-12
# 4 2025-09-08 12:22:02         757            2  2025-09-08

# %% [markdown]
# #### Mention Interaction

# %%
import re
# Get username in text
mention_pattern = re.compile(r'@(\w+)')

# %%
# calculate edge weights from mentions (author -> mentioned)
edge_weights = {}

for _, row in data.iterrows():
    author = row['username']
    text = str(row['text']) if pd.notna(row['text']) else ""
    mentions = mention_pattern.findall(text)

    for mentioned in mentions:
        if author != mentioned:  # Avoid self-loops
            edge_weights[(author, mentioned)] = edge_weights.get((author, mentioned), 0) + 1

# %%
# sort edge weights by value descending
edge_weights = dict(sorted(edge_weights.items(), key=lambda item: item[1], reverse=True))
edge_weights
# Out:
# {('rdt_prm', 'm'): 3,
#  ('brooklyn_cheesee', 'fzi'): 3,
#  ('denisarimbi06', 'prabowo'): 2,
#  ('enia130901', 'plutonioneon'): 2,
#  ('ranggaprimadasa', 'dinatauhida'): 2,
#  ('prasetyo_emilarie', 'bahlillahadalia'): 2,
#  ('prasetyo_emilarie', 'zul'): 2,
#  ('prasetyo_emilarie', 'listyosigitprabowo'): 2,
#  ('prasetyo_emilarie', 'erickthohir'): 2,
#  ('rafly.wibowo240101', 'prabowo'): 2,
#  ('ashurin.1010', 'prabowo'): 2,
#  ('pandu_ozil11', 'hadicobruts'): 2,
#  ('rhama.bpn.sgta', 'sumargodenny'): 2,
#  ('chllprk', 'salmainstbrz'): 2,
#  ('faaaaadiiil', 'heriant_international'): 2,
#  ('taniasoktaviani', '_nsrimulyani11'): 2,
#  ('_nsrimulyani11', 'taniasoktaviani'): 2,
#  ('marjuniaaa', 'anp_studio13'): 2,
#  ('ukmindo.id', 'prabowo'): 2,
#  ('tomsuryapanji', 'prabowo'): 2,
#  ('egiiiinn', 'sekretariat'): 2,
#  ('mrs_susinisharin', 'xreal_2202'): 2,
#  ('downhill_jaksquad', 'maria_quyya'): 2,
#  ('rudi.gaol', 'smindrawati'): 2,
#  ('fndnrz', 'risqi_aguspianto'): 1,
#  ('muchlizdarma1', 'lorenzoabim'): 1,
#  ('ikbarsinaga999', 'al_hazhouse'): 1,
#  ('meilanidoodling', 'rahmadsejati'): 1,
#  ('andianq', 'rahmadsejati'): 1,
#  ('alimunirss', 'thoniluthfi'): 1,
#  ('dudiramdani', 'reisaldo'): 1,
#  ('lenirahardja', 'ayurachanda'): 1,
#  ('nky.338', 'mika'): 1,
#  ('agnes_antam_minigold', 'auliaarezki'): 1,
#  ('aabunyamin', 'apna_permana97'): 1,
#  ('alimasykur__', 'roynais'): 1,
#  ('rakyadjelata', 'mhmdosmm'): 1,
#  ('nasrunart77', 'plutonioneon'): 1,
#  ('brez84', 'pu666uh'): 1,
#  ('lenirahardja', 'bungalawang22'): 1,
#  ('sarden.ina', 'ardii_lukman'): 1,
#  ('vandra_imanda', 'ardii_lukman'): 1,
#  ('io9713', 'ardii_lukman'): 1,
#  ('i.m.reys', 'polparty123'): 1,
#  ('aryaaa.gn', 'bang'): 1,
#  ('ikbarsinaga999', 'bang'): 1,
#  ('borusitoruspanenauli', 'bang'): 1,
#  ('wongtani_padi', 'rahayuindah_'): 1,
#  ('rahayuindah_', 'wongtani_padi'): 1,
#  ('eyesmaul', 'diah'): 1,
#  ('eyesmaul', 'gibran_rakabuming'): 1,
#  ('i.m.reys', 'diah'): 1,
#  ('diah.ummu.s', 'i'): 1,
#  ('lenirahardja', 'prabowo'): 1,
#  ('lenirahardja', 'fraksipartaigerindra'): 1,
#  ('berkegiatan', 'wirassan'): 1,
#  ('wirassan', 'berkegiatan'): 1,
#  ('syah_ram', 'prabowo'): 1,
#  ('syakurhilmy_', 'tempodotco'): 1,
#  ('muhammadkholili30', 'syakurhilmy_'): 1,
#  ('rngyudho', 'syakurhilmy_'): 1,
#  ('io9713', 'syakurhilmy_'): 1,
#  ('tsyahrulramadhan_', 'dahnil_anzar_simanjuntak'): 1,
#  ('ilzamuddin_', 'uktazzy'): 1,
#  ('ardnsyah.yusuf', 'anagirl20101993'): 1,
#  ('sarden.ina', 'ardnsyah'): 1,
#  ('neversaydie28_', 'listyosigitprabowo'): 1,
#  ('kidaisme', 'bchtakos'): 1,
#  ('susantoagus0310', 'bchtakos'): 1,
#  ('novacm', 'bchtakos'): 1,
#  ('syahrilim', 'tempodotco'): 1,
#  ('helinpurba', 'smindrawati'): 1,
#  ('daniwirdani', 'dahnil_anzar_simanjuntak'): 1,
#  ('charcoal1470', 'irwandiferry'): 1,
#  ('yantokuzo', 'tempodotco'): 1,
#  ('mrsamang', 'prabowo'): 1,
#  ('kanzen212', 'mohmahfudmd'): 1,
#  ('fauzanihanifanshori_', 'kementeriankegelapan'): 1,
#  ('patox_concept', 'smindrawati'): 1,
#  ('damarkurrnia', 'prabowo'): 1,
#  ('ineekkkaddsad', 'prabowo'): 1,
#  ('sellyaskyah', 'prabowo'): 1,
#  ('rika_julianti21', 'kemenpar'): 1,
#  ('sagitaaenyy66', 'prabowo'): 1,
#  ('fabillaanna', 'prabowo'): 1,
#  ('kanaraarsy', 'prabowo'): 1,
#  ('daffi.azhari', 'kemenpar'): 1,
#  ('daffi.azhari', 'prabowo'): 1,
#  ('maryanama33', 'prabowo'): 1,
#  ('anasyagit', 'prabowo'): 1,
#  ('rida.hera', 'prabowo'): 1,
#  ('reyfanaml', 'prabowo'): 1,
#  ('asnia_nanta', 'kemenpar'): 1,
#  ('asnia_nanta', 'prabowo'): 1,
#  ('zeolarg', 'prabowo'): 1,
#  ('marcusandnn', 'prabowo'): 1,
#  ('anti.karisna', 'kemenpar'): 1,
#  ('anti.karisna', 'prabowo'): 1,
#  ('wirataahhyad', 'prabowo'): 1,
#  ('ziarinala', 'prabowo'): 1,
#  ('maya_kolinda', 'prabowo'): 1,
#  ('selviadindda', 'prabowo'): 1,
#  ('fatiranaya', 'prabowo'): 1,
#  ('sassylana8', 'prabowo'): 1,
#  ('fellinasha', 'prabowo'): 1,
#  ('dianretno65', 'prabowo'): 1,
#  ('meldasindya', 'prabowo'): 1,
#  ('ervinadifitri', 'kemenpar'): 1,
#  ('ervinadifitri', 'prabowo'): 1,
#  ('ditaalmira89', 'prabowo'): 1,
#  ('geanita.amina23', 'prabowo'): 1,
#  ('ernasetyani747', 'prabowo'): 1,
#  ('revianasta7', 'kemenpar'): 1,
#  ('revianasta7', 'prabowo'): 1,
#  ('enisariee', 'prabowo'): 1,
#  ('himawari_hana7', 'kemenpar'): 1,
#  ('himawari_hana7', 'prabowo'): 1,
#  ('lisa.amina122023', 'prabowo'): 1,
#  ('srika.yatun', 'prabowo'): 1,
#  ('dirameirina', 'prabowo'): 1,
#  ('liviaviana2104', 'prabowo'): 1,
#  ('dindasafira138', 'prabowo'): 1,
#  ('dindasafira138', 'kemenpar'): 1,
#  ('zackarckerman', 'prabowo'): 1,
#  ('zackarckerman', 'kemenpar'): 1,
#  ('miyaaaloiiia', 'prabowo'): 1,
#  ('miyaaaloiiia', 'kemenpar'): 1,
#  ('ikonarendra', 'prabowo'): 1,
#  ('ikonarendra', 'kemenpar'): 1,
#  ('laurabbgaadd', 'prabowo'): 1,
#  ('laurabbgaadd', 'kemenpar'): 1,
#  ('faiza_azah', 'prabowo'): 1,
#  ('faiza_azah', 'kemenpar'): 1,
#  ('kun_toarya', 'prabowo'): 1,
#  ('kun_toarya', 'kemenpar'): 1,
#  ('meisiashh', 'prabowo'): 1,
#  ('meisiashh', 'kemenpar'): 1,
#  ('mawaariiuadd', 'prabowo'): 1,
#  ('mawaariiuadd', 'kemenpar'): 1,
#  ('mitadewanti5', 'prabowo'): 1,
#  ('mitadewanti5', 'kemenpar'): 1,
#  ('senoa_jj', 'prabowo'): 1,
#  ('senoa_jj', 'kemenpar'): 1,
#  ('puttinurma', 'prabowo'): 1,
#  ('puttinurma', 'kemenpar'): 1,
#  ('kinan.ataya', 'prabowo'): 1,
#  ('kinan.ataya', 'kemenpar'): 1,
#  ('antorubiyanto396', 'prabowo'): 1,
#  ('antorubiyanto396', 'kemenpar'): 1,
#  ('ketua_psms', 'prabowo'): 1,
#  ('ketua_psms', 'bocoraluspolitik'): 1,
#  ('ketua_psms', 'presiden_netizen_official1'): 1,
#  ('ketua_psms', 'presidenrepublikindonesia'): 1,
#  ('subhanfathah', 'donal_anjar_simanjuntak_'): 1,
#  ('yuanitagayatri', 'halo_polisi'): 1,
#  ('yuanitagayatri', 'official'): 1,
#  ('yuanitagayatri', 'listyosigitprabowo'): 1,
#  ('yuanitagayatri', 'mohmahfudmd'): 1,
#  ('yuanitagayatri', 'prabowo'): 1,
#  ('hijiraaa.w', 'prabowo'): 1,
#  ('junaeloo3', 'jonijn_'): 1,
#  ('tika_ry', 'jonijn_'): 1,
#  ('indragnwn330', 'lampubumi'): 1,
#  ('fwulan_10', 'sekarlangittttt'): 1,
#  ('dwanharun', 'dedyirawan1989'): 1,
#  ('amiril_mu', 'dwanharun'): 1,
#  ('wahyu_rajin_menabung_', 'padli'): 1,
#  ('goelabakingstudio', 'padli'): 1,
#  ('jonijn_', 'padli'): 1,
#  ('baiq._wati', 'bagastia_hekas'): 1,
#  ('yahginiamat', 'bagastia_hekas'): 1,
#  ('deddy.gondrong.3910', 'bagastia_hekas'): 1,
#  ('erik_tiono_0293', 'gowther06'): 1,
#  ('retoucherjakarta', 'ranisrina'): 1,
#  ('faila_kurnia', 'reshajr'): 1,
#  ('faila_kurnia', 'narasinewsroom'): 1,
#  ('baiq._wati', 'wahyu_rajin_menabung_'): 1,
#  ('wahyu_rajin_menabung_', 'baiq'): 1,
#  ('dwanharun', 'alkmardz'): 1,
#  ('lalalaamma', 'alkmardz'): 1,
#  ('acikaldi._', 'heri_sukatmii'): 1,
#  ('deddy.gondrong.3910', 'heri_sukatmii'): 1,
#  ('handcraft_bundiy', 'aadamchesar'): 1,
#  ('aadamchesar', 'handcraft_bundiy'): 1,
#  ('tikodes', 'smindrawati'): 1,
#  ('xy_lsn08', 'smindrawati'): 1,
#  ('dans_siltorxviii', 'narasinewsroom'): 1,
#  ('tamy.apreall', 'prabowo'): 1,
#  ('tamy.apreall', 'gerindra'): 1,
#  ('toko_alhidayah', 'mardiguwp'): 1,
#  ('ir_wily', 'narasinewsroom'): 1,
#  ('meirinashlic', 'prabowo'): 1,
#  ('meirinashlic', 'listyosigitprabowo'): 1,
#  ('nadhisalsaa', 'yantizieyah'): 1,
#  ('nadhisalsaa', 'dr'): 1,
#  ('fuji_pratiwiaff', 'nadhisalsaa'): 1,
#  ('sivaristantiya', 'roidwansudrajat_'): 1,
#  ('dewan_perwakilan_netizen_ri', 'prabowo'): 1,
#  ('dewan_perwakilan_netizen_ri', 'presidenrepublikindonesia'): 1,
#  ('dewan_perwakilan_netizen_ri', 'gibran_rakabuming'): 1,
#  ('dewan_perwakilan_netizen_ri', 'sekretariat'): 1,
#  ('bungfahmiali', 'kemenpora'): 1,
#  ('bungfahmiali', 'prabowo'): 1,
#  ('bungfahmiali', 'sekretariat'): 1,
#  ('bungfahmiali', 'tedsky89'): 1,
#  ('bungfahmiali', 'sufmi_dasco'): 1,
#  ('matakupingcomm', 'karunasankara01'): 1,
#  ('sutarno_car_linggau_bisa_84', 'karunasankara01'): 1,
#  ('fazri_ponosutan31', 'karunasankara01'): 1,
#  ('deryan_arya', 'marindasari'): 1,
#  ('shokhiaufal', 'marindasari'): 1,
#  ('donal79', 'tgk_ricky'): 1,
#  ('diyaresta', 'hammmmmmmag09'): 1,
#  ('thebadboyblues', 'donal79'): 1,
#  ('ysfibra', 'heldums'): 1,
#  ('susi_1778', 'heldums'): 1,
#  ('sonnydharmawan1707', 'heldums'): 1,
#  ('sonnydharmawan1707', 'randyputrapratama03'): 1,
#  ('lia_acut', 'praharja'): 1,
#  ('praharja.bangga', 'lia_acut'): 1,
#  ('hayati.ilma', 'tyfanew_21'): 1,
#  ('drop_shiiitttttt', 'habiburrahman1819'): 1,
#  ('mutiarardew', 'ariebecks23'): 1,
#  ('alimahmudi_10', 'nvioletas'): 1,
#  ('nabill_rayyan', 'ariebecks23'): 1,
#  ('aryandra_sagara', 'fadciks'): 1,
#  ('mustangid.mustangid', 'randuuuuuuuu'): 1,
#  ('yogirarala', 'wantose_'): 1,
#  ('lilysuzernita', 'wantose_'): 1,
#  ('meryoktaavia', 'citra_anindita_arum'): 1,
#  ('yan.4303', 'soniadrewbelle'): 1,
#  ('soniadrewbelle', 'yan'): 1,
#  ('deviedwar10', 'imrongiant20'): 1,
#  ('donal79', 'imrongiant20'): 1,
#  ('yaya_twa', 'imrongiant20'): 1,
#  ('muhammadkahfi___', 'fhmilham'): 1,
#  ('muhammadkahfi___', 'official'): 1,
#  ('muhammadkahfi___', 'budiaresetiadi'): 1,
#  ('1.917s', 'fhmilham'): 1,
#  ('fhmilham', '1'): 1,
#  ('husnahardiana', 'franzoro26'): 1,
#  ('jamalmecca', 'husnahardiana'): 1,
#  ('franzoro26', 'husnahardiana'): 1,
#  ('mustangid.mustangid', 'megadirga'): 1,
#  ('bennydsp', 'ketua_dprri'): 1,
#  ('bennydsp', 'puanmaharaniri'): 1,
#  ('mustangid.mustangid', 'sofyan__wijaya'): 1,
#  ('gritiesseven', 'herii_kurniawan'): 1,
#  ('mustangid.mustangid', 'elanofiqri'): 1,
#  ('hatta_elmakoalloe', 'smindrawati'): 1,
#  ('ascornion', 'muhammadridwan20112014'): 1,
#  ('jessy_humirtap', 'smindrawati'): 1,
#  ('zee.azizahhh', 'jessy_humirtap'): 1,
#  ('jessy_humirtap', 'zee'): 1,
#  ('c.rob.ad.wi', 'jessy_humirtap'): 1,
#  ('hengkiheng98', 'smindrawati'): 1,
#  ('hengkiheng98', 'zulhammuchtar'): 1,
#  ('zulhammuchtar', 'hengkiheng98'): 1,
#  ('aienditfc', 'smindrawati'): 1,
#  ('rubennebur05', 'naominapitpulu'): 1,
#  ('arthursien', 'rubennebur05'): 1,
#  ('jibriaratna', 'aienditfc'): 1,
#  ('jibriaratna', 'smindrawati'): 1,
#  ('dinatauhida', 'ranggaprimadasa'): 1,
#  ('priska_simanungkalit', 'smindrawati'): 1,
#  ('inimaszen', 'smindrawati'): 1,
#  ('yttagusfirmansyah', 'bahlillahadalia'): 1,
#  ('yttagusfirmansyah', 'natalius_pigai'): 1,
#  ('yttagusfirmansyah', 'prabowo'): 1,
#  ('aammansor', 'smindrawati'): 1,
#  ('vetynathasandra', 'smindrawati'): 1,
#  ('bintorosetya', 'prabowo'): 1,
#  ('bintorosetya', 'basukibtp'): 1,
#  ('syarifudinhidayat91', 'aimanwitjaksono'): 1,
#  ('lafathna', 'smindrawati'): 1,
#  ('nnazizah_15', 'idakristagram'): 1,
#  ('tsunderearmy', 'idakristagram'): 1,
#  ('rizalbojesz', 'idakristagram'): 1,
#  ('slatjenny', 'smindrawati'): 1,
#  ('andriawanarif24', 'slatjenny'): 1,
#  ('marioaian', 'rajaantoni'): 1,
#  ('marioaian', 'prabowo'): 1,
#  ('andriawanarif24', 'marioaian'): 1,
#  ('syams1991', 'smindrawati'): 1,
#  ('awahyudiiii', 'smindrawati'): 1,
#  ('firdaus_93__', 'awahyudiiii'): 1,
#  ('wie.46', 'prabowo'): 1,
#  ('wie.46', 'presidenrepublikindonesia'): 1,
#  ('roywicaksono', 'prabowo'): 1,
#  ('roywicaksono', 'mohmahfudmd'): 1,
#  ('berkahmandiri99', 'roywicaksono'): 1,
#  ('rizkipadilahhh', 'faizbacangocid'): 1,
#  ('denelwans8', 'smindrawati'): 1,
#  ('keboo.o_o', 'listyosigitprabowo'): 1,
#  ('ffiela', 'smindrawati'): 1,
#  ('xslendro', 'prabowo'): 1,
#  ('guns_1422', 'smindrawati'): 1,
#  ('rinnyuntu', 'smindrawati'): 1,
#  ('andiniclaudita', 'rajaantoni'): 1,
#  ('mhdnazmii._', 'smindrawati'): 1,
#  ('calll_me_nda', 'smindrawati'): 1,
#  ('nekoyaabigfam___', 'smindrawati'): 1,
#  ('ranipfahmi', 'smindrawati'): 1,
#  ('fuji.lestariiii', 'smindrawati'): 1,
#  ('johansihotang', 'smindrawati'): 1,
#  ('rainaldi', 'official'): 1,
#  ('sidiqrmd', 'bgsadikin'): 1,
#  ('alfarez_n', 'prabowo'): 1,
#  ('man_vidaview_apartments', 'prabowo'): 1,
#  ('man_vidaview_apartments', 'gerindra'): 1,
#  ('ledyanisipahutarlppim', 'smindrawati'): 1,
#  ('v.apriela', 'tin'): 1,
#  ('tin.mbele', 'v'): 1,
#  ('ascornion', 'yy_____hdn'): 1,
#  ('fitriana_vie', 'smindrawati'): 1,
#  ('abaadnantea', 'prabowo'): 1,
#  ('imam_al_safii', 'smindrawati'): 1,
#  ('triaspyrenia_iyaz', 'smindrawati'): 1,
#  ('mat.man89', 'smindrawati'): 1,
#  ('tryanggara23', 'smindrawati'): 1,
#  ('alaina_dandelion', 'prabowo'): 1,
#  ('jessica__floren', 'prabowogibran'): 1,
#  ('jessica__floren', 'prabowo'): 1,
#  ('jessica__floren', 'mohmahfudmd'): 1,
#  ('_aboed_', 'smindrawati'): 1,
#  ('cutrisanurzinahfonna', 'smindrawati'): 1,
#  ('akang_cutter', 'rocky'): 1,
#  ('ricko.firnandes', 'asepwahyudiatmasubrata'): 1,
#  ('aldo_adv', 'pangi_syarwi'): 1,
#  ('aldo_adv', 'irwandiferry'): 1,
#  ('aldo_adv', 'aimanwitjaksono'): 1,
#  ('mommy.saeida', 'smindrawati'): 1,
#  ('herieaje', 'official'): 1,
#  ('insomnia__mcmxcv__', 'presidenrepublikindonesia'): 1,
#  ('insomnia__mcmxcv__', 'prabowo'): 1,
#  ('insomnia__mcmxcv__', 'fraksipartaigerindra'): 1,
#  ('nasr_en.as', 'bahlillahadalia'): 1,
#  ('rham.md', 'smindrawati'): 1,
#  ('rakhmat_busthomi', 'smindrawati'): 1,
#  ('ekhyalfatih', 'smindrawati'): 1,
#  ('rizalbojesz', 'gusyaqut'): 1,
#  ('indahnyakotapekanbaru', 'prabowo'): 1,
#  ('indahnyakotapekanbaru', 'gerindra'): 1,
#  ('22risk_', 'bahlillahadalia'): 1,
#  ('22risk_', 'prabowo'): 1,
#  ('tony_hardianto_02', 'egiedouce'): 1,
#  ('nurasrimaulida', 'prabowo'): 1,
#  ('chindyelath98', 'n_jaftien'): 1,
#  ('tiket_konser123', 'smindrawati'): 1,
#  ('dewi_saja', 'smindrawati'): 1,
#  ('monitsitanggang', 'smindrawati'): 1,
#  ('haruto_akira6721', 'dpr_ri'): 1,
#  ('haruto_akira6721', 'prabowo'): 1,
#  ('irzanrisaldi', 'natalius_pigai'): 1,
#  ('rardiansp', 'prabowo'): 1,
#  ('meliaapr', 'smindrawati'): 1,
#  ('mafrizalandre270_', 'prabowo'): 1,
#  ('dewalautaru', 'vian_osd'): 1,
#  ('vian_osd', 'dewalautaru'): 1,
#  ('putriwhdtns', 'im_hekmachtyar'): 1,
#  ('adigunawanutama', 'prabowo'): 1,
#  ('fahria.zxcc', 'sekretariat'): 1,
#  ('fahria.zxcc', 'bahlillahadalia'): 1,
#  ('fahria.zxcc', 'erickthohir'): 1,
#  ('fahria.zxcc', 'zul'): 1,
#  ('fahria.zxcc', 'listyosigitprabowo'): 1,
#  ('fahria.zxcc', 'titokarnavian'): 1,
#  ('fahria.zxcc', 'rajaantoni'): 1,
#  ('yuliagrn', 'endaahh_11'): 1,
#  ('endaahh_11', 'yuliagrn'): 1,
#  ('andi_m_awal', 'ga'): 1,
#  ('andi_m_awal', 'prabowo'): 1,
#  ('dicki_nabil', 'prabowo'): 1,
#  ('ariesboriz', 'prabowo'): 1,
#  ('ariesboriz', 'listyosigitprabowo'): 1,
#  ('floflorav', 'muljanes'): 1,
#  ('nmitantika', 'vembyoctora'): 1,
#  ('vembyoctora', 'nmitantika'): 1,
#  ('endar.82', 'dennybigboy'): 1,
#  ('eka_fath', 'dennybigboy'): 1,
#  ('dennybigboy', 'eka_fath'): 1,
#  ('sipalingmoni', 'raymondchins'): 1,
#  ('floflorav', 'astriaprn'): 1,
#  ('indrayunandaa', 'smindrawati'): 1,
#  ('_zackyya_', 'salsaer'): 1,
#  ('rachmawatieermaa', 'prabowo'): 1,
#  ('sahabatgowesiantar', 'prabowo'): 1,
#  ('sriandoko_', 'sahabatgowesiantar'): 1,
#  ('shofia_rokhmah', 'aguez_gusuts'): 1,
#  ('rioramadany__', 'agung_rudes'): 1,
#  ('budhy.dhi', 'agung_rudes'): 1,
#  ('astrid.zein', 'prabowo'): 1,
#  ('rmbirtaaaaa', 'rikanarr'): 1,
#  ('bintangastari320', 'smindrawati'): 1,
#  ('anggerm', 'prabowo'): 1,
#  ('komarsoleh7', 'prabowo'): 1,
#  ('much.hartanto', 'presidenrepublikindonesia'): 1,
#  ('ani_lestari77', 'matanajwa'): 1,
#  ('endizulyanata', 'syahputra17_'): 1,
#  ('wisamfahry', 'smindrawati'): 1,
#  ('ansrhdyn03', 'smindrawati'): 1,
#  ('ansrhdyn03', 'bahlillahadalia'): 1,
#  ('ansrhdyn03', 'zul'): 1,
#  ('ansrhdyn03', 'titokarnavian'): 1,
#  ('bayibebek34', 'prabowo'): 1,
#  ('urredcherry', 'prabowo'): 1,
#  ('urredcherry', 'presidenrepublikindonesia'): 1,
#  ('satria_nusantara02', 'prabowo'): 1,
#  ('iamumaar', 'prabowo'): 1,
#  ('chindi1727', 'prabowo'): 1,
#  ('santytravnick', 'prabowo'): 1,
#  ('azhar_bintang_muhammad', 'tolhassiregar'): 1,
#  ('qwertyasn.ac', 'smindrawati'): 1,
#  ('vinsi_dharma87', 'prabowo'): 1,
#  ('aeztrishavaniabi', 'dienlala1987'): 1,
#  ('aeztrishavaniabi', 'prabowo'): 1,
#  ('aeztrishavaniabi', 'gerindra'): 1,
#  ('aeztrishavaniabi', 'presidenrepublikindonesia'): 1,
#  ('rnuzulla', 'smindrawati'): 1,
#  ('abduliqram31', 'hidupsedetik'): 1,
#  ('tirexmadep', 'dpr_ri'): 1,
#  ('tirexmadep', 'puanmaharaniri'): 1,
#  ('tirexmadep', 'king_uyakuya'): 1,
#  ('tirexmadep', 'sahroni'): 1,
#  ('nyari.lucu', 'prabowo'): 1,
#  ('syamsia_satra11', 'smindrawati'): 1,
#  ('sultan_sudirman17', 'smindrawati'): 1,
#  ('nurulfyu', 'prabowo'): 1,
#  ('hendrowijoyo123', 'smindrawati'): 1,
#  ('daniel.marda47', 'smindrawati'): 1,
#  ('rafly.wibowo240101', 'gerindra'): 1,
#  ('rafly.wibowo240101', 'presidenrepublikindonesia'): 1,
#  ('rafly.wibowo240101', 'gibran_rakabuming'): 1,
#  ('rafly.wibowo240101', 'mastercorbuzier'): 1,
#  ('rafly.wibowo240101', 'sumargodenny'): 1,
#  ('rafly.wibowo240101', 'jeromepolin'): 1,
#  ('rafly.wibowo240101', 'dedimulyadi71'): 1,
#  ('zeinedebali', 'prabowo'): 1,
#  ('zeinedebali', 'gerindra'): 1,
#  ('achmad.rehansyah.1', 'irtizaqdalahmas'): 1,
#  ('suroyanarif', 'jpd'): 1,
#  ('jpd.polo', 'suroyanarif'): 1,
#  ('ben_levinous', 'smindrawati'): 1,
#  ('desyadwi', 'ade_rai'): 1,
#  ('farielriz', 'mohamadbagas_s'): 1,
#  ('mohamadbagas_s', 'farielriz'): 1,
#  ('zackyzulfikar__', 'saridona28'): 1,
#  ('yuli03_', 'smindrawati'): 1,
#  ('sholah_raseed', 'prabowo'): 1,
#  ('gar.field_napoleon', 'smindrawati'): 1,
#  ('achmad.rehansyah.1', 'kaimsasiku'): 1,
#  ('f_rizal01', 'official'): 1,
#  ('jagorisol', 'smindrawati'): 1,
#  ('olie_august85', 'smindrawati'): 1,
#  ('claruzalejandro', 'smindrawati'): 1,
#  ('africanadi_', 'smindrawati'): 1,
#  ('nida_hidayah', 'smindrawati'): 1,
#  ('nuzuliea', 'romie_229'): 1,
#  ('boesetyawan', 'smindrawati'): 1,
#  ('teukurizkir', 'smindrawati'): 1,
#  ('gasmi_nganjuk.official', 'smindrawati'): 1,
#  ('gresyel', 'smindrawati'): 1,
#  ('achmad.rehansyah.1', 'rasdi_muchtar'): 1,
#  ('firnamaulia', 'smindrawati'): 1,
#  ('veni_daventi', 'ganjar_inst'): 1,
#  ('pudjasu', 'prabowo'): 1,
#  ('achmad.rehansyah.1', 'ahmadruyan9'): 1,
#  ('ahmadruyan9', 'smindrawati'): 1,
#  ('naeliatitik', 'subaltern___'): 1,
#  ('naeliatitik', 'kucingoyen2079'): 1,
#  ('kucingoyen2079', 'naeliatitik'): 1,
#  ('sam11ja', 'maulana'): 1,
#  ('nuritiewz', 'official'): 1,
#  ('san_jri', 'rajaantoni'): 1,
#  ('septi_faiffaniati_3', 'prabowo'): 1,
#  ('serwyqueen', 'salsaer'): 1,
#  ('serwyqueen', 'irwandiferry'): 1,
#  ('wahjoe_kum', 'sz_szoboslai'): 1,
#  ('basil.hawking', 'sz_szoboslai'): 1,
#  ('diego.fly1', 'bocoraluspolitik'): 1,
#  ('muharifrahman26', 'dimas_rahmat20'): 1,
#  ('oensragil.id', 'zul'): 1,
#  ('oensragil.id', 'titokarnavian'): 1,
#  ('oensragil.id', 'airlanggahartarto_official'): 1,
#  ('oensragil.id', 'luhut'): 1,
#  ('oensragil.id', 'listyosigitprabowo'): 1,
#  ('oensragil.id', 'prabowo'): 1,
#  ('rifqi492', 'bahlillahadalia'): 1,
#  ('fnm.maulana', 'prabowo'): 1,
#  ('sayyid_2302', 'presidenrepublikindonesia'): 1,
#  ('angga_ramdhann', 'michaelnadeak_id'): 1,
#  ('himaqueena', 'dndung_22'): 1,
#  ('aldiseptian0199', 'herzon'): 1,
#  ('arepngecaprak', 'nksavio'): 1,
#  ('nksavio', 'arepngecaprak'): 1,
#  ('andra_metavers', 'prabowo'): 1,
#  ('fajrinsta', 'official'): 1,
#  ('muhamad_faisal0093', 'rajaantoni'): 1,
#  ('arif_rustian', 'prabowo'): 1,
#  ('arif_rustian', 'presidenrepublikindonesia'): 1,
#  ('sugiartiikikii', 'smindrawati'): 1,
#  ('bambelagi', 'warungkl2'): 1,
#  ('warungkl2', 'bambelagi'): 1,
#  ('coissn', 'prabowo'): 1,
#  ('ayrosalia', 'lydiaamariana'): 1,
#  ('lydiaamariana', 'ayrosalia'): 1,
#  ('syahziar', 'zul'): 1,
#  ('syahziar', 'rajaantoni'): 1,
#  ('floflorav', 'smindrawati'): 1,
#  ('liualfarezelwibowo', 'smindrawati'): 1,
#  ('basoeki_widjaja', 'prabowo'): 1,
#  ('basoeki_widjaja', 'gerindra'): 1,
#  ('hadicobruts', 'pandu_ozil11'): 1,
#  ('aamedo3', 'gerindra'): 1,
#  ('aamedo3', 'prabowo'): 1,
#  ('aamedo3', 'presidenrepublikindonesia'): 1,
#  ('hammmmmmmag09', 'rafiq_putra97'): 1,
#  ('tyfanew_21', 'rafiq_putra97'): 1,
#  ('you.wishtoknowme', 'tyfanew_21'): 1,
#  ('19hendrasetiawan33', 'prabowo'): 1,
#  ('berdos_farabuto', 'prabowo'): 1,
#  ('__umi.adibah__', 'smindrawati'): 1,
#  ('kurniawanmirdan', 'wichaaw'): 1,
#  ('mohammedhesham._', 'prabowo'): 1,
#  ('hammmmmmmag09', 'ilham_m_ge8'): 1,
#  ('scorgees', 'hammmmmmmag09'): 1,
#  ('irmamulyani11', 'prabowo'): 1,
#  ('teer_yteee3949', 'subachan_subachan'): 1,
#  ('subachan_subachan', 'teer_yteee3949'): 1,
#  ('teer_yteee3949', 'farid_atmaja'): 1,
#  ('isabellemasniari', 'mohmahfudmd'): 1,
#  ('isabellemasniari', 'prabowo'): 1,
#  ('refpi_irmansah', 'prabowo'): 1,
#  ('refpi_irmansah', 'presidenrepublikindonesia'): 1,
#  ('teer_yteee3949', 'prabowo'): 1,
#  ('thecaptaen_', 'prabowo'): 1,
#  ('alamsyahsubakri', 'prabowo'): 1,
#  ('alamsyahsubakri', 'erickthohir'): 1,
#  ('alamsyahsubakri', 'rajaantoni'): 1,
#  ('alamsyahsubakri', 'bahlillahadalia'): 1,
#  ('alamsyahsubakri', 'titokarnavian'): 1,
#  ('alamsyahsubakri', 'luhut'): 1,
#  ('alamsyahsubakri', 'listyosigitprabowo'): 1,
#  ('naga_05_hoki', 'narasinewsroom'): 1,
#  ('pefintadiana', 'rockygerungfans'): 1,
#  ('mhd__fnda', 'prabowo'): 1,
#  ('anis.potopoto', 'bocoraluspolitik'): 1,
#  ('ummialkahfi', 'insanmuttaqin_'): 1,
#  ('avocado0941', 'prabowo'): 1,
#  ('nugraha.tara', 'abdillah'): 1,
#  ('anitaoktaviasitumorangreal', 'smindrawati'): 1,
#  ('hanamaryam__', 'smindrawati'): 1,
#  ('linda.dwiayu', 'mutiaayupratiwii'): 1,
#  ('linda.dwiayu', 'dr'): 1,
#  ('rahayuning.tyas9', 'linda'): 1,
#  ('ezelodes', 'bahlillahadalia'): 1,
#  ('ezelodes', 'prabowo'): 1,
#  ('nurhalimy7', 'prabowo'): 1,
#  ('idatusadiah.harahap', 'prabowo'): 1,
#  ('sandii2905', 'susipudjiastuti115'): 1,
#  ('sandii2905', 'prabowo'): 1,
#  ('scorgees', 'art_jepret'): 1,
#  ('scorgees', 'sezaree'): 1,
#  ('yonadeb', 'deaasukma'): 1,
#  ('aning_27.2', 'smindrawati'): 1,
#  ('havesasad', 'sanggarsetiadharma'): 1,
#  ('altiopras', 'havesasad'): 1,
#  ('jollyroger45_', 'havesasad'): 1,
#  ('velocyvnya_', 'fauzan_putra_b'): 1,
#  ('bosupik99', 'fauzan_putra_b'): 1,
#  ('nuun.1988', 'docturnal_'): 1,
#  ('docturnal_', 'nuun'): 1,
#  ('tiyasambawani', 'hermans_36'): 1,
#  ('ilan.albes', 'hermans_36'): 1,
#  ('amy_jakarta', 'adit_'): 1,
#  ('vikarilesta', 'adit_'): 1,
#  ('achmad.rehansyah.1', 'doraeyon_'): 1,
#  ('alee.consultant', 'doraeyon_'): 1,
#  ('agusgimnastiar_', 'doraeyon_'): 1,
#  ('subhan_ubam', 'bisaaja52'): 1,
#  ('kokosamajk', 'radmodiharjo'): 1,
#  ('berkatreynardo', 'auzanmarrio'): 1,
#  ('berkatreynardo', 'adietakbar_'): 1,
#  ('miriptokovape.bintaro', 'tukanglistrikbelajaran'): 1,
#  ('lucky76s', 'biijisesawi'): 1,
#  ('alifikri632', 'biijisesawi'): 1,
#  ('ini.thorrrr', 'biijisesawi'): 1,
#  ('maz.bagoez.beloved', 'rdhrmdhn'): 1,
#  ('tary_aww', 'rdhrmdhn'): 1,
#  ('a.bukhory_3', 'taufikk'): 1,
#  ('dede_ucihabalishoes18', 'taufikk'): 1,
#  ('iarthista', 'taufikk'): 1,
#  ('masyarakat9911', 'a'): 1,
#  ('azissamruu', 'a'): 1,
#  ('topanrizkyr', 'dede_ucihabalishoes18'): 1,
#  ('ttk.project', 'adhibonzai'): 1,
#  ('alifnoor_maximine', 'annas_so'): 1,
#  ('ttk.project', 'nano'): 1,
#  ('sandiramdhani', 'puji_widyanti'): 1,
#  ('dwidananx', 'azizputraaaaa'): 1,
#  ('edisaja1983', 'azizputraaaaa'): 1,
#  ('hendyhedyawan', 'adriantomay22'): 1,
#  ('octhavvia6', 'hendyhedyawan'): 1,
#  ('noe_oke95', 'maxluwis'): 1,
#  ('auzanmarrio', 'maxluwis'): 1,
#  ('octhavvia6', 'nalv_ti'): 1,
#  ('nalv_ti.ok', 'octhavvia6'): 1,
#  ('muhamadraihan_nur', 'fida'): 1,
#  ('fida.degel', 'muhamadraihan_nur'): 1,
#  ('ttk.project', 'alifikri632'): 1,
#  ('alifikri632', 'ttk'): 1,
#  ('tetapyosua', 'rzlrust'): 1,
#  ('ttk.project', 'ubeidhabibi'): 1,
#  ('octhavvia6', 'a'): 1,
#  ('oska.den', 'sumargodenny'): 1,
#  ('rhama.bpn.sgta', 'oska'): 1,
#  ('nowomanlikeevil', 'oska'): 1,
#  ('wahyu_uduy', 'ade_rai'): 1,
#  ('wahyu_uduy', 'prabowo'): 1,
#  ('rhama.bpn.sgta', 'wahyu_uduy'): 1,
#  ('wahyu_uduy', 'rhama'): 1,
#  ('tiaputrianaoehoe', 'smindrawati'): 1,
#  ('glhbn', 'dr'): 1,
#  ('rudi.syahrizal', 'glhbn'): 1,
#  ('apri_isnanto', 'azharirakhman'): 1,
#  ('azharirakhman', 'apri_isnanto'): 1,
#  ('isya_andika', 'rocky'): 1,
#  ('putralibrasang', 'smindrawati'): 1,
#  ('edisaja1983', 'mohmahfudmd'): 1,
#  ('azka_dhanurendra', 'smindrawati'): 1,
#  ('leliyan12', 'basukibtp'): 1,
#  ('rezza_ilham1808', 'prabowo'): 1,
#  ('jazimerveous', 'alaskankingcrabb'): 1,
#  ('alaskankingcrabb', 'hndabimanyu__'): 1,
#  ('ilhamelsoth', 'baratastum'): 1,
#  ('garlandini7', 'rocky'): 1,
#  ('paisald.arasit', 'ditoariotedjo'): 1,
#  ('paisald.arasit', 'dpp_pkb'): 1,
#  ('lalara556', 'prabowo'): 1,
#  ('hasanahaynur', 'canggihfit'): 1,
#  ('andretama26', 'prabowo'): 1,
#  ('rikko.novriyanto91', 'smindrawati'): 1,
#  ('rezayunizar_opaerza', 'mardiguwp'): 1,
#  ('ravitasepti4', 'smindrawati'): 1,
#  ('mutiahwijilestari', 'prabowo'): 1,
#  ('mutiahwijilestari', 'presidenrepublikindonesia'): 1,
#  ('za.fz_', 'fawwazhaqqi01'): 1,
#  ('aoen666', 'mastercorbuzier'): 1,
#  ('f.shavemaster', 'mastercorbuzier'): 1,
#  ('fredigunawansetio', 'rajaantoni'): 1,
#  ('madamahesa', 'barudak_gudang_kapuk'): 1,
#  ('madamahesa', 'fmy'): 1,
#  ('adefurqonn', 'vindes'): 1,
#  ('marditoakp', 'prabowo'): 1,
#  ('teman_terakhir10', 'prabowo'): 1,
#  ('thomedu', 'permanailham84'): 1,
#  ('niskala.wastu_kancana', 'permanailham84'): 1,
#  ('sahirabarai', 'ripperz_'): 1,
#  ('fauziah.nurii', 'fauziah'): 1,
#  ('gbriieel', 'firmanior'): 1,
#  ('rifkidimasaditya', 'gbriieel'): 1,
#  ('gildan.rsr', 'gbriieel'): 1,
#  ('octhavvia6', 'bjoeyyyy'): 1,
#  ('alfian_dharma_wicaksana', 'tinobkt'): 1,
#  ('sopyan.aam', 'nicomartens999'): 1,
#  ('ai_ainie125', 'sopyan'): 1,
#  ('anantzo', 'irpan_syabana'): 1,
#  ('rly.syp', 'satrio3nurcahya'): 1,
#  ('rofiq_muamar_pratama', 'rly'): 1,
#  ('satrio3nurcahya', 'rly'): 1,
#  ('octhavvia6', 'gerindra'): 1,
#  ('cepyanugrahs90', 'prabowo'): 1,
#  ('cepyanugrahs90', 'gerindra'): 1,
#  ('ayizthom', 'rocky'): 1,
#  ('taufik_hidayat237', 'prabowo'): 1,
#  ('toerantang', 'prabowo'): 1,
#  ('hrmaulana', 'mastercorbuzier'): 1,
#  ('yonowijaya46', 'prabowo'): 1,
#  ('sev.tjhoa', 'prabowo'): 1,
#  ('sev.tjhoa', 'gerindra'): 1,
#  ('rossargallica', 'junaydfloyd'): 1,
#  ('rossargallica', 'novhndyn'): 1,
#  ('rossargallica', 'rantirahmdn'): 1,
#  ('rossargallica', 'salsa'): 1,
#  ('metanayy', 'junaydfloyd'): 1,
#  ('metanayy', 'unitrh'): 1,
#  ('raimaus', 'mrozikinn'): 1,
#  ('donyendica', 'devisimanjorang08'): 1,
#  ('stevenid26', 'enzoyoay'): 1,
#  ('deni.fitriyanto', 'mineurpha'): 1,
#  ('oakoho', 'veren_hayon'): 1,
#  ('latepicku', 'bil_lee_'): 1,
#  ('nichoopras', 'jasaolahdata'): 1,
#  ('ravaliant', 'dimassaktinugraha'): 1,
#  ('mntpppppp111', 'mam_ading2728'): 1,
#  ('mam_ading2728', 'mntpppppp111'): 1,
#  ('ninikao4400', 'tikawngso'): 1,
#  ('bonifasius_bima', 'deaamlyaa_'): 1,
#  ('widyatri___', 'daiamond3u'): 1,
#  ('ghozali11_', 'bandung'): 1,
#  ('lindrianda', 'bandung'): 1,
#  ('rferdinan_007', 'bandung'): 1,
#  ('bonifasius_bima', 'dimsdwii'): 1,
#  ('adity4._', 'dimsdwii'): 1,
#  ('_almayym', 'indie_24jam'): 1,
#  ('taanilly', 'indie_24jam'): 1,
#  ('yulianafrastikaa', 'indie_24jam'): 1,
#  ('natluve_', 'trioatma'): 1,
#  ('bd_raffa', 'trioatma'): 1,
#  ('fadhil_saputra.045', 'trioatma'): 1,
#  ('alf.iw12', 'produkdigitalent'): 1,
#  ('lqmnfatih', '_rinadh'): 1,
#  ('upp_aja', '_rinadh'): 1,
#  ('lalaamala', 'adisilva21'): 1,
#  ('adisilva21', 'riokurniawan_id'): 1,
#  ('adisuryaputrariadii', 'riokurniawan_id'): 1,
#  ('naddyaasya', 'adivnm'): 1,
#  ('d_vrile', 'adivnm'): 1,
#  ('d_vrile', 'n'): 1,
#  ('chap99_', 'adivnm'): 1,
#  ('youngdla_', 'mass'): 1,
#  ('deni.fitriyanto', 'hideyuki'): 1,
#  ('hideyuki.id', 'deni'): 1,
#  ('deni.fitriyanto', 'frsardan_'): 1,
#  ('zulfadliputraas', 'frsardan_'): 1,
#  ('larissa_dewii', 'difi_raw'): 1,
#  ('log_aii', 'larissa_dewii'): 1,
#  ('ditrubyytay', 'takutkecoak'): 1,
#  ('michavann', 'kikeydira'): 1,
#  ('rferdinan_007', 'kikeydira'): 1,
#  ('sugaroflunar', 'hansraizee_'): 1,
#  ('rvvlnsyah12', 'yosafatsimarmata'): 1,
#  ('rvvlnsyah12', 'amariadc'): 1,
#  ('amariadc', 'rvvlnsyah12'): 1,
#  ('dindarvian', 'vira'): 1,
#  ('abaehaqi_id', 'jasapindahanbali'): 1,
#  ('alya_anaknya_pak_waka', 'jasapindahanbali'): 1,
#  ('ichaaaaaaaaaaaaa08', 'ardinadityaa'): 1,
#  ('dindarvian', 'panji_justice7'): 1,
#  ('syafiraoctafiani', 'smindrawati'): 1,
#  ('_sucinuraini1', 'syafiraoctafiani'): 1,
#  ('queenfir_', 'syafiraoctafiani'): 1,
#  ('lia.ryan2020', 'syafiraoctafiani'): 1,
#  ('ahmadrifai0459', 'bahlillahadalia'): 1,
#  ('ahmadrifai0459', 'prabowo'): 1,
#  ('rzalcavalera', 'agusyudhoyono'): 1,
#  ('rummatadody', 'kemenpar'): 1,
#  ('rummatadody', 'prabowo'): 1,
#  ('gustiamw', 'windafbrnt'): 1,
#  ('ayusriwahyunih', 'rezabahroem'): 1,
#  ('_almayym', 'rezabahroem'): 1,
#  ('dimastpramudita', 'rezabahroem'): 1,
#  ('cullens2024', 'christopher_adijaya'): 1,
#  ('christopher_adijaya', 'wisnuayp'): 1,
#  ('hanxxdo', 'mirrlosh'): 1,
#  ('thea_dyah', 'luckytwoacc_'): 1,
#  ('ham.putraa', 'aryakentoz12'): 1,
#  ('marimogstn', '_rajisSri'): 1,
#  ('ham.putraa', 'iamahyl'): 1,
#  ('catherine_vanbora', 'rndyahong'): 1,
#  ('f.aulia25', 'zakyazzikra'): 1,
#  ('restumujijoyo', 'budi_albukhari'): 1,
#  ('budi_albukhari', 'restumujijoyo'): 1,
#  ('salmainstbrz', 'chllprk'): 1,
#  ('nikomodjo', 'prabowo'): 1,
#  ('riyarsil', 'smindrawati'): 1,
#  ('fadilarizki_', 'seesaw'): 1,
#  ('hassan_parulian', 'nadbilqis'): 1,
#  ('sorayaainaa', 'muhammadcholis2'): 1,
#  ('renitameilia', 'miaajengs'): 1,
#  ('_______gaga', 'bahlillahadalia'): 1,
#  ('heli151001', 'yourmine'): 1,
#  ('lzltaa', 'mahartyasnasaputri'): 1,
#  ('afrizalrrx', 'dimasadji_k'): 1,
#  ('dimasadji_k', 'afrizalrrx'): 1,
#  ('rustychainnn', 'prabowo'): 1,
#  ('adaammubarok', 'iamrafiramzi18'): 1,
#  ('ravenzzyy', 'prabowo'): 1,
#  ('mavoslayer', 'ravenzzyy'): 1,
#  ('ingeagnesz', 'smindrawati'): 1,
#  ('itsmeforeveryoung_', 'smindrawati'): 1,
#  ('donipurr', 'anastasiayhna'): 1,
#  ('donipurr', 'frndinda'): 1,
#  ('frndinda', 'anastasiayhna'): 1,
#  ('vlt.naa_', 'smindrawati'): 1,
#  ('ihsannnnudin', 'wira_shaka'): 1,
#  ('wira_shaka', 'ihsannnnudin'): 1,
#  ('rajgrendaaudia', 'prabowo'): 1,
#  ('wnddp__', 'edoo_akhsan'): 1,
#  ('agathaadria_', 'prabowo'): 1,
#  ('pranata.ivan12', 'prabowo'): 1,
#  ('pranata.ivan12', 'bahlillahadalia'): 1,
#  ('ihsannnnudin', 'luyor_al_hanif'): 1,
#  ('prasetyo_emilarie', 'prabowo'): 1,
#  ('wmfy_', 'kementeriankegelapan'): 1,
#  ('wmfy_', 'semakindidevan'): 1,
#  ('princeharrie12', 'iniakunsellaaa'): 1,
#  ('fachminaufal_', 'ajisantososan21'): 1,
#  ('ajisantososan21', 'fachminaufal_'): 1,
#  ('leilaroom', 'rajaantoni'): 1,
#  ('ugasbanang__', 'presidenrepublikindonesia'): 1,
#  ('martakenzero_', 'smindrawati'): 1,
#  ('hi.aniianii', 'yuyenlee_'): 1,
#  ('farizaarif07', 'bahlillahadalia'): 1,
#  ('farizaarif07', 'melangkahdaritimur'): 1,
#  ('farizaarif07', 'prabowo'): 1,
#  ('jouririssinaga', 'smindrawati'): 1,
#  ('volkgvg', 'shansrahayu'): 1,
#  ('indratnosigit', 'rgdiwan1010'): 1,
#  ('ptrhndyni', '_inaaa18'): 1,
#  ('niaprid', 'rolln'): 1,
#  ('arkina_mei', 'sanihadibrata'): 1,
#  ('gfrdwiputra', 'smindrawati'): 1,
#  ('meyarchivve', 'prgga_dk'): 1,
#  ('ranisaraswatii', 'smindrawati'): 1,
#  ('arkina_mei', 'xynt_iu'): 1,
#  ('starryp0nd', 'bahlillahadalia'): 1,
#  ('karepediplo', 'smindrawati'): 1,
#  ('rsm.hrnd', 'bung'): 1,
#  ('bung.isal', 'rsm'): 1,
#  ('agungfirmansyyah_12', 'beyourap'): 1,
#  ('dinar_melodi', 'ditoariotedjo'): 1,
#  ('dinar_melodi', 'prabowo'): 1,
#  ('jann.ah4464', 'jokowi'): 1,
#  ('ihsan.alprss', 'prabowo'): 1,
#  ('ihsan.alprss', 'presidenrepublikindonesia'): 1,
#  ('lianka.drg', 'prabowo'): 1,
#  ('noviisaputri_', 'prabowo'): 1,
#  ('amandaazly', 'bil_lee_'): 1,
#  ('bimaananta', 'bil_lee_'): 1,
#  ('ernsprynti', 'bimaananta'): 1,
#  ('23isaaac', 'gardynianissa'): 1,
#  ('rendyhyi', '23isaaac'): 1,
#  ('23isaaac', 'rendyhyi'): 1,
#  ('javanoase', 'prabowo'): 1,
#  ('javanoase', 'kantorstafpresidenri'): 1,
#  ('javanoase', 'presidenrepublikindonesia'): 1,
#  ('javanoase', 'sekretariat'): 1,
#  ('javanoase', 'kemensetneg'): 1,
#  ('jjeessiiiee', 'kelilit'): 1,
#  ('heriant_international', 'faaaaadiiil'): 1,
#  ('revan_vaan', 'aziz_fatchur'): 1,
#  ('aanorayy', 'mwerrie'): 1,
#  ('ida_yatulj', 'mwerrie'): 1,
#  ('dofficial7', 'mwerrie'): 1,
#  ('alvintheoriza', 'listyosigitprabowo'): 1,
#  ('aazizahnf_', 'joshuaa77666'): 1,
#  ('barrel_0', 'aazizahnf_'): 1,
#  ('iqbalrifqi777', 'prabowo'): 1,
#  ('shellasonia17', 'erwinayesica'): 1,
#  ('aazizahnf_', 'ardilahpuspa'): 1,
#  ('ardilahpuspa', 'aazizahnf_'): 1,
#  ('chicha_renden', 'ardilahpuspa'): 1,
#  ('ddisicaa_', 'nraahma'): 1,
#  ('ardilahpuspa', 'dpr_ri'): 1,
#  ('sekencoiiss_', 'rusli_muhajirin'): 1,
#  ('hilutfi_', 'arenagadget__'): 1,
#  ('cjustinrimbat', 'mukhtarudin'): 1,
#  ('cleverjayen4ever', 'imankurniawan_13'): 1,
#  ('serlyaprlyn', 'fahrizulkarnainp'): 1,
#  ('siiriyans', 'smindrawati'): 1,
#  ('ernieee6', 'siiriyans'): 1,
#  ('lestarymiaku', 'bambie'): 1,
#  ('shenlyy', 'itzmye'): 1,
#  ('shenlyy', 'anggun'): 1,
#  ('nisafhzaa', 'nurhayani_26'): 1,
#  ('nurhayani_26', 'nisafhzaa'): 1,
#  ('abesst_543', 'prabowo'): 1,
#  ('dhe.noke', 'gudsat999'): 1,
#  ('gede.kusumaaa', 'smindrawati'): 1,
#  ('dandi_aef', 'prabowo'): 1,
#  ('uurfutture', 'prabowo'): 1,
#  ('thereskymuhammad', 'iwaktongkoliwaklele'): 1,
#  ('bn__gxxtd', 'prabowo'): 1,
#  ('yohanes.am', 'smindrawati'): 1,
#  ('kaikyou_26', 'fauzia________'): 1,
#  ('aharism27', 'rajaantoni'): 1,
#  ('_yulieeeee', 'jeunghoon_____'): 1,
#  ('nestheaceae', 'adispadyana'): 1,
#  ('nestheaceae', 'maulidakmll'): 1,
#  ('nestheaceae', 'rafaaael'): 1,
#  ('nestheaceae', 'epuyyy'): 1,
#  ('epuyyy.e', 'nestheaceae'): 1,
#  ('zeinmarccc', 'ollie_aulia'): 1,
#  ('putra_max_', 'justisiaharsono'): 1,
#  ('reyhansagevti', 'prabowo'): 1,
#  ('eputriyyyy', 'trioatma'): 1,
#  ('erwindjuntak', 'urfanramadhan'): 1,
#  ('urfanramadhan', 'erwindjuntak'): 1,
#  ('sr_muthia', 'prabowo'): 1,
#  ('arfasptian', 'prabowo'): 1,
#  ('imayusiagian', 'rajaantoni'): 1,
#  ('dwiii_annn', 'andilavon'): 1,
#  ('arifriandia', 'prabowo'): 1,
#  ('riobagoesp', 'prabowo'): 1,
#  ('mutyafahira', 'smindrawati'): 1,
#  ('militarynewsinternational2', 'militarynewsinternational'): 1,
#  ('fznirsyd_', 'geriorag'): 1,
#  ('dalgoncandy_', 'jauw'): 1,
#  ('emmili_dwi', 'prabowo'): 1,
#  ('jib_elshirazy', 'fupo'): 1,
#  ('din_da6839', 'wnda_fp'): 1,
#  ('rahmi_mln', 'wnda_fp'): 1,
#  ('ungieww', 'wnda_fp'): 1,
#  ('thariqsalmandaffa', 'official'): 1,
#  ('febriyustian_', 'smindrawati'): 1,
#  ('f.ef__', 'sersanhusen_'): 1,
#  ('sersanhusen_', 'f'): 1,
#  ('bi_ntang1502', 'prabowo'): 1,
#  ('ha.bi.bu', 'smindrawati'): 1,
#  ('rendynadyan', 'prabowo'): 1,
#  ('rinpast', 'sutrianaawjy__________'): 1,
#  ('sutrianaawjy__________', 'rinpast'): 1,
#  ('bergkamp_p', 'sulaimanelahmad'): 1,
#  ('bergkamp_p', 'darealize_'): 1,
#  ('im.semm', 'sulaimanelahmad'): 1,
#  ('zey_photograf', 'cipeng_uchiha'): 1,
#  ('khessy21', 'dera'): 1,
#  ('tgalih_wijayanto', 'khessy21'): 1,
#  ('babyviooo', 'prabowo'): 1,
#  ('rifky.fr', 'prabowo'): 1,
#  ('jae.kimhyeon', 'smindrawati'): 1,
#  ('promosi_cantik', 'adisya_96'): 1,
#  ('arf.arfian', 'prabowo'): 1,
#  ('armisoemardi', 'neurball'): 1,
#  ('egyxprasetyo', 'neurball'): 1,
#  ('luckysuprayogi', 'prabowo'): 1,
#  ('aslumpgod__', 'signaturechoco0'): 1,
#  ('aslumpgod__', 'zayyannnnsq_'): 1,
#  ('linggachndraaa', 'endrianhs'): 1,
#  ('endrianhs', 'linggachndraaa'): 1,
#  ('difslm_', 'arrmyy17_'): 1,
#  ('ikhaaikhull', 'prabowo'): 1,
#  ('ikhaaikhull', 'presidenrepublikindonesia'): 1,
#  ('raplyy_tubeless', 'pontianak'): 1,
#  ('febrinaharyono', 'dinavanjaitan'): 1,
#  ('febrinaharyono', 'kpamadea'): 1,
#  ('febrinaharyono', 'dwedrina'): 1,
#  ('dikodr', 'afdhalzaky'): 1,
#  ('ekybong365', 'sigit_breakfast'): 1,
#  ('respati_z', 'ekybong365'): 1,
#  ('faxrixnxx', 'farhanlugina'): 1,
#  ('adityarahmawaan_', 'don_husnay'): 1,
#  ('ferdinantambunan14', 'bagusdwiwibowo'): 1,
#  ('thea_dyah', 'miripadit_'): 1,
#  ('bagus_khott', 'troyaedvn_'): 1,
#  ('andriianr_', 'official'): 1,
#  ('dwiwahyuni464', 'prabowo'): 1,
#  ('zahrashfaaara', 'dwiwahyuni464'): 1,
#  ('faislhfz', 'a_man_and_his_dream'): 1,
#  ('billypradhn', 'ianone__'): 1,
#  ('satriogumilangg', 'ianone__'): 1,
#  ('ianone__', 'billyprdhn'): 1,
#  ('lutfi.upay28', 'jnurcy_'): 1,
#  ('aji.dewantoro7', 'bangadit_69'): 1,
#  ('alinuralghozali', 'adakahcafe2020'): 1,
#  ('i.ilm', 'diary'): 1,
#  ('fahmirosyada10', 'erlis_na_erlis'): 1,
#  ('febzen_96', 'chandra182121'): 1,
#  ('khoirulfl', 'chandra182121'): 1,
#  ('driciv', 'arumi1307'): 1,
#  ('ox_tiz.din', 'muhammad_hezra'): 1,
#  ('uciharoyy', 'muhammad_hezra'): 1,
#  ('khoirulfl', 'muhammad_hezra'): 1,
#  ('zaqub.orenska28', 'arifback11'): 1,
#  ('khoirulfl', 'arifback11'): 1,
#  ('arifback11', 'khoirulfl'): 1,
#  ('ulye_zriyani', 'iln'): 1,
#  ('ryan_wtp', 'ulye_zriyani'): 1,
#  ('aldyanometer', 'ulye_zriyani'): 1,
#  ('hanafi__18', 'arifbd_'): 1,
#  ('khoirulfl', 'hanafi__18'): 1,
#  ('m_arie66', 'hanafi__18'): 1,
#  ('ab_ilman', 'suryaaje_'): 1,
#  ('lalunatyana', 'so_lichaa'): 1,
#  ('celwmotan_met_met', 'mbayuaprianto'): 1,
#  ('gandung.ra', 'zardioka'): 1,
#  ('andrejosafat_', 'fahri_noviantoo'): 1,
#  ('rhisky.26', 'fahri_noviantoo'): 1,
#  ('randy.qyuha', 'fanzaayn'): 1,
#  ('rhisky.26', 'randy'): 1,
#  ('wahyu.stevano', 'luthfiemuamar'): 1,
#  ('van.himx', 'luthfiemuamar'): 1,
#  ('fk25._', 'wahyu'): 1,
#  ('bheema11', 'azizjayapartnersip2015'): 1,
#  ('azizjayapartnersip2015', 'bheema11'): 1,
#  ('kareemenzo', 'amirhuu'): 1,
#  ('fahmirosyada10', 'rezaaszhari'): 1,
#  ('om_nunu12', 'jaka_huna25'): 1,
#  ('myimamsantoso', 'jaka_huna25'): 1,
#  ('28.nemesis', 'zain_sulaiman_ramadhan1725'): 1,
#  ('iskandr30', 'zain_sulaiman_ramadhan1725'): 1,
#  ('wmfms_', 'damara18_'): 1,
#  ('wmfms_', 'jokowi'): 1,
#  ('bersihsehat88', 'danielmonorel'): 1,
#  ('danielmonorel', 'bersihsehat88'): 1,
#  ('franciscussimon', 'titofergianto'): 1,
#  ('aldy_mabir', 'hendra'): 1,
#  ('hery_wibowoo', 'prabowo'): 1,
#  ('lllgita97', 'hery_wibowoo'): 1,
#  ...}

# %% [markdown]
# #### User Info

# %%
# comment count and sort by value descending
comment_count = data['username'].value_counts().to_dict()
comment_count = dict(sorted(comment_count.items(), key=lambda item: item[1], reverse=True))
comment_count
# Out:
# {'octhavvia6': 9,
#  'heyjoykuy': 8,
#  'achmad.rehansyah.1': 5,
#  'mustangid.mustangid': 5,
#  'ttk.project': 5,
#  'floflorav': 5,
#  'deddy.gondrong.3910': 5,
#  'khoirulfl': 5,
#  'kebenaranpastiterjadi': 5,
#  'dwanharun': 4,
#  'scorgees': 4,
#  'arkina_mei': 4,
#  'wahyu_rajin_menabung_': 4,
#  'lenirahardja': 4,
#  'gbriieel': 4,
#  'thea_dyah': 4,
#  'io9713': 4,
#  'andriawanarif24': 4,
#  'alifikri632': 4,
#  'wvictorym': 4,
#  'brooklyn_cheesee': 4,
#  'panduadiputrawijaya': 4,
#  'ikbarsinaga999': 4,
#  'ilhamelsoth': 3,
#  'docturnal_': 3,
#  'irtizaqdalahmas': 3,
#  'foraes4': 3,
#  'naeliatitik': 3,
#  'hendyhedyawan': 3,
#  'donal79': 3,
#  'hideyuki.id': 3,
#  'sonnydharmawan1707': 3,
#  'bergkamp_p': 3,
#  'aryosamuelhartanto': 3,
#  'amy_jakarta': 3,
#  'azissamruu': 3,
#  'xtrememerch': 3,
#  'marjuniaaa': 3,
#  'bgsabdrrhmn_29': 3,
#  'pp.imamsyafii_alhasan': 3,
#  'rvvlnsyah12': 3,
#  'indragnwn330': 3,
#  'marselinop13': 3,
#  'fadciks': 3,
#  'damara18_': 3,
#  'mrs_susinisharin': 3,
#  'vian_osd': 3,
#  'ekybong365': 3,
#  'muhammad_noah_elsafik': 3,
#  'rdt_prm': 3,
#  'bagassakbr': 3,
#  'rama_vj_': 3,
#  'edzeki': 3,
#  'downhill_jaksquad': 3,
#  'leliyan12': 3,
#  'christopher_adijaya': 3,
#  'teer_yteee3949': 3,
#  '23isaaac': 3,
#  'ardilahpuspa': 3,
#  'deni.fitriyanto': 3,
#  'donnyo1105': 3,
#  'hammmmmmmag09': 3,
#  'tesseract_dimensions': 2,
#  'lampubumi': 2,
#  'anshorfauzan': 2,
#  'muh.syahruull': 2,
#  'alaskankingcrabb': 2,
#  'rudi.syahrizal': 2,
#  'azkharyaa': 2,
#  'mdcakrawala': 2,
#  'tika_ry': 2,
#  'yadikuningan1': 2,
#  'jonijn_': 2,
#  'winanjar13': 2,
#  'anggianr': 2,
#  'karepediplo': 2,
#  'pradiptayogaa': 2,
#  'kumis_lembut': 2,
#  'mel.dharmawan': 2,
#  'viebgr._': 2,
#  'ranisrina': 2,
#  'baiq._wati': 2,
#  'rafik_smart': 2,
#  'pembangkang_62': 2,
#  'retoucherjakarta': 2,
#  'farhanmau29': 2,
#  'ryannn_adii': 2,
#  'shofiyahabidaheshal': 2,
#  'bung.isal': 2,
#  'azizah.hanum_lpw': 2,
#  'yupipinky18': 2,
#  'ashurin.1010': 2,
#  'rferdinan_007': 2,
#  'hery_wibowoo': 2,
#  'abhedesalam': 2,
#  'ynsmlnprmn98': 2,
#  'fpranss_': 2,
#  'syamsuddingare': 2,
#  'arifback11': 2,
#  'suherpurwocoroko': 2,
#  'bangfaqih38': 2,
#  'fahmirosyada10': 2,
#  'ohhayo.flora': 2,
#  '_zkrry': 2,
#  'nugraha.tara': 2,
#  'nurul_chusna_andrea_tsalis': 2,
#  'canserabbas': 2,
#  'andrehdt_': 2,
#  'lutfi.upay28': 2,
#  'sulton_firdaus': 2,
#  'nayl_46': 2,
#  'sahirabarai': 2,
#  'ahmadruyan9': 2,
#  'dwiii_annn': 2,
#  'ianone__': 2,
#  'fahria.zxcc': 2,
#  'okk_knpi_kutim': 2,
#  'lihend_m': 2,
#  'isanmalau': 2,
#  'hi_mmamad': 2,
#  'ajisantososan21': 2,
#  'hardigunawan__': 2,
#  'juli.4nto': 2,
#  'ulye_zriyani': 2,
#  'marllinaekaa': 2,
#  'hanafi__18': 2,
#  'nawaraja99': 2,
#  'fzy.ahmad': 2,
#  'cimihh': 2,
#  'syed_najieb': 2,
#  'aldi_bdg112': 2,
#  'putra_max_': 2,
#  'wahyu_uduy': 2,
#  'aldy_mabir': 2,
#  'franciscussimon': 2,
#  'danielmonorel': 2,
#  'monitsitanggang': 2,
#  '28.nemesis': 2,
#  'aldy_rnh': 2,
#  'ovie_ny': 2,
#  'jaka_huna25': 2,
#  'rudy_geblek': 2,
#  'azizjayapartnersip2015': 2,
#  'freddyjuan27': 2,
#  'sam11ja': 2,
#  'wahyu.stevano': 2,
#  'luthfiemuamar': 2,
#  'rhisky.26': 2,
#  'andrejosafat_': 2,
#  'lalunatyana': 2,
#  'palestin3_iaminlove': 2,
#  'opickk_inst': 2,
#  'ridwan_tanu': 2,
#  'hanumsamira': 2,
#  'romi_nuril': 2,
#  'tyfanew_21': 2,
#  'reyshahy': 2,
#  'leefuthu_123': 2,
#  'pandu_ozil11': 2,
#  'akang_cutter': 2,
#  'bimaananta': 2,
#  'liualfarezelwibowo': 2,
#  'aldo_adv': 2,
#  'rizalbojesz': 2,
#  'dayatoemar': 2,
#  'nosutris2304': 2,
#  'havesasad': 2,
#  'msrarrahman': 2,
#  'insomnia__mcmxcv__': 2,
#  'ranggaprimadasa': 2,
#  'andi.dm27': 2,
#  'hengkiheng98': 2,
#  'hadi48436': 2,
#  'jessy_humirtap': 2,
#  'ascornion': 2,
#  'doraeyon_': 2,
#  'simon.santoso.77985': 2,
#  'rsnaaamd': 2,
#  'kyky_5_': 2,
#  'ekkosantana': 2,
#  'baladraf_': 2,
#  'warungkl2': 2,
#  'm_hidayatulloh96': 2,
#  'agusgimnastiar_': 2,
#  'langitbiroe92': 2,
#  'rioramadany__': 2,
#  'prahonggo3': 2,
#  'item_pekat': 2,
#  'insanmuttaqin_': 2,
#  'naga_05_hoki': 2,
#  'grestyan': 2,
#  'pram26_': 2,
#  'arenagadget__': 2,
#  'aazizahnf_': 2,
#  'mrtinoo__': 2,
#  'denelwans8': 2,
#  'subachan_subachan': 2,
#  'esuardhani960': 2,
#  'merri_daffa1503': 2,
#  'ilan.albes': 2,
#  'masadiputra_': 2,
#  'linda.dwiayu': 2,
#  'andiippank422': 2,
#  '08selvie': 2,
#  'faaaaadiiil': 2,
#  'yangmanazal': 2,
#  'tomsuryapanji': 2,
#  'herii_kurniawan': 2,
#  'shevani_birgita': 2,
#  'rhama.bpn.sgta': 2,
#  'rahman_kurnia01': 2,
#  'nksavio': 2,
#  'edisaja1983': 2,
#  'bemy_perfectlife': 2,
#  'masa_umum': 2,
#  'nalv_ti.ok': 2,
#  'fida.degel': 2,
#  'pangkypopster': 2,
#  'vembyoctora': 2,
#  'agamhendi': 2,
#  'garena_property': 2,
#  'alienjack2025': 2,
#  'agung_k_kusuma': 2,
#  'gerrlax': 2,
#  'asannopik199': 2,
#  'irkham.mustafa': 2,
#  'guardiian_angel': 2,
#  'nadhisalsaa': 2,
#  'yongki_bank': 2,
#  'meirinashlic': 2,
#  'maulana_akbar0699': 2,
#  'wied_2702': 2,
#  'irha36209': 2,
#  'anjar_cbng': 2,
#  'rudi.gaol': 2,
#  'kaikyou_26': 2,
#  'baratastum': 2,
#  'berkatreynardo': 2,
#  'ujangsulaimann': 2,
#  'husnahardiana': 2,
#  'robbyhabetha': 2,
#  'fhmilham': 2,
#  'deviedwar10': 2,
#  'soniadrewbelle': 2,
#  'meryoktaavia': 2,
#  'dfey77': 2,
#  'medsos1999': 2,
#  'noer_1680': 2,
#  'yogirarala': 2,
#  'wantose_': 2,
#  'a.bukhory_3': 2,
#  'mohikhsani': 2,
#  '_negggaaaaaaa_': 2,
#  'dede_ucihabalishoes18': 2,
#  'iarthista': 2,
#  'a.kurniawan16__': 2,
#  'setiawan26789': 2,
#  'masyarakat9911': 2,
#  'praharja.bangga': 2,
#  'geo.kyboobs': 2,
#  'wahyu.setiawan98': 2,
#  'johanlc': 2,
#  'harissuryajaya': 2,
#  'astriaprn': 2,
#  'heriant_international': 2,
#  '_almayym': 2,
#  'jasapindahanbali': 2,
#  'prasetyo_emilarie': 2,
#  'uwi_frozen_food': 2,
#  'satrio3nurcahya': 2,
#  'syahrilim': 2,
#  'sarden.ina': 2,
#  'ravaliant': 2,
#  'enteresc3': 2,
#  'mntpppppp111': 2,
#  'moelyadhie89': 2,
#  'jowo.bioso': 2,
#  'real.ardian': 2,
#  'jpd.polo': 2,
#  'rifkidimasaditya': 2,
#  'bonifasius_bima': 2,
#  'dindarvian': 2,
#  'denisarimbi06': 2,
#  'ham.putraa': 2,
#  'nicomartens999': 2,
#  'alfian_dharma_wicaksana': 2,
#  'amariadc': 2,
#  'hafidh.dwi.w': 2,
#  'suroyanarif': 2,
#  'yosafatsimarmata': 2,
#  'zerovoid_': 2,
#  'latepicku': 2,
#  'rviardnn': 2,
#  'ademiiko': 2,
#  'zackyzulfikar__': 2,
#  'enia130901': 2,
#  'voltaire_kid66': 2,
#  'hardymasri': 2,
#  'temanmatik': 2,
#  'bjoeyyyy': 2,
#  'mraazzrr': 2,
#  'andr.bmntr_': 2,
#  'ardiiiii_p': 2,
#  'don_husnay': 2,
#  'tommyna70': 2,
#  'hitalesmana': 2,
#  'ariefdc14': 2,
#  'samz_rizi': 2,
#  'izamaranief': 2,
#  'fakta7pedia': 2,
#  'kaimsasiku': 2,
#  'derikssa': 2,
#  'klinik.pupukracikan': 2,
#  'dandy00s': 2,
#  'kaagung': 2,
#  'anakbatak_ke3': 2,
#  'aldihrdnsyah_': 2,
#  'oya_ht': 2,
#  'sugaroflunar': 2,
#  'fajaar_e': 2,
#  'i.m.reys': 2,
#  'salmainstbrz': 2,
#  'dennybigboy': 2,
#  'callmedjlee': 2,
#  'ganiya_galery': 2,
#  'saridona28': 2,
#  'rahayuindah_': 2,
#  'fauziah.nurii': 2,
#  'jollyroger45_': 2,
#  'ihsannnnudin': 2,
#  'lqmnfatih': 2,
#  'wira_shaka': 2,
#  'frsardan_': 2,
#  'budi_albukhari': 2,
#  'muhammadrahmatr': 2,
#  'onlymenq': 2,
#  'zraguzeli': 2,
#  'chllprk': 2,
#  'lalaamala': 2,
#  'diah.ummu.s': 2,
#  'youngdla_': 2,
#  'chandra182121': 2,
#  'khessy21': 2,
#  'sutrianaawjy__________': 2,
#  'ilzamfath': 2,
#  'novacm': 2,
#  'ardnsyah.yusuf': 2,
#  'kesempatantaubat': 2,
#  'ansrhdyn03': 2,
#  'choirull_huda': 2,
#  'endrianhs': 2,
#  'elfadhs': 2,
#  'petrolheadidn': 2,
#  'ravenzzyy': 2,
#  'adityarahmawaan_': 2,
#  'masmas_youtube': 2,
#  'sersanhusen_': 2,
#  'mylovelypinkkeu': 2,
#  'taniasoktaviani': 2,
#  '_nsrimulyani11': 2,
#  'stevhiya': 2,
#  'rinpast': 2,
#  'haris_prayudhi': 2,
#  '_diit23': 1,
#  'bev.bert': 1,
#  'gungg_a97': 1,
#  'tegarrakas': 1,
#  'mrzkzzzzz': 1,
#  'opqriyan': 1,
#  'rendynadyan': 1,
#  'devirosidayanti': 1,
#  'rendyismail1': 1,
#  'jarrqswr': 1,
#  'shenlyy': 1,
#  'bananatub': 1,
#  'qiung21': 1,
#  'praktekind.id': 1,
#  'gratiaginting_': 1,
#  'lestarymiaku': 1,
#  'agstnvs.ckriss': 1,
#  'gumelarrmni': 1,
#  'ridwanthoriq': 1,
#  'nurhayani_26': 1,
#  'bambie.bi': 1,
#  'nisafhzaa': 1,
#  'elegant_jogja_weddingorganizer': 1,
#  'yyunaliass_': 1,
#  'obito_rafi_aufa': 1,
#  'abesst_543': 1,
#  'emyyvauel': 1,
#  'adolf_farhan': 1,
#  'ulfa_mk': 1,
#  'itsmebibah__': 1,
#  'zallxnxn___': 1,
#  'gingeraylee_': 1,
#  'iwaktongkoliwaklele': 1,
#  'redykadika': 1,
#  'akbar.syahdaan': 1,
#  'thereskymuhammad': 1,
#  'hanfa13': 1,
#  'thetransportazion': 1,
#  'cepalekx': 1,
#  'niz4r_arifin': 1,
#  'hsnfathoni': 1,
#  'kamalzari': 1,
#  'chemicalregar': 1,
#  'fennymawarda_': 1,
#  'achmad_1_1': 1,
#  'rdhofrds__': 1,
#  'metanviika': 1,
#  'dainilham_w': 1,
#  'bi_ntang1502': 1,
#  'imamagustian01': 1,
#  'liladhemartha': 1,
#  'asawbowo': 1,
#  'rantonesia': 1,
#  'rizkyadim_': 1,
#  'txkyodope': 1,
#  'rehanaziss': 1,
#  'gudday.capp': 1,
#  'fachribr_': 1,
#  'velyadelvyraa': 1,
#  'dimasputraadjie': 1,
#  'ha.bi.bu': 1,
#  'phaanzky': 1,
#  'sofyanmahardika': 1,
#  'napinkeu': 1,
#  'fachruddinnn': 1,
#  'a_fiq1': 1,
#  'imaniaas': 1,
#  'sosialpolitika': 1,
#  'gudsat999': 1,
#  'pujisawitri': 1,
#  'dhe.noke': 1,
#  'monicanfs': 1,
#  'b_atjaah': 1,
#  'uurfutture': 1,
#  'kialiwali': 1,
#  'hello.kamm': 1,
#  'slsamytiaaa': 1,
#  'gede.kusumaaa': 1,
#  'rissyour_': 1,
#  'dianmustikas': 1,
#  'dandi_aef': 1,
#  'gigestha______': 1,
#  'hariisetiawan_': 1,
#  'ryanfhrzz_': 1,
#  'januarrsanjaya': 1,
#  'arimuktwii': 1,
#  'rakharzkyy_': 1,
#  'donirinaldy': 1,
#  'frederickpelawi': 1,
#  'saaharan': 1,
#  'nndiyah': 1,
#  'andhikaputra_p': 1,
#  'muhammadsuhudfadill': 1,
#  'salmahanifah_': 1,
#  'puttdhl_': 1,
#  'danielkipow': 1,
#  'thisisarikoo': 1,
#  'syrifachmad': 1,
#  'alfrizzk': 1,
#  '_doysky_': 1,
#  'rizkyfajarajip': 1,
#  'haiii_its.me_itutt': 1,
#  'rongeryue': 1,
#  'ruldamayanti': 1,
#  'steven_xizco': 1,
#  'fadelkilwalaga': 1,
#  'rkfthn': 1,
#  'aldisabil': 1,
#  'agasinuraya07': 1,
#  'ervan.anggara18': 1,
#  'wldanfrhn': 1,
#  'whosfellll': 1,
#  'miftanaaa': 1,
#  'windasuhana': 1,
#  'zaf_bree': 1,
#  'agels19': 1,
#  '_____sassss': 1,
#  'bodim_id': 1,
#  'snnyaa_ny': 1,
#  'suciepri2': 1,
#  'ramavuspayani23': 1,
#  'fadly.san': 1,
#  'mardiana.jjongs': 1,
#  'yosuagpr_': 1,
#  'ardhy.frmnsyah': 1,
#  'iiiiffftyrayyy': 1,
#  'lezyar_': 1,
#  'bonnskuyyy': 1,
#  'sekencoiiss_': 1,
#  'rusli_muhajirin': 1,
#  'rakhbokk': 1,
#  'tianblacknwhite2': 1,
#  'putrivardia': 1,
#  'hilutfi_': 1,
#  'barmagribpsan': 1,
#  'fada1096': 1,
#  'tehespanas': 1,
#  'vonzxyyy': 1,
#  'ulfa_khaerunnisa': 1,
#  '_adunggg': 1,
#  'miaa.marpaung_': 1,
#  'evilenkkk': 1,
#  'aaferahanata23': 1,
#  'tatavanreza': 1,
#  'adityavirgi4141': 1,
#  'kintan_atuy': 1,
#  'rafjayh_': 1,
#  'retnw_': 1,
#  'renopanda': 1,
#  'algikuzma': 1,
#  'azizahhh.hhh': 1,
#  'swastihutabarat': 1,
#  'bachank_': 1,
#  'putrykarun': 1,
#  'ginaaaul__': 1,
#  'dindabayu48': 1,
#  'dleanferdiansyah': 1,
#  'robsonlbs_': 1,
#  'unbubbleliebubbleu': 1,
#  'hurybem_': 1,
#  'sridhewi': 1,
#  'andrmaulana': 1,
#  'cipeng_uchiha': 1,
#  'onnaatttt': 1,
#  'zey_photograf': 1,
#  'adh1sulistyo': 1,
#  'rifaipaul': 1,
#  'km_pamungkas': 1,
#  'ayyunurmala': 1,
#  'xann_erstyerz': 1,
#  'cleverjayen4ever': 1,
#  'imankurniawan_13': 1,
#  'nabillkar': 1,
#  'gungdwijaa': 1,
#  'adamfikih': 1,
#  'fahrizulkarnainp': 1,
#  'serlyaprlyn': 1,
#  'separuh_aku_dosa': 1,
#  'rifqyamboy': 1,
#  'monariaa_': 1,
#  'dendy70s': 1,
#  'ilman_alkhalifi': 1,
#  'im.semm': 1,
#  'thugfulss': 1,
#  'uliyah_n': 1,
#  'ahmadharis.official': 1,
#  'dafaaziznr': 1,
#  'btyhook13': 1,
#  'siiriyans': 1,
#  'ernieee6': 1,
#  'auliarchd': 1,
#  'rafilalgani': 1,
#  'bedillah1009': 1,
#  'janurwahyu.r': 1,
#  'ssbrh_': 1,
#  'cjustinrimbat': 1,
#  'audimanaf': 1,
#  'seloktav': 1,
#  'lestariilfy': 1,
#  '__rrasyaa': 1,
#  'gstiawn__': 1,
#  'xixael_': 1,
#  'thetifzy': 1,
#  'rickyaflah': 1,
#  'fitrianysitumorang': 1,
#  'hadi_prbya': 1,
#  'rxkiee': 1,
#  'mishbahuddin_muhammad': 1,
#  'rizalxpratama': 1,
#  'iampebriii_': 1,
#  'uchi_07_07': 1,
#  'rifalinthesky': 1,
#  'aarryynnnnnn': 1,
#  'abidin_z_m': 1,
#  'leeyaa_ya': 1,
#  'adrialbadri': 1,
#  'kissofbilla': 1,
#  'megayutw': 1,
#  'mirrzaah': 1,
#  'ed.fitngrow': 1,
#  'ariefpost': 1,
#  'mmjinans': 1,
#  'nesyaaavd': 1,
#  'ibnugraa': 1,
#  '_manusiarandommm': 1,
#  'lifeink.std': 1,
#  'isma_2o': 1,
#  'indahpekir': 1,
#  'riobagoesp': 1,
#  'riokristian27': 1,
#  'militarynewsinternational2': 1,
#  'padet_merayap': 1,
#  'imayusiagian': 1,
#  'murniatimd_': 1,
#  'yuriprice666': 1,
#  'mooontainnn12e': 1,
#  'elsaw_': 1,
#  'lxt51_z': 1,
#  'vannyrachma': 1,
#  'edoylagii': 1,
#  'dnlfrnsc_': 1,
#  'missnenooo': 1,
#  'hrydimly7': 1,
#  'aziezmaulana': 1,
#  'auliakhairunnisyah': 1,
#  'zaidanaap': 1,
#  'yourbabyellow': 1,
#  'yls_4490': 1,
#  'riifkaa_._': 1,
#  'syifa_rose': 1,
#  'windiningsih73': 1,
#  'dwalisme': 1,
#  'saiful_kasim': 1,
#  'dzaki.af': 1,
#  'irmadjuhari': 1,
#  '251579_ap': 1,
#  'kikinpwk': 1,
#  'winwarsire': 1,
#  'suryadanutirta': 1,
#  'dameriajtk': 1,
#  'mrs.hhh1': 1,
#  'cupcakecake1210': 1,
#  'puspitaanindasy': 1,
#  'tinkerdelll': 1,
#  'jesaya.barus': 1,
#  'maulanaafw': 1,
#  'dikyaade_': 1,
#  'ernando_magat': 1,
#  'imvocados': 1,
#  'ceng_achwannn': 1,
#  'gulfgulf_': 1,
#  'na.dafa': 1,
#  'tazzz9': 1,
#  'demosgeya': 1,
#  'iyan_manchunian': 1,
#  'husnatulnurjanah': 1,
#  'eputriyyyy': 1,
#  'erwindjuntak': 1,
#  'urfanramadhan': 1,
#  'sr_muthia': 1,
#  'fadhilaakamilaa': 1,
#  '_lovenbeyond': 1,
#  'msterate_': 1,
#  'narciissism0813': 1,
#  'glgpraw': 1,
#  'ira_ul': 1,
#  'meiimemeell_': 1,
#  'nazzyyy_lah': 1,
#  'deanetard_': 1,
#  'fariedsyafarie': 1,
#  'chickennoodlefood': 1,
#  'dianashilfa': 1,
#  'fikarr3': 1,
#  'jordyisml': 1,
#  'arfasptian': 1,
#  'ahmadrahandy': 1,
#  'flumadiddles': 1,
#  'as.tan.0': 1,
#  'mygrsw': 1,
#  'andilavon': 1,
#  'jesichasihombing': 1,
#  'alt_kesehatan_': 1,
#  'ntar_no': 1,
#  'binaninu': 1,
#  'canoverse': 1,
#  'vika.ftrn': 1,
#  'gandidos': 1,
#  'sopyan.doa_ibu': 1,
#  'sulaimanramdhani_41': 1,
#  'arifriandia': 1,
#  'ncsade': 1,
#  'yudha_poeradipraja': 1,
#  'weirdofeedo': 1,
#  'aldhftrie12': 1,
#  'husniiaja': 1,
#  'ibnu.aziizaan': 1,
#  'carlos_alfredy': 1,
#  '03_ziz': 1,
#  'husnimubarok_____': 1,
#  'avd8l': 1,
#  'gregorius.vino': 1,
#  'renvkhrsn': 1,
#  'ignasjordi': 1,
#  'elrinachen': 1,
#  'devimuktii': 1,
#  'meongg.gn': 1,
#  'ketopraktabrakrasa': 1,
#  'taipau7': 1,
#  'frezahapr': 1,
#  'mutyafahira': 1,
#  'resinta_alanisa': 1,
#  'wisnuu_legowo': 1,
#  'palembang_drone_pilot': 1,
#  'scar.face53': 1,
#  'raynabbymanyu': 1,
#  'bro.abizarrr': 1,
#  'endahpake.h': 1,
#  'ratusaluhah17': 1,
#  'nrlt_r': 1,
#  'marhaban2222': 1,
#  'bukan.ormas11111': 1,
#  'teukuzuma': 1,
#  'abdulkholik713': 1,
#  'libraoktvmtn': 1,
#  'bima_prabaswara_': 1,
#  'setocarel': 1,
#  'lalaveniaa': 1,
#  'kesshabidari': 1,
#  'shanyani18': 1,
#  'assumpta_resy': 1,
#  'dindadewani': 1,
#  'ayufra88': 1,
#  '_ahmadirham08': 1,
#  'sindu_ad': 1,
#  'alfaar0': 1,
#  'bro.vr_': 1,
#  'crzydumbass': 1,
#  'pnjdwthm': 1,
#  'qiptiaah': 1,
#  'slwdza_': 1,
#  'ridwansatyamusic': 1,
#  'lindaharrun': 1,
#  'ali_fiksi': 1,
#  'rahmannurhidayat': 1,
#  'miftah27_tah': 1,
#  'rahmi_mln': 1,
#  'ferdisntso': 1,
#  'sikodittt': 1,
#  'rahmadaf_': 1,
#  'bn__gxxtd': 1,
#  'kartiniii63': 1,
#  'arina.hd': 1,
#  'thariqsalmandaffa': 1,
#  'toniandrean_': 1,
#  'hi_leonando': 1,
#  'muhamadfarhanw': 1,
#  'yohanes.am': 1,
#  'r.ltfiiii': 1,
#  'ungieww': 1,
#  'd.nisssh': 1,
#  'din_da6839': 1,
#  'okeham_': 1,
#  'wnda_fp': 1,
#  'indahmishwari': 1,
#  'rshrdnn': 1,
#  'pay_joe13': 1,
#  'jib_elshirazy': 1,
#  'fupo.vvip': 1,
#  'azwinurr': 1,
#  'lutfhimaulana_': 1,
#  '_parningotan': 1,
#  'pitboy186_': 1,
#  'riantaraherprianda': 1,
#  'frmnnna_': 1,
#  'ossaraka': 1,
#  'tymorrzz': 1,
#  'imfikrii96_': 1,
#  'alooo13r': 1,
#  'pahrevis.revi': 1,
#  'massghii': 1,
#  'fudinsoib': 1,
#  'helokitting': 1,
#  'xxyz03': 1,
#  'ttosunmon12_': 1,
#  'niettzscheee': 1,
#  'sunbych': 1,
#  'deariannr': 1,
#  'inamurobbi': 1,
#  'septianuswilly': 1,
#  'pratiwip': 1,
#  'thedark_diary': 1,
#  'deden_abdul_rochman09': 1,
#  'ohjeerrr': 1,
#  'jogjatrip.co': 1,
#  'mochadz': 1,
#  'nusantara_quotes_updates': 1,
#  'dikiyudas': 1,
#  'nabilah_zayn': 1,
#  'ellgortt': 1,
#  'f.ef__': 1,
#  'jonatan.naibahoo': 1,
#  'momink_typ': 1,
#  'bintangfs1809': 1,
#  'fdlllhhrmn': 1,
#  'ippiy': 1,
#  'hhanaaa31': 1,
#  'febriyustian_': 1,
#  'zldjn06': 1,
#  'ukoli.natan16': 1,
#  'andre_nugie': 1,
#  'tobyath_': 1,
#  'reyhansagevti': 1,
#  '_aeruni': 1,
#  'dalgoncandy_': 1,
#  'adellee01': 1,
#  'jauw.jin.to': 1,
#  'mnd.feb': 1,
#  'yusamahardhika': 1,
#  'waffkml': 1,
#  's4kk0nno': 1,
#  'melypasaribu': 1,
#  'jeunghoon_____': 1,
#  'raynatan_utama': 1,
#  '_yulieeeee': 1,
#  'shabira_yusi': 1,
#  'janoyyyyyyy_': 1,
#  'alresramanda': 1,
#  'fznirsyd_': 1,
#  'rama.achda': 1,
#  'nestheaceae': 1,
#  'geriorag': 1,
#  'epuyyy.e': 1,
#  'stwrttt': 1,
#  'panjiesays': 1,
#  '_camatcha': 1,
#  'ollie_aulia': 1,
#  'nofadaaa': 1,
#  'rizalpnama': 1,
#  'elfa.np': 1,
#  'dwizulfikarnur': 1,
#  'haratama.felix': 1,
#  '_____ardiansa': 1,
#  'rizkiano_17': 1,
#  'reremimzy': 1,
#  'agakekanan': 1,
#  'gurikohanaki__': 1,
#  'andigaffarr_': 1,
#  'fauzia________': 1,
#  'barbiebena': 1,
#  'ryfrmnsyh_': 1,
#  'renofrdk': 1,
#  'revivan0va': 1,
#  'callme_linaaaaa': 1,
#  'zahriwardhana': 1,
#  'danielwungkar': 1,
#  'emmili_dwi': 1,
#  'berpax77': 1,
#  'komputerr452': 1,
#  '_pendul04': 1,
#  'aananjas__': 1,
#  '_illecebraarcanus': 1,
#  'imroncooo': 1,
#  'omezenn': 1,
#  'rlskgramabanl_': 1,
#  'krisnaprasetyaa': 1,
#  'lagimalesbgt_': 1,
#  'budi_ayamgeprek': 1,
#  'clystaam': 1,
#  'rendy.my': 1,
#  'wahabcharis': 1,
#  'm_ridho_06': 1,
#  'ani_lamada': 1,
#  'firm4nsyh': 1,
#  'aharism27': 1,
#  'adichdn': 1,
#  'garrygerardt': 1,
#  'zeinmarccc': 1,
#  'jjeessiiiee': 1,
#  'prido_putu39': 1,
#  'danangzh_': 1,
#  'richvando': 1,
#  'orangspesial_': 1,
#  'alibatasa_': 1,
#  'fachminaufal_': 1,
#  '09widiaulia': 1,
#  'febybrii': 1,
#  'gilngr__': 1,
#  'paulusbakung06_': 1,
#  'ikhwanudin.ajied': 1,
#  'rezzafiqrathulputra': 1,
#  'vienz90': 1,
#  'joduncanjo': 1,
#  'drian12elia': 1,
#  'rezzarenaldi': 1,
#  'anggara9o': 1,
#  'shanti_mryn': 1,
#  'fahdahrlna': 1,
#  'panjiakbar_95': 1,
#  'princeharrie12': 1,
#  'naachan32_': 1,
#  'utmkndyss': 1,
#  'adhi._.fatih': 1,
#  'faisalbayuajii_': 1,
#  'riskisafitriii': 1,
#  'julians_latuheru': 1,
#  'baappps_': 1,
#  'rolandaherta_': 1,
#  'farnationblush': 1,
#  'lessthantelu': 1,
#  'achsanyanuar': 1,
#  'aninditanurindra': 1,
#  'septiana.sha': 1,
#  'candyplastik': 1,
#  'ugasbanang__': 1,
#  'leilaroom': 1,
#  'rangerspink_': 1,
#  'amransatria_': 1,
#  'iniakunsellaaa': 1,
#  'mfisyamudin': 1,
#  'tfnrwn': 1,
#  'x.pradiptaa': 1,
#  'pjrmdhn': 1,
#  'ochbaaaaaa.k': 1,
#  'ach_nur_124': 1,
#  'yogapunyaig': 1,
#  'aldomuhammad___': 1,
#  'marisaichaaa': 1,
#  'faruru04': 1,
#  '__ejakjackie': 1,
#  'sanorganicfarming': 1,
#  'agathaadria_': 1,
#  'middleshiba': 1,
#  'sitinuraen16': 1,
#  'bartlett.pear_': 1,
#  'sourpineappwlee': 1,
#  'mhmmdfqhhidayat': 1,
#  'dikigandhasaputra': 1,
#  'mutyrxz': 1,
#  'khtyra_': 1,
#  'r0ng_seoochan': 1,
#  'wmfy_': 1,
#  'baemon_yg_7': 1,
#  'rhobytesti': 1,
#  'asfriinnn': 1,
#  'ordinarypublic_': 1,
#  'sitikusss': 1,
#  'luyor_al_hanif': 1,
#  'rifqhiww': 1,
#  'gih_._gih': 1,
#  'prasega__': 1,
#  'danuqrthaa': 1,
#  'masharam07': 1,
#  'malfindd': 1,
#  'dhardianti_': 1,
#  'pranata.ivan12': 1,
#  'yusrilandi__': 1,
#  'rayhan.kurnia16': 1,
#  'kaswidi_baong33': 1,
#  'wnddp__': 1,
#  'shansrahayu': 1,
#  'arnodhani': 1,
#  'cutienadey': 1,
#  'indratnosigit': 1,
#  'rgdiwan1010': 1,
#  'juanwil_': 1,
#  'vitaliatm': 1,
#  'volkgvg': 1,
#  'firdiatriana': 1,
#  'aapprriiaannii._': 1,
#  'j_rm1310': 1,
#  'melaniedara_32': 1,
#  'fadhliset': 1,
#  'katateknik': 1,
#  'unknownrowrrr': 1,
#  'nhararaaa': 1,
#  'noviasyr_': 1,
#  'yusufelgaja1': 1,
#  'sepedaan_di_sarajevo': 1,
#  '_ntasyaa26': 1,
#  'masmokot': 1,
#  'dffaaprillio': 1,
#  'muhammad_dian17': 1,
#  'fajar_dirham': 1,
#  'aqwamnuqrh': 1,
#  'chidhn14': 1,
#  'lahsenoritam': 1,
#  'mardiana2559': 1,
#  'vinnapandansari': 1,
#  'adityarhmn_374': 1,
#  '_ferrdis': 1,
#  'jaywillmmm': 1,
#  'caca.4010': 1,
#  'nadbellapr_': 1,
#  'safitrivita': 1,
#  'fajarnugg_': 1,
#  'daniernawati_mario_s': 1,
#  'giozrx': 1,
#  'jjausaa': 1,
#  'rhmaaapiww': 1,
#  'amandaa.hartantoo': 1,
#  'rizkysyafit': 1,
#  'hi.aniianii': 1,
#  'anisyafdll_': 1,
#  'nahebrahm_': 1,
#  'martakenzero_': 1,
#  'nahar_abdur': 1,
#  'lianggra_': 1,
#  '___________21ag12new': 1,
#  'melistadita': 1,
#  'alcautsar': 1,
#  'ramadhvni': 1,
#  'dt8.rice': 1,
#  'aditpriana_': 1,
#  'achioshop86': 1,
#  'gangsaralahyo_': 1,
#  'nuw.nuw': 1,
#  'farizaarif07': 1,
#  ...}

# %%
# like sum and sort by value descending
like_sum = data.groupby('username')['like_count'].sum().to_dict()
like_sum = dict(sorted(like_sum.items(), key=lambda item: item[1], reverse=True))
like_sum
# Out:
# {'junaydfloyd': 9825,
#  'tikawngso': 6891,
#  'difi_raw': 5275,
#  'praharja.bangga': 4366,
#  'jasaolahdata.co': 2719,
#  'jessy_humirtap': 2415,
#  'veren_hayon': 2351,
#  'bataramanik': 2088,
#  'bagusradhitya': 2023,
#  'jasapindahanbali': 1587,
#  'ikanterikiyowo': 1481,
#  'dimsdwii': 1207,
#  'thoniluthfi': 1033,
#  'fhmilham': 966,
#  'karunasankara01': 944,
#  'heldums': 917,
#  'dimassaktinugraha': 898,
#  'bandung.gigs': 883,
#  'tgk_ricky.a': 883,
#  'ry.iyyd': 854,
#  'nvioletas': 833,
#  'rahmadsejati': 757,
#  'mahendraprks': 755,
#  'wnda_fp': 746,
#  'rezabahroem': 693,
#  'airfaanin': 677,
#  '_rinadh': 662,
#  'xreal_2202': 634,
#  'adivnm': 633,
#  'netfllixx_murah': 604,
#  'youngdla_': 590,
#  'geriorag': 561,
#  'muhammad_hezra': 519,
#  'arifback11': 515,
#  'fzi.ibongg_': 506,
#  'yehezkielde12': 481,
#  'rimahanidar': 456,
#  'wantose_': 455,
#  'marindasari': 449,
#  'susiloturjoyo': 447,
#  'dirisendirri': 441,
#  'ardianirwan__': 434,
#  'septian.purnama': 424,
#  'yeti_nurmayati': 419,
#  'melaniera12': 413,
#  'fikriadhiez': 411,
#  'hengkiheng98': 410,
#  'indie_24jam': 397,
#  'virdhaarguna': 385,
#  'time_traitor': 384,
#  'auliaarezki': 336,
#  'kikeydira': 323,
#  'fitiafilia': 295,
#  'miniaturmotor_indonesia': 291,
#  'dfey77': 284,
#  'budiwarso': 281,
#  'ulye_zriyani': 273,
#  'hatta_elmakoalloe': 257,
#  'hideyuki.id': 257,
#  'andihidayat92': 256,
#  'xtrememerch': 248,
#  'aienditfc': 237,
#  'arrmyy17_': 237,
#  'chandra182121': 231,
#  'msolihinnn': 220,
#  'ace.noer_': 214,
#  'riokurniawan_id': 198,
#  'lorenzoabim': 192,
#  'indragnwn330': 178,
#  'havesasad': 174,
#  'ujangsulaimann': 174,
#  'mhmdosmm': 157,
#  'imrongiant20': 156,
#  'a.kurniawan16__': 154,
#  'frsardan_': 149,
#  'cipeng_uchiha': 147,
#  'vin_tjoa': 139,
#  'bokuwachoppertonytonychoper': 132,
#  'syafiraoctafiani': 130,
#  'luthfiemuamar': 127,
#  'xixael_': 122,
#  'gungdwijaa': 117,
#  'sidingin112': 115,
#  'iwazza.kun': 111,
#  'vickarzz': 107,
#  'muh.syahruull': 105,
#  'rdhrmdhn': 104,
#  'pujisawitri': 97,
#  'trioatma': 97,
#  'wahyu_rajin_menabung_': 97,
#  'noyaryan': 92,
#  'ekybong365': 91,
#  'rico_ap09': 86,
#  'husnahardiana': 85,
#  'syrifachmad': 85,
#  'rndyahong': 84,
#  'syah_ram': 81,
#  'andiiprt': 77,
#  'rubbyrhoma': 76,
#  'tika_ry': 76,
#  'gadispulau__': 75,
#  'afrizaljijay': 73,
#  'adietakbar_': 72,
#  'puji_widyanti': 72,
#  'taufikk.w': 72,
#  'bagusfirmansyahputra': 69,
#  'lgaa_99': 69,
#  'masa_umum': 69,
#  'dewi_pebrilia': 67,
#  'bimaananta': 66,
#  'reshajr': 66,
#  'sz_szoboslai': 65,
#  'achmdherry': 63,
#  'deeroo.co': 63,
#  'bungbess': 60,
#  'dndung_22': 59,
#  'doraeyon_': 58,
#  'permanailham84': 57,
#  'floflorav': 56,
#  'gbriieel': 56,
#  'wisnu7331': 54,
#  'empathmommy': 53,
#  'mwerrie': 53,
#  'michaelnadeak_id': 51,
#  'fauzan_putra_b': 50,
#  'nolanawls': 50,
#  'ridwanthoriq': 50,
#  'andrejosafat_': 49,
#  'hanafi__18': 49,
#  'hermans_36': 49,
#  'rendy.my': 49,
#  'tukanglistrikbelajaran': 48,
#  'bisaaja52': 45,
#  'hammmmmmmag09': 44,
#  'baladraf_': 43,
#  'jaytiem': 40,
#  'alienjack2025': 39,
#  'indahpontoh__': 37,
#  'priska_simanungkalit': 37,
#  'gigestha______': 36,
#  'habibsyadzily': 36,
#  'syakurhilmy_': 36,
#  'inimaszen': 35,
#  'shofiyahabidaheshal': 35,
#  'adrianulza': 34,
#  'nicomartens999': 33,
#  'budi.iwan.188': 32,
#  'hery_wibowoo': 32,
#  'husnulnn': 32,
#  'idakristagram': 32,
#  'abelvanrnn_': 30,
#  'ale_alikhsan': 30,
#  'azzy_09': 30,
#  'tyfanew_21': 30,
#  'bjoeyyyy': 29,
#  'plutonioneon': 29,
#  'ulfahtacii': 29,
#  'arif_rustian': 28,
#  'herdajl': 28,
#  'natalieputri63': 28,
#  'bono_0170': 27,
#  'docturnal_': 27,
#  'ura_miayam': 27,
#  '__rrasyaa': 26,
#  'andra_metavers': 26,
#  'bayuhastomo111': 26,
#  'brooklyn_cheesee': 26,
#  'latheris33': 26,
#  'annas_so': 25,
#  'damara18_': 25,
#  'imankurniawan_13': 23,
#  'johanlc': 23,
#  'k.falaaq': 23,
#  'muhammadarisaputro': 23,
#  'nabilamirulhaq': 23,
#  'yoga.rstln94': 23,
#  'dedyirawan1989': 22,
#  'tatisulaeman': 22,
#  'zain_sulaiman_ramadhan1725': 22,
#  'redy_marvino': 21,
#  'rzlrust': 21,
#  'aditya_fernnd4': 20,
#  'danyagmar_s': 20,
#  'ianone__': 20,
#  'lutfi.upay28': 20,
#  'nksavio': 20,
#  'pu666uh': 20,
#  'ardiiiii_p': 19,
#  'yupipinky18': 19,
#  'hanamaryam__': 18,
#  'nadbilqis': 18,
#  'paracetamol289': 18,
#  'aziz_fatchur': 17,
#  'ekayunia_prawira': 17,
#  'herychrist789': 17,
#  'smart.m4t': 17,
#  'warungkl2': 17,
#  'ademutiara_h': 16,
#  'bennydsp': 16,
#  'h_ssnu': 16,
#  'indahpekir': 16,
#  'grestyan': 15,
#  'jeunghoon_____': 15,
#  'redykadika': 15,
#  'restyfawzia': 15,
#  'slatjenny': 15,
#  'uwiencak': 15,
#  'kygovel': 14,
#  'radit.kums': 14,
#  'robsonlbs_': 14,
#  'yunoo_29': 14,
#  'bombaclipp': 13,
#  'fanzaayn': 13,
#  'npc.villain5': 13,
#  'oxrfndtxo': 13,
#  'siabay': 13,
#  'vira.amb_': 13,
#  'wvictorym': 13,
#  'alfarisi_id': 12,
#  'alkmardz': 12,
#  'fadlanmuhammad': 12,
#  'tinobkt.n': 12,
#  'ulfa_khaerunnisa': 12,
#  'dans_siltorxviii': 11,
#  'moses171094': 11,
#  'neurball': 11,
#  'andreankusumah': 10,
#  'armisoemardi': 10,
#  'downhill_jaksquad': 10,
#  'husnatulnurjanah': 10,
#  'jaka_huna25': 10,
#  'krnwaan__': 10,
#  'lagimalesbgt_': 10,
#  'lalunatyana': 10,
#  'maxluwis': 10,
#  'ahmadmubarok221': 9,
#  'azizputraaaaa': 9,
#  'bang.dondo97': 9,
#  'cupakadiwa': 9,
#  'edisaja1983': 9,
#  'fida.degel': 9,
#  'gowther06': 9,
#  'iamrafiramzi18': 9,
#  'mujjex.128': 9,
#  'traw__young': 9,
#  'txkyodope': 9,
#  'yohanes.am': 9,
#  'zackspearce': 9,
#  'agung_rudes': 8,
#  'asepgunawan7194': 8,
#  'berchandya72': 8,
#  'bev.bert': 8,
#  'bonnskuyyy': 8,
#  'dedi_bydindo': 8,
#  'gendishanum': 8,
#  'iqbalrifqi777': 8,
#  'irpan_syabana': 8,
#  'naeliatitik': 8,
#  'nini.indah': 8,
#  'pagarajiwanaufal': 8,
#  'ran_albertserva': 8,
#  'ryanjunians': 8,
#  'satrio3nurcahya': 8,
#  'tikodes': 8,
#  'vica_putri': 8,
#  'wafdhu': 8,
#  'yulia_wijayanti_uul': 8,
#  '_ridsu': 7,
#  'andijerni': 7,
#  'chalhisyam': 7,
#  'dimasputraadjie': 7,
#  'dleanferdiansyah': 7,
#  'dwanharun': 7,
#  'eyhiiaksel': 7,
#  'firmannsptra': 7,
#  'fznirsyd_': 7,
#  'imammtech': 7,
#  'irtizaqdalahmas': 7,
#  'iwaktongkoliwaklele': 7,
#  'juli.4nto': 7,
#  'nawaraja99': 7,
#  'ravenzzyy': 7,
#  'rayyaahasan': 7,
#  'rizky_wy': 7,
#  'ryowesleyy': 7,
#  'serverduawayy': 7,
#  'sukarna_natawira': 7,
#  'tinkerdelll': 7,
#  'viebgr._': 7,
#  'zulmiulfa': 7,
#  'andi.dm27': 6,
#  'dwiwahyuni464': 6,
#  'fzy.ahmad': 6,
#  'galang45xx': 6,
#  'halshalz': 6,
#  'ikeromawati': 6,
#  'intanpuspitasari.sr': 6,
#  'karyono6879': 6,
#  'lia_so19': 6,
#  'm.iqbalzaidan': 6,
#  'masmas_youtube': 6,
#  'mecks9_': 6,
#  'mohammadariefal': 6,
#  'mooontainnn12e': 6,
#  'muhammadsuhudfadill': 6,
#  'narciissism0813': 6,
#  'nickonino': 6,
#  'pradiptayogaa': 6,
#  'rendynadyan': 6,
#  'revivan0va': 6,
#  'rini.az': 6,
#  'rizky_jisantt': 6,
#  'sosialpolitika': 6,
#  'syams1991': 6,
#  '_bayurizkiawan': 5,
#  'adhibonzai': 5,
#  'amirafazam_': 5,
#  'andigaffarr_': 5,
#  'aning_27.2': 5,
#  'asannopik199': 5,
#  'ayah_sean': 5,
#  'ayuuandriani_': 5,
#  'fahlevifahmi': 5,
#  'foraes4': 5,
#  'fpranss_': 5,
#  'hafidh.dwi.w': 5,
#  'hamzahmaulaana': 5,
#  'hendrowijoyo123': 5,
#  'iandarwis': 5,
#  'jorbae_88': 5,
#  'jpd.polo': 5,
#  'khoirulfl': 5,
#  'kongco70': 5,
#  'm.ridwan051092': 5,
#  'mctfq': 5,
#  'megayutw': 5,
#  'naddyaasya': 5,
#  'nanawahyudin145': 5,
#  'nurulfyu': 5,
#  'oensragil.id': 5,
#  'p_al25': 5,
#  'pur_nomothefu': 5,
#  'reviewmajo': 5,
#  'tatia_hst': 5,
#  'tianblacknwhite2': 5,
#  'vlntkslvna': 5,
#  'vonymelian': 5,
#  'zidnymubarokc': 5,
#  '5onn4': 4,
#  'adhi._.fatih': 4,
#  'alyssabchairati': 4,
#  'apanjimny04': 4,
#  'ardyerde': 4,
#  'arthursien': 4,
#  'azizah.hanum_lpw': 4,
#  'chikaangelica_': 4,
#  'davin_muhammad_arsyad': 4,
#  'ev.lukito': 4,
#  'eza_hrsmann': 4,
#  'fdlllhhrmn': 4,
#  'frstdikk': 4,
#  'gilang_militia': 4,
#  'gumelarrmni': 4,
#  'helooriaaa': 4,
#  'herzon.z': 4,
#  'ihsyahriakbar': 4,
#  'ilhamelsoth': 4,
#  'imam_al_safii': 4,
#  'ir_wily': 4,
#  'irha36209': 4,
#  'jvshua.bnahor': 4,
#  'kaylaaa5476': 4,
#  'kyky_5_': 4,
#  'madiku': 4,
#  'marioaian': 4,
#  'marllinaekaa': 4,
#  'maulanaafw': 4,
#  'mirzawijaya_': 4,
#  'mister.zaldi': 4,
#  'mrzkzzzzz': 4,
#  'nadhisalsaa': 4,
#  'rnuzulla': 4,
#  'saidatul_muhimmah': 4,
#  'salmainstbrz': 4,
#  'sidkitenoth666': 4,
#  'subhan_ubam': 4,
#  'sulaimanramdhani_41': 4,
#  'sultan_sudirman17': 4,
#  'tbend79': 4,
#  'tehespanas': 4,
#  'tokoh_fiksi_buatan_yaduhi': 4,
#  'triaspyrenia_iyaz': 4,
#  'tryanggara23': 4,
#  'uliyah_n': 4,
#  'wahyu.stevano': 4,
#  'yongki_bank': 4,
#  'yuanntea': 4,
#  'yuliaew': 4,
#  '23isaaac': 3,
#  '__lyhy': 3,
#  '_hastyo1996_': 3,
#  'abesst_543': 3,
#  'adhinewgraha': 3,
#  'adoraribka': 3,
#  'ahmdramdhani96': 3,
#  'akmals.10': 3,
#  'alamsyahsubakri': 3,
#  'alibatasa_': 3,
#  'amy_jakarta': 3,
#  'anggianr': 3,
#  'annidaunnatiqulya': 3,
#  'arcahyanti_': 3,
#  'arcasgoodstuff': 3,
#  'ardii_lukman': 3,
#  'ardilahpuspa': 3,
#  'arianidina972': 3,
#  'arummmrhy': 3,
#  'asma_hsna13': 3,
#  'azrullkhafizin': 3,
#  'baransaldi6': 3,
#  'bgs.pramudita': 3,
#  'bgsabdrrhmn_29': 3,
#  'bli_bagus777': 3,
#  'candra_septiano': 3,
#  'catherine_vanbora': 3,
#  'cleverjayen4ever': 3,
#  'dduudduung': 3,
#  'deriwilandi': 3,
#  'donnyo1105': 3,
#  'dzikrisyafaat18': 3,
#  'elanofiqri': 3,
#  'freddyjuan27': 3,
#  'gendistawa99': 3,
#  'geo.kyboobs': 3,
#  'gungg_a97': 3,
#  'haidirheliamasa': 3,
#  'hariez_jhuna': 3,
#  'hr___21': 3,
#  'husnii_mubarok': 3,
#  'iinsoetedjo': 3,
#  'imanalig_': 3,
#  'imroncooo': 3,
#  'intan_rs_': 3,
#  'iqbalmuntahaaa': 3,
#  'itsmeurjoo': 3,
#  'j_rm1310': 3,
#  'jualchatgpt.canva': 3,
#  'krisnaprasetyaa': 3,
#  'laekjun.90': 3,
#  'lalaamala': 3,
#  'leefuthu_123': 3,
#  'lenneth_valy': 3,
#  'luckytwoacc_': 3,
#  'm_ridho_06': 3,
#  'mardiana2559': 3,
#  'marimogstn': 3,
#  'mazid_art': 3,
#  'megadirga': 3,
#  'mhd__fnda': 3,
#  'miftah27_tah': 3,
#  'mogskisme': 3,
#  'mohikhsani': 3,
#  'muji_pangrango': 3,
#  'mutiarakardiman': 3,
#  'nasverite': 3,
#  'nidaarrm': 3,
#  'novita.asri21': 3,
#  'nurlistaarifah_': 3,
#  'oska.den': 3,
#  'panji_justice7': 3,
#  'putriratiwi': 3,
#  'rachmawatieermaa': 3,
#  'rahma_adjikinasih': 3,
#  'rahman_kurnia01': 3,
#  'randy.qyuha': 3,
#  'ranisrina': 3,
#  'rendisuhadi_': 3,
#  'retoucherjakarta': 3,
#  'reyhansagevti': 3,
#  'rgdiwan1010': 3,
#  'ricominio': 3,
#  'ridwan.asharii': 3,
#  'sofyan__wijaya': 3,
#  'suciasaririzki': 3,
#  'syamsia_satra11': 3,
#  'teguhtio': 3,
#  'tommyna70': 3,
#  'unaaaa000_': 3,
#  'wahyou.nim': 3,
#  'whoisgaling': 3,
#  'wira_shaka': 3,
#  'xy_lsn08': 3,
#  'yanpurnanto': 3,
#  'yantizieyah': 3,
#  'yashfadhli': 3,
#  'younee7_': 3,
#  'yuli03_': 3,
#  'yy_____hdn': 3,
#  'zackyzulfikar__': 3,
#  'zlfdln': 3,
#  '19hendrasetiawan33': 2,
#  '28.nemesis': 2,
#  '4jisaputr4': 2,
#  '_camatcha': 2,
#  '_endusia_': 2,
#  '_guduncle_': 2,
#  '_isan_18': 2,
#  'aagymkrd_': 2,
#  'aammansor': 2,
#  'adprince_10': 2,
#  'agungkurniawan481': 2,
#  'ahmadrifai0459': 2,
#  'akbar.syahdaan': 2,
#  'akbararfandi': 2,
#  'alaskankingcrabb': 2,
#  'alinuralghozali': 2,
#  'amiril_mu': 2,
#  'andirudi.13': 2,
#  'andreasseptiaan': 2,
#  'andriianr_': 2,
#  'andy_fahlevi': 2,
#  'angga.adrs': 2,
#  'anggarbaskoro': 2,
#  'ansyaharaya': 2,
#  'ar.io793': 2,
#  'ardina_rasha_': 2,
#  'ardinadityaa': 2,
#  'arenagadget__': 2,
#  'ariefdc14': 2,
#  'arkanasis_': 2,
#  'arvanpradiansyah': 2,
#  'aryosamuelhartanto': 2,
#  'atmaja_oka28': 2,
#  'awahyudiiii': 2,
#  'awaruzin_24': 2,
#  'ayu.widi.a': 2,
#  'bagastia_hekas': 2,
#  'bchtakos': 2,
#  'berry.bidar': 2,
#  'bro.vr_': 2,
#  'bts__ilovelies': 2,
#  'budi_albukhari': 2,
#  'bung.isal': 2,
#  'bungalawang22': 2,
#  'carissaaiss': 2,
#  'chezmuth': 2,
#  'cjustinrimbat': 2,
#  'cupcakecake1210': 2,
#  'dainilham_w': 2,
#  'daniel.marda47': 2,
#  'davidtadja': 2,
#  'deni.fitriyanto': 2,
#  'dessyamaya': 2,
#  'diapasko': 2,
#  'dimaswongapik123': 2,
#  'dinan5871': 2,
#  'dioo.dptraa': 2,
#  'dntorus': 2,
#  'dryan11_': 2,
#  'ds_soerjana11': 2,
#  'edoylagii': 2,
#  'edzeki': 2,
#  'ekhyalfatih': 2,
#  'emaskoko168': 2,
#  'enia130901': 2,
#  'eputriyyyy': 2,
#  'fadli.irhamdani': 2,
#  'fahria.zxcc': 2,
#  'faqihmhsiy': 2,
#  'faqihramdhaani': 2,
#  'fariedsyafarie': 2,
#  'fbradzkdyraaa': 2,
#  'ferlyferial': 2,
#  'fiqih_nr': 2,
#  'firdaus_93__': 2,
#  'firnamaulia': 2,
#  'fk25._': 2,
#  'ftimtuzhda': 2,
#  'fupo.vvip': 2,
#  'galihparamandana': 2,
#  'ganihgandoel': 2,
#  'gardaarda': 2,
#  'gemgirl3155': 2,
#  'gevansamahari': 2,
#  'giopratamaaa': 2,
#  'grahadiawan': 2,
#  'gudsat999': 2,
#  'h.ruzbihanbaqliee_': 2,
#  'halisamaulidia': 2,
#  'halooucii': 2,
#  'hamam_m85': 2,
#  'hanii.imut': 2,
#  'hanz_1983': 2,
#  'harucil.rahmadani22': 2,
#  'hendyhedyawan': 2,
#  'herii_kurniawan': 2,
#  'husnamadiri': 2,
#  'ifta_ita': 2,
#  'ilham_aged': 2,
#  'ilhammaulya': 2,
#  'imayusiagian': 2,
#  'imvocados': 2,
#  'indowijigrosir': 2,
#  'iqbaal144': 2,
#  'irkham.mustafa': 2,
#  'irmaningsih13': 2,
#  'ivy_netasya': 2,
#  'jagorisol': 2,
#  'jangkimuhammad': 2,
#  'jann.ah4464': 2,
#  'jeiinar': 2,
#  'jizharfeb': 2,
#  'joeragan_1333_nu': 2,
#  'johansihotang': 2,
#  'jokiinaja_skripsimu': 2,
#  'jonijn_': 2,
#  'k.wndyy': 2,
#  'kelilit.talijemuran': 2,
#  'kentakyw': 2,
#  'lampubumi': 2,
#  'ledyanisipahutarlppim': 2,
#  'lilysuzernita': 2,
#  'lindaharrun': 2,
#  'luckysuprayogi': 2,
#  'luks_gis': 2,
#  'marjudin_arga': 2,
#  'masadsdq': 2,
#  'maz_aris_oe': 2,
#  'melianamerissa': 2,
#  'mfisyamudin': 2,
#  'mgg73580': 2,
#  'mika.mikuku': 2,
#  'milla_food_and_fashion': 2,
#  'monaapriliaw': 2,
#  'motherfucker_606': 2,
#  'mpokrohmeh': 2,
#  'msterate_': 2,
#  'mufidf_alf': 2,
#  'muhammadfauzi9501': 2,
#  'mylovelypinkkeu': 2,
#  'myoilsist': 2,
#  'nadyaratna24': 2,
#  'nbilaazzza': 2,
#  'nenesssss_________': 2,
#  'niaskbmm': 2,
#  'niettzscheee': 2,
#  'nikomodjo': 2,
#  'nn.themidnightsun': 2,
#  'nugieramadhan97': 2,
#  'nuun.1988': 2,
#  'octhavvia6': 2,
#  'ohjeerrr': 2,
#  'oktasfn': 2,
#  'olie_august85': 2,
#  'opickk_inst': 2,
#  'opii_26': 2,
#  'paulineciuputri': 2,
#  'pontianak.folk': 2,
#  'pra.tamaan': 2,
#  'prido_putu39': 2,
#  'rafly.wibowo240101': 2,
#  'rahayuindah_': 2,
#  'rahmafadilah18': 2,
#  'rakhmat_busthomi': 2,
#  'ramaliaadp': 2,
#  'ramlansilalahi': 2,
#  'randuuuuuuuu': 2,
#  'randydave_': 2,
#  'ranggaprimadasa': 2,
#  'rauliheriana': 2,
#  'rendyismail1': 2,
#  'rham.md': 2,
#  'richvando': 2,
#  'ridwan_tanu': 2,
#  'riifkaa_._': 2,
#  'riki_adi_siswwnto': 2,
#  'ririsgalerifotografi': 2,
#  'rival.di2235': 2,
#  'rizalbojesz': 2,
#  'rizkifajari': 2,
#  'rkrahmansyahr': 2,
#  'romi_nuril': 2,
#  'rosyalinomada': 2,
#  'rsm.hrnd': 2,
#  'sarkasinwakanda': 2,
#  'shanti_mryn': 2,
#  'sholikinlikin291': 2,
#  'siddik_hs': 2,
#  'sideofst_': 2,
#  'sidiqrmd': 2,
#  'siiriyans': 2,
#  'smokynight_': 2,
#  'solehudin_00': 2,
#  'sonnydharmawan1707': 2,
#  'sopyan.aam': 2,
#  'sukabumimediautama': 2,
#  'sutrianaawjy__________': 2,
#  'swedishfishburgers7': 2,
#  'syahputra17_': 2,
#  'taan_009': 2,
#  'taklukandunia': 2,
#  'talithaagnes20': 2,
#  'tesseract_dimensions': 2,
#  'tetapyosua': 2,
#  'thea_dyah': 2,
#  'tomi.yk': 2,
#  'troyaedvn_': 2,
#  'tuantemu': 2,
#  'urredcherry': 2,
#  'valdifal': 2,
#  'vinsi_dharma87': 2,
#  'wie.46': 2,
#  'wied_2702': 2,
#  'wilptr_6': 2,
#  'yanuarmuslih': 2,
#  'yogatamawk': 2,
#  'yohannes_sibagariang': 2,
#  'yoursbagslovers': 2,
#  'yuan_farabey': 2,
#  'yulia77mustika': 2,
#  'yuliavira': 2,
#  'yunuzrismawan': 2,
#  'zallxnxn___': 2,
#  'zaynidrus_': 2,
#  '03_ziz': 1,
#  '08selvie': 1,
#  '1090mhz___': 1,
#  '11cvancv': 1,
#  '14frr': 1,
#  '5081_rin': 1,
#  '7dar168': 1,
#  '_____imf9': 1,
#  '_____sassss': 1,
#  '__umi.adibah__': 1,
#  '_abibbih': 1,
#  '_aboed_': 1,
#  '_asyanura_': 1,
#  '_capberuangasli': 1,
#  '_emamysrhachmad': 1,
#  '_fajarsaputra__': 1,
#  '_latieffff': 1,
#  '_pendul04': 1,
#  '_riezaast': 1,
#  '_sucinuraini1': 1,
#  '_ujik13': 1,
#  '_vny.then69': 1,
#  '_zamzamiali': 1,
#  'a.bukhory_3': 1,
#  'a5hfd': 1,
#  'a_man_and_his_dream': 1,
#  'aapnf_30': 1,
#  'aapprriiaannii._': 1,
#  'aazizahnf_': 1,
#  'abaadnantea': 1,
#  'abdlrzkce': 1,
#  'abduliqram31': 1,
#  'abdulkholik713': 1,
#  'abdulrzk24_': 1,
#  'abduroo7': 1,
#  'abe58215': 1,
#  'abryan_story': 1,
#  'abu_ghazwan': 1,
#  'achioshop86': 1,
#  'achmad.rehansyah.1': 1,
#  'achmaddaerobi': 1,
#  'achmads212': 1,
#  'achsanyanuar': 1,
#  'adam_pratamaaa01': 1,
#  'adamfikih': 1,
#  'adamwsn6': 1,
#  'addhit_ya': 1,
#  'adellee01': 1,
#  'adendesss': 1,
#  'adh1sulistyo': 1,
#  'adib.abdllh': 1,
#  'adichdn': 1,
#  'adindaape_': 1,
#  'adis.only85': 1,
#  'adrian.nurr__': 1,
#  'affandyabdul': 1,
#  'aflahj': 1,
#  'africanadi_': 1,
#  'afrijal.jamal': 1,
#  'agathaadria_': 1,
#  'age_sn': 1,
#  'agungharimu': 1,
#  'agungyuliyantonugroho': 1,
#  'agusgimnastiar_': 1,
#  'agusmudidani': 1,
#  'ahmat_rojalih': 1,
#  'aindra.ir': 1,
#  'aisavah2025': 1,
#  'ajisantososan21': 1,
#  'ajuanpram': 1,
#  'akang_cutter': 1,
#  'akizztafarie': 1,
#  'albertadriaan': 1,
#  'albertusfs': 1,
#  'albizio19_': 1,
#  'aldimac': 1,
#  'aldyanometer': 1,
#  'alee_mhmmd': 1,
#  'alexander_radityaa': 1,
#  'alfianadew': 1,
#  'alfino846': 1,
#  'ali_fiksi': 1,
#  'alineandari': 1,
#  'alleta_stfn': 1,
#  'alresramanda': 1,
#  'altiopras': 1,
#  'alyssairvn_': 1,
#  'amaliarstn': 1,
#  'amandaazly': 1,
#  'ambolajamirna': 1,
#  'amelia.09090': 1,
#  'aminudln': 1,
#  'anagirl20101993': 1,
#  'anang_maulanakh': 1,
#  'andi_m_awal': 1,
#  'andianq': 1,
#  'andikabc': 1,
#  'andikahonda18': 1,
#  'andiniclaudita': 1,
#  'andreazadhi': 1,
#  'andryanlesmanaa_': 1,
#  'andy_aszafran': 1,
#  'anggerm': 1,
#  'anggiagrr': 1,
#  'anggiatpsrb': 1,
#  'aninditanurindra': 1,
#  'anisaoctafiani': 1,
#  'anitaoktaviasitumorangreal': 1,
#  'anna_ch3016': 1,
#  'anna_rasyabilla': 1,
#  'anncashies': 1,
#  'annie_depeurple': 1,
#  'anshorfauzan': 1,
#  'antarestar_outdoor': 1,
#  'antozahly': 1,
#  'apoy._.03': 1,
#  'aqimsyml': 1,
#  'araahya_shopbdl': 1,
#  'arayyl': 1,
#  'ardipantiarso': 1,
#  'arfanlee': 1,
#  'arfasptian': 1,
#  'arfrhmd_': 1,
#  'ari.marli': 1,
#  'ariefa_khaira_azmi_': 1,
#  'ariefsalim23': 1,
#  'ariesboriz': 1,
#  'arif_rahman_hakim0': 1,
#  'arifriandia': 1,
#  'arilalexandria': 1,
#  'arimauu': 1,
#  'arisdwi2124': 1,
#  'arka.mhzz': 1,
#  'armando_hendrawan': 1,
#  'arnodhani': 1,
#  'arrnii_tii': 1,
#  'arsisella_': 1,
#  'arsyadwiyanto': 1,
#  'arul_777': 1,
#  'arurenaren': 1,
#  'arvays__': 1,
#  'ary_indengi': 1,
#  'ascipto11': 1,
#  'ashurin.1010': 1,
#  'assalamualaikum_burger': 1,
#  'astriaprn': 1,
#  'astriwika': 1,
#  'atiekkurniaa': 1,
#  'atunglav': 1,
#  'atwal_yanuar13': 1,
#  'auliawahyuni': 1,
#  'auliya_bhst': 1,
#  'aurelia_dd': 1,
#  'avocado0941': 1,
#  'axcels07': 1,
#  'ayangkeidi': 1,
#  'ayankyenky': 1,
#  'ayansuputra_': 1,
#  'azhionme': 1,
#  'azissamruu': 1,
#  'azizah_arf': 1,
#  'azizjayapartnersip2015': 1,
#  'aziznrfdllh__': 1,
#  'azka_dhanurendra': 1,
#  'azkharyaa': 1,
#  'b4dut.t.t': 1,
#  'babyviooo': 1,
#  'baelah.uus': 1,
#  'bagus_dwi_m': 1,
#  'bagusbig_': 1,
#  'bagusdwiwibowo': 1,
#  'bananatub': 1,
#  'bang_amad1901': 1,
#  'bang_qwoy': 1,
#  'bangmukandi': 1,
#  'bankgrez': 1,
#  'baratastum': 1,
#  'barbiebena': 1,
#  'barephotoshoot': 1,
#  'barlicing': 1,
#  'barmagribpsan': 1,
#  'basyaralhakimmm': 1,
#  'batosai890': 1,
#  'bayu_aji_dwiputra': 1,
#  'bell.argo': 1,
#  'bendhutabarat': 1,
#  'benoodian': 1,
#  'bergerakfor': 1,
#  'bernadethaadriana': 1,
#  'berpax77': 1,
#  'beyourap': 1,
#  'bintangastari320': 1,
#  'bintangfs1809': 1,
#  'boloku___': 1,
#  'bonifasius_bima': 1,
#  'bow21wow': 1,
#  'budhy.dhi': 1,
#  'budy_thea': 1,
#  'bukan.ormas11111': 1,
#  'bumibuletbundar': 1,
#  'bunnymoonlights': 1,
#  'c.rob.ad.wi': 1,
#  'candyplastik': 1,
#  'capitulate_': 1,
#  'cepyanugrahs90': 1,
#  'chairuldamalio': 1,
#  'cheryz_anissa': 1,
#  'chickennoodlefood': 1,
#  'chilmyleg': 1,
#  'chindi1727': 1,
#  'chintiaaa30': 1,
#  'chllprk': 1,
#  'choi_khonsa': 1,
#  'choirull_huda': 1,
#  'cintamldaaa': 1,
#  'cintyashofinabila': 1,
#  'claruzalejandro': 1,
#  'cloud._andblue': 1,
#  'co_tebe': 1,
#  'cutienadey': 1,
#  'cutrisanurzinahfonna': 1,
#  'd3wa_saja': 1,
#  'daarin_07': 1,
#  'dafaaziznr': 1,
#  'danangzh_': 1,
#  'danielkipow': 1,
#  'danilpebri': 1,
#  'daniramasyah': 1,
#  'daradatu': 1,
#  'dayatoemar': 1,
#  'deddyrusmadi': 1,
#  'dede_ucihabalishoes18': 1,
#  'dedek.krnw': 1,
#  'dedewawan_': 1,
#  'dendy70s': 1,
#  'deni_al.izdihaar': 1,
#  'dennybigboy': 1,
#  'denting_harmony2011': 1,
#  'desi_ambarwati1': 1,
#  'dessnatt': 1,
#  'destrihsnn': 1,
#  'deviedwar10': 1,
#  'dewiayuasarii': 1,
#  'dffaaprillio': 1,
#  'dhe.noke': 1,
#  'dhie.diaty': 1,
#  'dhuwananx': 1,
#  'diah.ummu.s': 1,
#  'dian_anjani89': 1,
#  'dianrasyid16': 1,
#  'dicki_nabil': 1,
#  'difslm_': 1,
#  'diiitthh_': 1,
#  'dikyaade_': 1,
#  'dinasti.andrian': 1,
#  'dinatauhida': 1,
#  'donal79': 1,
#  'donaldgarcia_lm': 1,
#  'donipurr': 1,
#  'donyendica': 1,
#  'dr.andreas_situngkir': 1,
#  'drakorindo_wisdom': 1,
#  'drg.emydasiregar_sp.ort': 1,
#  'drian12elia': 1,
#  'driciv': 1,
#  'drtn_naff': 1,
#  'drumer_gimik': 1,
#  'dudiramdani': 1,
#  'dumpacc4512': 1,
#  'dwi0825_10': 1,
#  'dwipa_denis': 1,
#  'dwizulfikarnur': 1,
#  'dzfaa_aa': 1,
#  'ebe_mbe': 1,
#  'edday_eddoy': 1,
#  'edikafajarbastariyanto': 1,
#  ...}

# %%
# mention count
mention_count = {}
for (a,b), w in edge_weights.items():
    mention_count[a] = mention_count.get(a, 0) + w
    mention_count[b] = mention_count.get(b, 0) + w

# sort mention count by value descending
mention_count = dict(sorted(mention_count.items(), key=lambda item: item[1], reverse=True))
mention_count
# Out:
# {'prabowo': 236,
#  'smindrawati': 111,
#  'presidenrepublikindonesia': 24,
#  'kemenpar': 22,
#  'bahlillahadalia': 19,
#  'official': 15,
#  'gerindra': 15,
#  'listyosigitprabowo': 14,
#  'rajaantoni': 14,
#  'prasetyo_emilarie': 9,
#  'rafly.wibowo240101': 9,
#  'rocky': 9,
#  'heyjoykuy': 8,
#  'zul': 7,
#  'erickthohir': 7,
#  'egiiiinn': 7,
#  'fahria.zxcc': 7,
#  'alamsyahsubakri': 7,
#  'tomsuryapanji': 6,
#  'sekretariat': 6,
#  'mohmahfudmd': 6,
#  'oensragil.id': 6,
#  'octhavvia6': 6,
#  'gibran_rakabuming': 5,
#  'yuanitagayatri': 5,
#  'bungfahmiali': 5,
#  'achmad.rehansyah.1': 5,
#  'luhut': 5,
#  'javanoase': 5,
#  'nestheaceae': 5,
#  'khoirulfl': 5,
#  'rhama.bpn.sgta': 4,
#  'sumargodenny': 4,
#  'taniasoktaviani': 4,
#  '_nsrimulyani11': 4,
#  'marjuniaaa': 4,
#  'lenirahardja': 4,
#  'syakurhilmy_': 4,
#  'ketua_psms': 4,
#  'narasinewsroom': 4,
#  'dr': 4,
#  'dewan_perwakilan_netizen_ri': 4,
#  'hammmmmmmag09': 4,
#  'mustangid.mustangid': 4,
#  'jessy_humirtap': 4,
#  'titokarnavian': 4,
#  'ansrhdyn03': 4,
#  'aeztrishavaniabi': 4,
#  'tirexmadep': 4,
#  'mastercorbuzier': 4,
#  'teer_yteee3949': 4,
#  'ttk.project': 4,
#  'wahyu_uduy': 4,
#  'rossargallica': 4,
#  'trioatma': 4,
#  'syafiraoctafiani': 4,
#  'kemensetneg': 4,
#  'aazizahnf_': 4,
#  'ardilahpuspa': 4,
#  'riowahyuda58': 4,
#  'aryosamuelhartanto': 4,
#  'rahmathidayah_12': 4,
#  'nawaraja99': 4,
#  'rdt_prm': 3,
#  'm': 3,
#  'brooklyn_cheesee': 3,
#  'fzi': 3,
#  'plutonioneon': 3,
#  'ranggaprimadasa': 3,
#  'dinatauhida': 3,
#  'pandu_ozil11': 3,
#  'hadicobruts': 3,
#  'chllprk': 3,
#  'salmainstbrz': 3,
#  'faaaaadiiil': 3,
#  'heriant_international': 3,
#  'anp_studio13': 3,
#  'xreal_2202': 3,
#  'downhill_jaksquad': 3,
#  'maria_quyya': 3,
#  'ardii_lukman': 3,
#  'bang': 3,
#  'tempodotco': 3,
#  'bchtakos': 3,
#  'irwandiferry': 3,
#  'bocoraluspolitik': 3,
#  'jonijn_': 3,
#  'dwanharun': 3,
#  'wahyu_rajin_menabung_': 3,
#  'padli': 3,
#  'bagastia_hekas': 3,
#  'nadhisalsaa': 3,
#  'karunasankara01': 3,
#  'donal79': 3,
#  'heldums': 3,
#  'tyfanew_21': 3,
#  'imrongiant20': 3,
#  'muhammadkahfi___': 3,
#  'fhmilham': 3,
#  'husnahardiana': 3,
#  'hengkiheng98': 3,
#  'yttagusfirmansyah': 3,
#  'natalius_pigai': 3,
#  'idakristagram': 3,
#  'marioaian': 3,
#  'roywicaksono': 3,
#  'jessica__floren': 3,
#  'aldo_adv': 3,
#  'insomnia__mcmxcv__': 3,
#  'dpr_ri': 3,
#  'floflorav': 3,
#  'dennybigboy': 3,
#  'naeliatitik': 3,
#  'aamedo3': 3,
#  'scorgees': 3,
#  'havesasad': 3,
#  'doraeyon_': 3,
#  'biijisesawi': 3,
#  'alifikri632': 3,
#  'taufikk': 3,
#  'a': 3,
#  'ditoariotedjo': 3,
#  'gbriieel': 3,
#  'deni.fitriyanto': 3,
#  'bil_lee_': 3,
#  'bandung': 3,
#  'indie_24jam': 3,
#  'adivnm': 3,
#  'rvvlnsyah12': 3,
#  'rezabahroem': 3,
#  'ihsannnnudin': 3,
#  'farizaarif07': 3,
#  'jokowi': 3,
#  '23isaaac': 3,
#  'mwerrie': 3,
#  'wnda_fp': 3,
#  'febrinaharyono': 3,
#  'ianone__': 3,
#  'muhammad_hezra': 3,
#  'arifback11': 3,
#  'ulye_zriyani': 3,
#  'hanafi__18': 3,
#  'hery_wibowoo': 3,
#  'karyono6879': 3,
#  'saran_masukan': 3,
#  'yoggyyeni': 3,
#  'dfey77': 3,
#  'ujangsulaimann': 3,
#  'bagusfirmansyahputra': 3,
#  'panduadiputrawijaya': 3,
#  'asannopik199': 3,
#  'fiqriiz': 3,
#  'rama_vj_': 3,
#  'krnwaan__': 3,
#  'asma_hsna13': 3,
#  'ev': 3,
#  'dian_anjani89': 3,
#  'denisarimbi06': 2,
#  'enia130901': 2,
#  'ashurin.1010': 2,
#  'ukmindo.id': 2,
#  'mrs_susinisharin': 2,
#  'rudi.gaol': 2,
#  'ikbarsinaga999': 2,
#  'rahmadsejati': 2,
#  'sarden.ina': 2,
#  'io9713': 2,
#  'i.m.reys': 2,
#  'wongtani_padi': 2,
#  'rahayuindah_': 2,
#  'eyesmaul': 2,
#  'diah': 2,
#  'fraksipartaigerindra': 2,
#  'berkegiatan': 2,
#  'wirassan': 2,
#  'dahnil_anzar_simanjuntak': 2,
#  'kementeriankegelapan': 2,
#  'daffi.azhari': 2,
#  'asnia_nanta': 2,
#  'anti.karisna': 2,
#  'ervinadifitri': 2,
#  'revianasta7': 2,
#  'himawari_hana7': 2,
#  'dindasafira138': 2,
#  'zackarckerman': 2,
#  'miyaaaloiiia': 2,
#  'ikonarendra': 2,
#  'laurabbgaadd': 2,
#  'faiza_azah': 2,
#  'kun_toarya': 2,
#  'meisiashh': 2,
#  'mawaariiuadd': 2,
#  'mitadewanti5': 2,
#  'senoa_jj': 2,
#  'puttinurma': 2,
#  'kinan.ataya': 2,
#  'antorubiyanto396': 2,
#  'baiq._wati': 2,
#  'deddy.gondrong.3910': 2,
#  'faila_kurnia': 2,
#  'alkmardz': 2,
#  'heri_sukatmii': 2,
#  'handcraft_bundiy': 2,
#  'aadamchesar': 2,
#  'tamy.apreall': 2,
#  'mardiguwp': 2,
#  'meirinashlic': 2,
#  'marindasari': 2,
#  'sonnydharmawan1707': 2,
#  'lia_acut': 2,
#  'ariebecks23': 2,
#  'wantose_': 2,
#  'soniadrewbelle': 2,
#  'franzoro26': 2,
#  'bennydsp': 2,
#  'puanmaharaniri': 2,
#  'ascornion': 2,
#  'zulhammuchtar': 2,
#  'aienditfc': 2,
#  'rubennebur05': 2,
#  'jibriaratna': 2,
#  'bintorosetya': 2,
#  'basukibtp': 2,
#  'aimanwitjaksono': 2,
#  'rizalbojesz': 2,
#  'slatjenny': 2,
#  'andriawanarif24': 2,
#  'awahyudiiii': 2,
#  'wie.46': 2,
#  'man_vidaview_apartments': 2,
#  'indahnyakotapekanbaru': 2,
#  '22risk_': 2,
#  'haruto_akira6721': 2,
#  'dewalautaru': 2,
#  'vian_osd': 2,
#  'yuliagrn': 2,
#  'endaahh_11': 2,
#  'andi_m_awal': 2,
#  'ariesboriz': 2,
#  'nmitantika': 2,
#  'vembyoctora': 2,
#  'eka_fath': 2,
#  'salsaer': 2,
#  'sahabatgowesiantar': 2,
#  'agung_rudes': 2,
#  'urredcherry': 2,
#  'zeinedebali': 2,
#  'suroyanarif': 2,
#  'ade_rai': 2,
#  'farielriz': 2,
#  'mohamadbagas_s': 2,
#  'ahmadruyan9': 2,
#  'kucingoyen2079': 2,
#  'serwyqueen': 2,
#  'sz_szoboslai': 2,
#  'arepngecaprak': 2,
#  'nksavio': 2,
#  'arif_rustian': 2,
#  'bambelagi': 2,
#  'warungkl2': 2,
#  'ayrosalia': 2,
#  'lydiaamariana': 2,
#  'syahziar': 2,
#  'basoeki_widjaja': 2,
#  'rafiq_putra97': 2,
#  'subachan_subachan': 2,
#  'isabellemasniari': 2,
#  'refpi_irmansah': 2,
#  'linda.dwiayu': 2,
#  'ezelodes': 2,
#  'sandii2905': 2,
#  'susipudjiastuti115': 2,
#  'fauzan_putra_b': 2,
#  'docturnal_': 2,
#  'hermans_36': 2,
#  'adit_': 2,
#  'berkatreynardo': 2,
#  'auzanmarrio': 2,
#  'rdhrmdhn': 2,
#  'dede_ucihabalishoes18': 2,
#  'azizputraaaaa': 2,
#  'edisaja1983': 2,
#  'hendyhedyawan': 2,
#  'maxluwis': 2,
#  'muhamadraihan_nur': 2,
#  'oska': 2,
#  'glhbn': 2,
#  'apri_isnanto': 2,
#  'azharirakhman': 2,
#  'alaskankingcrabb': 2,
#  'paisald.arasit': 2,
#  'mutiahwijilestari': 2,
#  'madamahesa': 2,
#  'permanailham84': 2,
#  'satrio3nurcahya': 2,
#  'rly': 2,
#  'cepyanugrahs90': 2,
#  'sev.tjhoa': 2,
#  'junaydfloyd': 2,
#  'metanayy': 2,
#  'mntpppppp111': 2,
#  'mam_ading2728': 2,
#  'bonifasius_bima': 2,
#  'rferdinan_007': 2,
#  'dimsdwii': 2,
#  '_almayym': 2,
#  '_rinadh': 2,
#  'adisilva21': 2,
#  'riokurniawan_id': 2,
#  'd_vrile': 2,
#  'frsardan_': 2,
#  'larissa_dewii': 2,
#  'kikeydira': 2,
#  'amariadc': 2,
#  'dindarvian': 2,
#  'jasapindahanbali': 2,
#  'ahmadrifai0459': 2,
#  'rummatadody': 2,
#  'christopher_adijaya': 2,
#  'thea_dyah': 2,
#  'ham.putraa': 2,
#  'restumujijoyo': 2,
#  'budi_albukhari': 2,
#  'afrizalrrx': 2,
#  'dimasadji_k': 2,
#  'ravenzzyy': 2,
#  'donipurr': 2,
#  'anastasiayhna': 2,
#  'frndinda': 2,
#  'wira_shaka': 2,
#  'pranata.ivan12': 2,
#  'wmfy_': 2,
#  'fachminaufal_': 2,
#  'ajisantososan21': 2,
#  'arkina_mei': 2,
#  'dinar_melodi': 2,
#  'ihsan.alprss': 2,
#  'bimaananta': 2,
#  'rendyhyi': 2,
#  'siiriyans': 2,
#  'shenlyy': 2,
#  'nisafhzaa': 2,
#  'nurhayani_26': 2,
#  'erwindjuntak': 2,
#  'urfanramadhan': 2,
#  'sersanhusen_': 2,
#  'f': 2,
#  'rinpast': 2,
#  'sutrianaawjy__________': 2,
#  'bergkamp_p': 2,
#  'sulaimanelahmad': 2,
#  'khessy21': 2,
#  'neurball': 2,
#  'aslumpgod__': 2,
#  'linggachndraaa': 2,
#  'endrianhs': 2,
#  'ikhaaikhull': 2,
#  'ekybong365': 2,
#  'dwiwahyuni464': 2,
#  'fahmirosyada10': 2,
#  'chandra182121': 2,
#  'fahri_noviantoo': 2,
#  'rhisky.26': 2,
#  'luthfiemuamar': 2,
#  'bheema11': 2,
#  'azizjayapartnersip2015': 2,
#  'jaka_huna25': 2,
#  'zain_sulaiman_ramadhan1725': 2,
#  'wmfms_': 2,
#  'bersihsehat88': 2,
#  'danielmonorel': 2,
#  'lllgita97': 2,
#  'paracetamol289': 2,
#  'kejaksaan': 2,
#  'fajarrh0': 2,
#  'abryan_story': 2,
#  'bgsabdrrhmn_29': 2,
#  'cukawikachuu': 2,
#  'dwii_setyawan_': 2,
#  'muhammad_noah_elsafik': 2,
#  'edzeki': 2,
#  'andiippank422': 2,
#  'chineselovematures': 2,
#  'agus_punyo': 2,
#  'ikbar_muchtar': 2,
#  'ucu3024': 2,
#  '_negggaaaaaaa_': 2,
#  'dirisendirri': 2,
#  'setiawan26789': 2,
#  'bayuhastomo111': 2,
#  'geo.kyboobs': 2,
#  'dedi_bydindo': 2,
#  'xtrememerch': 2,
#  'bono_0170': 2,
#  'vin_tjoa': 2,
#  'masa_umum': 2,
#  'alienjack2025': 2,
#  'andiiprt': 2,
#  'bsxxvn': 2,
#  'andrewwahyono': 2,
#  'andijerni': 2,
#  'derry_pm05': 2,
#  'rianardiansyah21': 2,
#  'mel.dharmawan': 2,
#  'kumis_lembut': 2,
#  'mel': 2,
#  'enmyyoshi': 2,
#  'rafik_smart': 2,
#  'dimaswongapik123': 2,
#  'gilang_bayureksa': 2,
#  'freddyjuan27': 2,
#  'donnyo1105': 2,
#  'evan.g10': 2,
#  'khairulhamid28': 2,
#  'kesempatantaubat': 2,
#  'ronikeeprockin': 2,
#  'sukabumimediautama': 2,
#  'izamaranief': 2,
#  '_a.aa.n': 2,
#  'fndnrz': 1,
#  'risqi_aguspianto': 1,
#  'muchlizdarma1': 1,
#  'lorenzoabim': 1,
#  'al_hazhouse': 1,
#  'meilanidoodling': 1,
#  'andianq': 1,
#  'alimunirss': 1,
#  'thoniluthfi': 1,
#  'dudiramdani': 1,
#  'reisaldo': 1,
#  'ayurachanda': 1,
#  'nky.338': 1,
#  'mika': 1,
#  'agnes_antam_minigold': 1,
#  'auliaarezki': 1,
#  'aabunyamin': 1,
#  'apna_permana97': 1,
#  'alimasykur__': 1,
#  'roynais': 1,
#  'rakyadjelata': 1,
#  'mhmdosmm': 1,
#  'nasrunart77': 1,
#  'brez84': 1,
#  'pu666uh': 1,
#  'bungalawang22': 1,
#  'vandra_imanda': 1,
#  'polparty123': 1,
#  'aryaaa.gn': 1,
#  'borusitoruspanenauli': 1,
#  'diah.ummu.s': 1,
#  'i': 1,
#  'syah_ram': 1,
#  'muhammadkholili30': 1,
#  'rngyudho': 1,
#  'tsyahrulramadhan_': 1,
#  'ilzamuddin_': 1,
#  'uktazzy': 1,
#  'ardnsyah.yusuf': 1,
#  'anagirl20101993': 1,
#  'ardnsyah': 1,
#  'neversaydie28_': 1,
#  'kidaisme': 1,
#  'susantoagus0310': 1,
#  'novacm': 1,
#  'syahrilim': 1,
#  'helinpurba': 1,
#  'daniwirdani': 1,
#  'charcoal1470': 1,
#  'yantokuzo': 1,
#  'mrsamang': 1,
#  'kanzen212': 1,
#  'fauzanihanifanshori_': 1,
#  'patox_concept': 1,
#  'damarkurrnia': 1,
#  'ineekkkaddsad': 1,
#  'sellyaskyah': 1,
#  'rika_julianti21': 1,
#  'sagitaaenyy66': 1,
#  'fabillaanna': 1,
#  'kanaraarsy': 1,
#  'maryanama33': 1,
#  'anasyagit': 1,
#  'rida.hera': 1,
#  'reyfanaml': 1,
#  'zeolarg': 1,
#  'marcusandnn': 1,
#  'wirataahhyad': 1,
#  'ziarinala': 1,
#  'maya_kolinda': 1,
#  'selviadindda': 1,
#  'fatiranaya': 1,
#  'sassylana8': 1,
#  'fellinasha': 1,
#  'dianretno65': 1,
#  'meldasindya': 1,
#  'ditaalmira89': 1,
#  'geanita.amina23': 1,
#  'ernasetyani747': 1,
#  'enisariee': 1,
#  'lisa.amina122023': 1,
#  'srika.yatun': 1,
#  'dirameirina': 1,
#  'liviaviana2104': 1,
#  'presiden_netizen_official1': 1,
#  'subhanfathah': 1,
#  'donal_anjar_simanjuntak_': 1,
#  'halo_polisi': 1,
#  'hijiraaa.w': 1,
#  'junaeloo3': 1,
#  'tika_ry': 1,
#  'indragnwn330': 1,
#  'lampubumi': 1,
#  'fwulan_10': 1,
#  'sekarlangittttt': 1,
#  'dedyirawan1989': 1,
#  'amiril_mu': 1,
#  'goelabakingstudio': 1,
#  'yahginiamat': 1,
#  'erik_tiono_0293': 1,
#  'gowther06': 1,
#  'retoucherjakarta': 1,
#  'ranisrina': 1,
#  'reshajr': 1,
#  'baiq': 1,
#  'lalalaamma': 1,
#  'acikaldi._': 1,
#  'tikodes': 1,
#  'xy_lsn08': 1,
#  'dans_siltorxviii': 1,
#  'toko_alhidayah': 1,
#  'ir_wily': 1,
#  'yantizieyah': 1,
#  'fuji_pratiwiaff': 1,
#  'sivaristantiya': 1,
#  'roidwansudrajat_': 1,
#  'kemenpora': 1,
#  'tedsky89': 1,
#  'sufmi_dasco': 1,
#  'matakupingcomm': 1,
#  'sutarno_car_linggau_bisa_84': 1,
#  'fazri_ponosutan31': 1,
#  'deryan_arya': 1,
#  'shokhiaufal': 1,
#  'tgk_ricky': 1,
#  'diyaresta': 1,
#  'thebadboyblues': 1,
#  'ysfibra': 1,
#  'susi_1778': 1,
#  'randyputrapratama03': 1,
#  'praharja': 1,
#  'praharja.bangga': 1,
#  'hayati.ilma': 1,
#  'drop_shiiitttttt': 1,
#  'habiburrahman1819': 1,
#  'mutiarardew': 1,
#  'alimahmudi_10': 1,
#  'nvioletas': 1,
#  'nabill_rayyan': 1,
#  'aryandra_sagara': 1,
#  'fadciks': 1,
#  'randuuuuuuuu': 1,
#  'yogirarala': 1,
#  'lilysuzernita': 1,
#  'meryoktaavia': 1,
#  'citra_anindita_arum': 1,
#  'yan.4303': 1,
#  'yan': 1,
#  'deviedwar10': 1,
#  'yaya_twa': 1,
#  'budiaresetiadi': 1,
#  '1.917s': 1,
#  '1': 1,
#  'jamalmecca': 1,
#  'megadirga': 1,
#  'ketua_dprri': 1,
#  'sofyan__wijaya': 1,
#  'gritiesseven': 1,
#  'herii_kurniawan': 1,
#  'elanofiqri': 1,
#  'hatta_elmakoalloe': 1,
#  'muhammadridwan20112014': 1,
#  'zee.azizahhh': 1,
#  'zee': 1,
#  'c.rob.ad.wi': 1,
#  'naominapitpulu': 1,
#  'arthursien': 1,
#  'priska_simanungkalit': 1,
#  'inimaszen': 1,
#  'aammansor': 1,
#  'vetynathasandra': 1,
#  'syarifudinhidayat91': 1,
#  'lafathna': 1,
#  'nnazizah_15': 1,
#  'tsunderearmy': 1,
#  'syams1991': 1,
#  'firdaus_93__': 1,
#  'berkahmandiri99': 1,
#  'rizkipadilahhh': 1,
#  'faizbacangocid': 1,
#  'denelwans8': 1,
#  'keboo.o_o': 1,
#  'ffiela': 1,
#  'xslendro': 1,
#  'guns_1422': 1,
#  'rinnyuntu': 1,
#  'andiniclaudita': 1,
#  'mhdnazmii._': 1,
#  'calll_me_nda': 1,
#  'nekoyaabigfam___': 1,
#  'ranipfahmi': 1,
#  'fuji.lestariiii': 1,
#  'johansihotang': 1,
#  'rainaldi': 1,
#  'sidiqrmd': 1,
#  'bgsadikin': 1,
#  'alfarez_n': 1,
#  'ledyanisipahutarlppim': 1,
#  'v.apriela': 1,
#  'tin': 1,
#  'tin.mbele': 1,
#  'v': 1,
#  'yy_____hdn': 1,
#  'fitriana_vie': 1,
#  'abaadnantea': 1,
#  'imam_al_safii': 1,
#  'triaspyrenia_iyaz': 1,
#  'mat.man89': 1,
#  'tryanggara23': 1,
#  'alaina_dandelion': 1,
#  'prabowogibran': 1,
#  '_aboed_': 1,
#  'cutrisanurzinahfonna': 1,
#  'akang_cutter': 1,
#  'ricko.firnandes': 1,
#  'asepwahyudiatmasubrata': 1,
#  'pangi_syarwi': 1,
#  'mommy.saeida': 1,
#  'herieaje': 1,
#  'nasr_en.as': 1,
#  'rham.md': 1,
#  'rakhmat_busthomi': 1,
#  'ekhyalfatih': 1,
#  'gusyaqut': 1,
#  'tony_hardianto_02': 1,
#  'egiedouce': 1,
#  'nurasrimaulida': 1,
#  'chindyelath98': 1,
#  'n_jaftien': 1,
#  'tiket_konser123': 1,
#  'dewi_saja': 1,
#  'monitsitanggang': 1,
#  'irzanrisaldi': 1,
#  'rardiansp': 1,
#  'meliaapr': 1,
#  'mafrizalandre270_': 1,
#  'putriwhdtns': 1,
#  'im_hekmachtyar': 1,
#  'adigunawanutama': 1,
#  'ga': 1,
#  'dicki_nabil': 1,
#  'muljanes': 1,
#  'endar.82': 1,
#  'sipalingmoni': 1,
#  'raymondchins': 1,
#  'astriaprn': 1,
#  'indrayunandaa': 1,
#  '_zackyya_': 1,
#  'rachmawatieermaa': 1,
#  'sriandoko_': 1,
#  'shofia_rokhmah': 1,
#  'aguez_gusuts': 1,
#  'rioramadany__': 1,
#  'budhy.dhi': 1,
#  'astrid.zein': 1,
#  'rmbirtaaaaa': 1,
#  'rikanarr': 1,
#  'bintangastari320': 1,
#  'anggerm': 1,
#  'komarsoleh7': 1,
#  'much.hartanto': 1,
#  'ani_lestari77': 1,
#  'matanajwa': 1,
#  'endizulyanata': 1,
#  'syahputra17_': 1,
#  'wisamfahry': 1,
#  'bayibebek34': 1,
#  'satria_nusantara02': 1,
#  'iamumaar': 1,
#  'chindi1727': 1,
#  'santytravnick': 1,
#  'azhar_bintang_muhammad': 1,
#  'tolhassiregar': 1,
#  'qwertyasn.ac': 1,
#  'vinsi_dharma87': 1,
#  'dienlala1987': 1,
#  'rnuzulla': 1,
#  'abduliqram31': 1,
#  'hidupsedetik': 1,
#  'king_uyakuya': 1,
#  'sahroni': 1,
#  'nyari.lucu': 1,
#  'syamsia_satra11': 1,
#  'sultan_sudirman17': 1,
#  'nurulfyu': 1,
#  'hendrowijoyo123': 1,
#  'daniel.marda47': 1,
#  'jeromepolin': 1,
#  'dedimulyadi71': 1,
#  'irtizaqdalahmas': 1,
#  'jpd': 1,
#  'jpd.polo': 1,
#  'ben_levinous': 1,
#  'desyadwi': 1,
#  'zackyzulfikar__': 1,
#  'saridona28': 1,
#  'yuli03_': 1,
#  'sholah_raseed': 1,
#  'gar.field_napoleon': 1,
#  'kaimsasiku': 1,
#  'f_rizal01': 1,
#  'jagorisol': 1,
#  'olie_august85': 1,
#  'claruzalejandro': 1,
#  'africanadi_': 1,
#  'nida_hidayah': 1,
#  'nuzuliea': 1,
#  'romie_229': 1,
#  'boesetyawan': 1,
#  'teukurizkir': 1,
#  'gasmi_nganjuk.official': 1,
#  'gresyel': 1,
#  'rasdi_muchtar': 1,
#  'firnamaulia': 1,
#  'veni_daventi': 1,
#  'ganjar_inst': 1,
#  'pudjasu': 1,
#  'subaltern___': 1,
#  'sam11ja': 1,
#  'maulana': 1,
#  'nuritiewz': 1,
#  'san_jri': 1,
#  'septi_faiffaniati_3': 1,
#  'wahjoe_kum': 1,
#  'basil.hawking': 1,
#  'diego.fly1': 1,
#  'muharifrahman26': 1,
#  'dimas_rahmat20': 1,
#  'airlanggahartarto_official': 1,
#  'rifqi492': 1,
#  'fnm.maulana': 1,
#  'sayyid_2302': 1,
#  'angga_ramdhann': 1,
#  'michaelnadeak_id': 1,
#  'himaqueena': 1,
#  'dndung_22': 1,
#  'aldiseptian0199': 1,
#  'herzon': 1,
#  'andra_metavers': 1,
#  'fajrinsta': 1,
#  'muhamad_faisal0093': 1,
#  'sugiartiikikii': 1,
#  'coissn': 1,
#  'liualfarezelwibowo': 1,
#  'you.wishtoknowme': 1,
#  '19hendrasetiawan33': 1,
#  'berdos_farabuto': 1,
#  '__umi.adibah__': 1,
#  'kurniawanmirdan': 1,
#  'wichaaw': 1,
#  'mohammedhesham._': 1,
#  'ilham_m_ge8': 1,
#  'irmamulyani11': 1,
#  'farid_atmaja': 1,
#  'thecaptaen_': 1,
#  'naga_05_hoki': 1,
#  'pefintadiana': 1,
#  'rockygerungfans': 1,
#  'mhd__fnda': 1,
#  'anis.potopoto': 1,
#  'ummialkahfi': 1,
#  'insanmuttaqin_': 1,
#  'avocado0941': 1,
#  'nugraha.tara': 1,
#  'abdillah': 1,
#  'anitaoktaviasitumorangreal': 1,
#  'hanamaryam__': 1,
#  'mutiaayupratiwii': 1,
#  'rahayuning.tyas9': 1,
#  'linda': 1,
#  'nurhalimy7': 1,
#  'idatusadiah.harahap': 1,
#  'art_jepret': 1,
#  'sezaree': 1,
#  'yonadeb': 1,
#  'deaasukma': 1,
#  'aning_27.2': 1,
#  'sanggarsetiadharma': 1,
#  'altiopras': 1,
#  'jollyroger45_': 1,
#  'velocyvnya_': 1,
#  'bosupik99': 1,
#  'nuun.1988': 1,
#  'nuun': 1,
#  'tiyasambawani': 1,
#  'ilan.albes': 1,
#  'amy_jakarta': 1,
#  'vikarilesta': 1,
#  'alee.consultant': 1,
#  'agusgimnastiar_': 1,
#  'subhan_ubam': 1,
#  'bisaaja52': 1,
#  'kokosamajk': 1,
#  'radmodiharjo': 1,
#  'adietakbar_': 1,
#  'miriptokovape.bintaro': 1,
#  'tukanglistrikbelajaran': 1,
#  'lucky76s': 1,
#  'ini.thorrrr': 1,
#  'maz.bagoez.beloved': 1,
#  'tary_aww': 1,
#  'a.bukhory_3': 1,
#  'iarthista': 1,
#  'masyarakat9911': 1,
#  'azissamruu': 1,
#  'topanrizkyr': 1,
#  'adhibonzai': 1,
#  'alifnoor_maximine': 1,
#  'annas_so': 1,
#  'nano': 1,
#  'sandiramdhani': 1,
#  'puji_widyanti': 1,
#  'dwidananx': 1,
#  'adriantomay22': 1,
#  'noe_oke95': 1,
#  'nalv_ti': 1,
#  'nalv_ti.ok': 1,
#  'fida': 1,
#  'fida.degel': 1,
#  'ttk': 1,
#  'tetapyosua': 1,
#  'rzlrust': 1,
#  'ubeidhabibi': 1,
#  'oska.den': 1,
#  'nowomanlikeevil': 1,
#  'rhama': 1,
#  'tiaputrianaoehoe': 1,
#  'rudi.syahrizal': 1,
#  'isya_andika': 1,
#  'putralibrasang': 1,
#  'azka_dhanurendra': 1,
#  'leliyan12': 1,
#  'rezza_ilham1808': 1,
#  'jazimerveous': 1,
#  'hndabimanyu__': 1,
#  'ilhamelsoth': 1,
#  'baratastum': 1,
#  'garlandini7': 1,
#  'dpp_pkb': 1,
#  'lalara556': 1,
#  'hasanahaynur': 1,
#  'canggihfit': 1,
#  'andretama26': 1,
#  'rikko.novriyanto91': 1,
#  'rezayunizar_opaerza': 1,
#  'ravitasepti4': 1,
#  'za.fz_': 1,
#  'fawwazhaqqi01': 1,
#  'aoen666': 1,
#  'f.shavemaster': 1,
#  'fredigunawansetio': 1,
#  'barudak_gudang_kapuk': 1,
#  'fmy': 1,
#  'adefurqonn': 1,
#  'vindes': 1,
#  'marditoakp': 1,
#  'teman_terakhir10': 1,
#  'thomedu': 1,
#  'niskala.wastu_kancana': 1,
#  'sahirabarai': 1,
#  'ripperz_': 1,
#  'fauziah.nurii': 1,
#  'fauziah': 1,
#  'firmanior': 1,
#  'rifkidimasaditya': 1,
#  'gildan.rsr': 1,
#  'bjoeyyyy': 1,
#  'alfian_dharma_wicaksana': 1,
#  'tinobkt': 1,
#  'sopyan.aam': 1,
#  'nicomartens999': 1,
#  'ai_ainie125': 1,
#  'sopyan': 1,
#  'anantzo': 1,
#  'irpan_syabana': 1,
#  'rly.syp': 1,
#  'rofiq_muamar_pratama': 1,
#  'ayizthom': 1,
#  'taufik_hidayat237': 1,
#  'toerantang': 1,
#  'hrmaulana': 1,
#  'yonowijaya46': 1,
#  'novhndyn': 1,
#  'rantirahmdn': 1,
#  'salsa': 1,
#  'unitrh': 1,
#  'raimaus': 1,
#  'mrozikinn': 1,
#  'donyendica': 1,
#  'devisimanjorang08': 1,
#  'stevenid26': 1,
#  'enzoyoay': 1,
#  'mineurpha': 1,
#  'oakoho': 1,
#  'veren_hayon': 1,
#  'latepicku': 1,
#  'nichoopras': 1,
#  'jasaolahdata': 1,
#  'ravaliant': 1,
#  'dimassaktinugraha': 1,
#  'ninikao4400': 1,
#  'tikawngso': 1,
#  'deaamlyaa_': 1,
#  'widyatri___': 1,
#  'daiamond3u': 1,
#  'ghozali11_': 1,
#  'lindrianda': 1,
#  'adity4._': 1,
#  'taanilly': 1,
#  'yulianafrastikaa': 1,
#  'natluve_': 1,
#  'bd_raffa': 1,
#  'fadhil_saputra.045': 1,
#  'alf.iw12': 1,
#  'produkdigitalent': 1,
#  'lqmnfatih': 1,
#  'upp_aja': 1,
#  'lalaamala': 1,
#  'adisuryaputrariadii': 1,
#  'naddyaasya': 1,
#  'n': 1,
#  'chap99_': 1,
#  'youngdla_': 1,
#  'mass': 1,
#  'hideyuki': 1,
#  'hideyuki.id': 1,
#  'deni': 1,
#  'zulfadliputraas': 1,
#  'difi_raw': 1,
#  'log_aii': 1,
#  'ditrubyytay': 1,
#  'takutkecoak': 1,
#  'michavann': 1,
#  'sugaroflunar': 1,
#  'hansraizee_': 1,
#  'yosafatsimarmata': 1,
#  'vira': 1,
#  'abaehaqi_id': 1,
#  'alya_anaknya_pak_waka': 1,
#  'ichaaaaaaaaaaaaa08': 1,
#  'ardinadityaa': 1,
#  'panji_justice7': 1,
#  '_sucinuraini1': 1,
#  'queenfir_': 1,
#  'lia.ryan2020': 1,
#  'rzalcavalera': 1,
#  'agusyudhoyono': 1,
#  'gustiamw': 1,
#  'windafbrnt': 1,
#  'ayusriwahyunih': 1,
#  'dimastpramudita': 1,
#  'cullens2024': 1,
#  'wisnuayp': 1,
#  'hanxxdo': 1,
#  'mirrlosh': 1,
#  'luckytwoacc_': 1,
#  'aryakentoz12': 1,
#  'marimogstn': 1,
#  '_rajisSri': 1,
#  'iamahyl': 1,
#  'catherine_vanbora': 1,
#  'rndyahong': 1,
#  'f.aulia25': 1,
#  'zakyazzikra': 1,
#  'nikomodjo': 1,
#  'riyarsil': 1,
#  'fadilarizki_': 1,
#  'seesaw': 1,
#  'hassan_parulian': 1,
#  'nadbilqis': 1,
#  'sorayaainaa': 1,
#  'muhammadcholis2': 1,
#  'renitameilia': 1,
#  'miaajengs': 1,
#  '_______gaga': 1,
#  'heli151001': 1,
#  'yourmine': 1,
#  'lzltaa': 1,
#  'mahartyasnasaputri': 1,
#  'rustychainnn': 1,
#  'adaammubarok': 1,
#  ...}

# %% [markdown]
# #### Build Graph

# %%
import networkx as nx

# %%
# filter users with at least 2 mentions
min_mentions = 2
active_users = {u for u, c in mention_count.items() if c >= min_mentions}

# create graph
G = nx.DiGraph()
for (a, b), w in edge_weights.items():
    if a in active_users and b in active_users:
        G.add_edge(a, b, weight=w)

print("Nodes:", G.number_of_nodes(), "Edges:", G.number_of_edges())
# Out:
# Nodes: 355 Edges: 431

# %%
from pyvis.network import Network
import os

# %%
# create results directory if not exists
os.makedirs('../results', exist_ok=True)

# %%
import math

# %%
# create pyvis network
net = Network(notebook=True, directed=True)

# add nodes with attributes
for node in G.nodes():
    mentions = mention_count.get(node, 0)
    size = math.sqrt(mentions)*5+5
    net.add_node(
        node,
        title=f"User: {node}<br>Comments: {comment_count.get(node, 0)}<br>Likes: {like_sum.get(node, 0)}<br>Mentions: {mention_count.get(node, 0)}",
        value=size
    )

# add edges with weights
for u, v, info in G.edges(data=True):
    net.add_edge(u, v, value=info['weight'], title=f"Mentions: {info['weight']}")

# save result
net.show('../results/mention_network.html', notebook=False)
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# ../results/mention_network.html

# %% [markdown]
# #### Comunity Detection

# %%
import community as community_louvain

# %%
# using louvain
for node in G.nodes():
    G.nodes[node]['comment_count'] = comment_count.get(node, 0)
    G.nodes[node]['like_sum'] = like_sum.get(node, 0)
    G.nodes[node]['mention_count'] = mention_count.get(node, 0)

partition = community_louvain.best_partition(G.to_undirected())
partition
# Out:
# {'rdt_prm': 0,
#  'm': 0,
#  'brooklyn_cheesee': 1,
#  'fzi': 1,
#  'denisarimbi06': 2,
#  'prabowo': 2,
#  'enia130901': 3,
#  'plutonioneon': 3,
#  'ranggaprimadasa': 4,
#  'dinatauhida': 4,
#  'prasetyo_emilarie': 5,
#  'bahlillahadalia': 5,
#  'zul': 5,
#  'listyosigitprabowo': 5,
#  'erickthohir': 5,
#  'rafly.wibowo240101': 6,
#  'ashurin.1010': 2,
#  'pandu_ozil11': 7,
#  'hadicobruts': 7,
#  'rhama.bpn.sgta': 6,
#  'sumargodenny': 6,
#  'chllprk': 8,
#  'salmainstbrz': 8,
#  'faaaaadiiil': 9,
#  'heriant_international': 9,
#  'taniasoktaviani': 10,
#  '_nsrimulyani11': 10,
#  'marjuniaaa': 11,
#  'anp_studio13': 11,
#  'ukmindo.id': 2,
#  'tomsuryapanji': 5,
#  'egiiiinn': 12,
#  'sekretariat': 12,
#  'mrs_susinisharin': 13,
#  'xreal_2202': 13,
#  'downhill_jaksquad': 14,
#  'maria_quyya': 14,
#  'rudi.gaol': 15,
#  'smindrawati': 15,
#  'sarden.ina': 16,
#  'ardii_lukman': 16,
#  'io9713': 16,
#  'ikbarsinaga999': 17,
#  'bang': 17,
#  'wongtani_padi': 18,
#  'rahayuindah_': 18,
#  'eyesmaul': 12,
#  'diah': 12,
#  'gibran_rakabuming': 12,
#  'i.m.reys': 12,
#  'lenirahardja': 12,
#  'fraksipartaigerindra': 12,
#  'berkegiatan': 19,
#  'wirassan': 19,
#  'syakurhilmy_': 16,
#  'tempodotco': 16,
#  'daffi.azhari': 2,
#  'kemenpar': 2,
#  'asnia_nanta': 2,
#  'anti.karisna': 2,
#  'ervinadifitri': 2,
#  'revianasta7': 2,
#  'himawari_hana7': 2,
#  'dindasafira138': 2,
#  'zackarckerman': 2,
#  'miyaaaloiiia': 2,
#  'ikonarendra': 2,
#  'laurabbgaadd': 2,
#  'faiza_azah': 2,
#  'kun_toarya': 2,
#  'meisiashh': 2,
#  'mawaariiuadd': 2,
#  'mitadewanti5': 2,
#  'senoa_jj': 2,
#  'puttinurma': 2,
#  'kinan.ataya': 2,
#  'antorubiyanto396': 2,
#  'ketua_psms': 12,
#  'bocoraluspolitik': 12,
#  'presidenrepublikindonesia': 12,
#  'yuanitagayatri': 20,
#  'official': 20,
#  'mohmahfudmd': 20,
#  'wahyu_rajin_menabung_': 22,
#  'padli': 22,
#  'jonijn_': 22,
#  'baiq._wati': 22,
#  'bagastia_hekas': 22,
#  'deddy.gondrong.3910': 22,
#  'faila_kurnia': 23,
#  'narasinewsroom': 23,
#  'dwanharun': 24,
#  'alkmardz': 24,
#  'heri_sukatmii': 22,
#  'handcraft_bundiy': 25,
#  'aadamchesar': 25,
#  'tamy.apreall': 2,
#  'gerindra': 2,
#  'meirinashlic': 5,
#  'nadhisalsaa': 26,
#  'dr': 26,
#  'dewan_perwakilan_netizen_ri': 12,
#  'bungfahmiali': 12,
#  'sonnydharmawan1707': 27,
#  'heldums': 27,
#  'donal79': 28,
#  'imrongiant20': 28,
#  'muhammadkahfi___': 20,
#  'fhmilham': 20,
#  'husnahardiana': 29,
#  'franzoro26': 29,
#  'bennydsp': 30,
#  'puanmaharaniri': 30,
#  'jessy_humirtap': 15,
#  'hengkiheng98': 15,
#  'zulhammuchtar': 15,
#  'aienditfc': 15,
#  'jibriaratna': 15,
#  'yttagusfirmansyah': 5,
#  'natalius_pigai': 5,
#  'bintorosetya': 2,
#  'basukibtp': 2,
#  'rizalbojesz': 31,
#  'idakristagram': 31,
#  'slatjenny': 15,
#  'andriawanarif24': 15,
#  'marioaian': 15,
#  'rajaantoni': 5,
#  'awahyudiiii': 15,
#  'wie.46': 12,
#  'roywicaksono': 20,
#  'man_vidaview_apartments': 2,
#  'jessica__floren': 20,
#  'aldo_adv': 32,
#  'irwandiferry': 32,
#  'aimanwitjaksono': 32,
#  'insomnia__mcmxcv__': 12,
#  'indahnyakotapekanbaru': 2,
#  '22risk_': 5,
#  'haruto_akira6721': 30,
#  'dpr_ri': 30,
#  'dewalautaru': 33,
#  'vian_osd': 33,
#  'fahria.zxcc': 5,
#  'titokarnavian': 5,
#  'yuliagrn': 34,
#  'endaahh_11': 34,
#  'andi_m_awal': 2,
#  'ariesboriz': 5,
#  'nmitantika': 35,
#  'vembyoctora': 35,
#  'eka_fath': 36,
#  'dennybigboy': 36,
#  'sahabatgowesiantar': 2,
#  'ansrhdyn03': 5,
#  'urredcherry': 12,
#  'aeztrishavaniabi': 2,
#  'tirexmadep': 30,
#  'mastercorbuzier': 6,
#  'zeinedebali': 2,
#  'farielriz': 37,
#  'mohamadbagas_s': 37,
#  'achmad.rehansyah.1': 15,
#  'ahmadruyan9': 15,
#  'naeliatitik': 38,
#  'kucingoyen2079': 38,
#  'serwyqueen': 32,
#  'salsaer': 32,
#  'oensragil.id': 5,
#  'luhut': 5,
#  'arepngecaprak': 39,
#  'nksavio': 39,
#  'arif_rustian': 12,
#  'bambelagi': 40,
#  'warungkl2': 40,
#  'ayrosalia': 41,
#  'lydiaamariana': 41,
#  'syahziar': 5,
#  'floflorav': 15,
#  'basoeki_widjaja': 2,
#  'aamedo3': 2,
#  'hammmmmmmag09': 42,
#  'rafiq_putra97': 42,
#  'tyfanew_21': 42,
#  'scorgees': 42,
#  'teer_yteee3949': 2,
#  'subachan_subachan': 2,
#  'isabellemasniari': 20,
#  'refpi_irmansah': 12,
#  'alamsyahsubakri': 5,
#  'linda.dwiayu': 26,
#  'ezelodes': 5,
#  'sandii2905': 2,
#  'susipudjiastuti115': 2,
#  'doraeyon_': 15,
#  'berkatreynardo': 43,
#  'auzanmarrio': 43,
#  'alifikri632': 44,
#  'biijisesawi': 44,
#  'dede_ucihabalishoes18': 45,
#  'taufikk': 45,
#  'edisaja1983': 20,
#  'azizputraaaaa': 20,
#  'octhavvia6': 46,
#  'hendyhedyawan': 46,
#  'maxluwis': 43,
#  'ttk.project': 44,
#  'a': 46,
#  'oska': 6,
#  'wahyu_uduy': 6,
#  'ade_rai': 6,
#  'glhbn': 26,
#  'apri_isnanto': 47,
#  'azharirakhman': 47,
#  'paisald.arasit': 48,
#  'ditoariotedjo': 48,
#  'mutiahwijilestari': 12,
#  'satrio3nurcahya': 49,
#  'rly': 49,
#  'cepyanugrahs90': 2,
#  'sev.tjhoa': 2,
#  'rossargallica': 50,
#  'junaydfloyd': 50,
#  'metanayy': 50,
#  'mntpppppp111': 51,
#  'mam_ading2728': 51,
#  'rferdinan_007': 52,
#  'bandung': 52,
#  'bonifasius_bima': 53,
#  'dimsdwii': 53,
#  '_almayym': 54,
#  'indie_24jam': 54,
#  'adisilva21': 55,
#  'riokurniawan_id': 55,
#  'd_vrile': 56,
#  'adivnm': 56,
#  'deni.fitriyanto': 57,
#  'frsardan_': 57,
#  'kikeydira': 52,
#  'rvvlnsyah12': 58,
#  'amariadc': 58,
#  'syafiraoctafiani': 15,
#  'ahmadrifai0459': 5,
#  'rummatadody': 2,
#  'rezabahroem': 54,
#  'restumujijoyo': 59,
#  'budi_albukhari': 59,
#  'afrizalrrx': 60,
#  'dimasadji_k': 60,
#  'ravenzzyy': 2,
#  'donipurr': 61,
#  'anastasiayhna': 61,
#  'frndinda': 61,
#  'ihsannnnudin': 62,
#  'wira_shaka': 62,
#  'pranata.ivan12': 5,
#  'wmfy_': 63,
#  'kementeriankegelapan': 63,
#  'fachminaufal_': 64,
#  'ajisantososan21': 64,
#  'farizaarif07': 5,
#  'dinar_melodi': 48,
#  'ihsan.alprss': 12,
#  'bimaananta': 65,
#  'bil_lee_': 65,
#  'rendyhyi': 66,
#  '23isaaac': 66,
#  'javanoase': 12,
#  'kemensetneg': 12,
#  'aazizahnf_': 30,
#  'ardilahpuspa': 30,
#  'siiriyans': 15,
#  'nisafhzaa': 67,
#  'nurhayani_26': 67,
#  'erwindjuntak': 68,
#  'urfanramadhan': 68,
#  'sersanhusen_': 69,
#  'f': 69,
#  'rinpast': 70,
#  'sutrianaawjy__________': 70,
#  'bergkamp_p': 71,
#  'sulaimanelahmad': 71,
#  'linggachndraaa': 72,
#  'endrianhs': 72,
#  'ikhaaikhull': 12,
#  'dwiwahyuni464': 2,
#  'khoirulfl': 73,
#  'chandra182121': 73,
#  'muhammad_hezra': 73,
#  'arifback11': 73,
#  'hanafi__18': 73,
#  'rhisky.26': 74,
#  'fahri_noviantoo': 74,
#  'bheema11': 75,
#  'azizjayapartnersip2015': 75,
#  'wmfms_': 76,
#  'jokowi': 76,
#  'bersihsehat88': 77,
#  'danielmonorel': 77,
#  'hery_wibowoo': 2,
#  'lllgita97': 2,
#  'paracetamol289': 20,
#  'kejaksaan': 20,
#  'fajarrh0': 5,
#  'abryan_story': 2,
#  'karyono6879': 2,
#  'saran_masukan': 12,
#  'dwii_setyawan_': 69,
#  'muhammad_noah_elsafik': 69,
#  'riowahyuda58': 2,
#  'andiippank422': 5,
#  'chineselovematures': 15,
#  'agus_punyo': 5,
#  'yoggyyeni': 12,
#  'ikbar_muchtar': 12,
#  'ucu3024': 78,
#  'ujangsulaimann': 78,
#  '_negggaaaaaaa_': 78,
#  'setiawan26789': 79,
#  'dirisendirri': 79,
#  'aryosamuelhartanto': 80,
#  'bagusfirmansyahputra': 80,
#  'geo.kyboobs': 81,
#  'bayuhastomo111': 81,
#  'dedi_bydindo': 81,
#  'bono_0170': 82,
#  'vin_tjoa': 82,
#  'masa_umum': 80,
#  'panduadiputrawijaya': 79,
#  'andiiprt': 15,
#  'bsxxvn': 83,
#  'andrewwahyono': 83,
#  'andijerni': 2,
#  'derry_pm05': 84,
#  'rianardiansyah21': 84,
#  'rahmathidayah_12': 5,
#  'fiqriiz': 85,
#  'rama_vj_': 85,
#  'mel.dharmawan': 86,
#  'kumis_lembut': 86,
#  'mel': 86,
#  'enmyyoshi': 87,
#  'rafik_smart': 87,
#  'nawaraja99': 5,
#  'donnyo1105': 2,
#  'krnwaan__': 2,
#  'asma_hsna13': 26,
#  'evan.g10': 12,
#  'dian_anjani89': 20,
#  'khairulhamid28': 21,
#  'kesempatantaubat': 21,
#  'ronikeeprockin': 12,
#  'sukabumimediautama': 15,
#  'izamaranief': 2,
#  '_a.aa.n': 12}

# %%
# save user info with community
users_df = pd.DataFrame({'username': data['username'].dropna().unique()})
comm_df = pd.DataFrame(list(partition.items()), columns=['username', 'community'])
users_com = users_df.merge(comm_df, on='username', how='left')

# save to csv
users_com.to_csv('../results/users_community.csv', index=False)

# %%
# plot community graph
net = Network(notebook=True, directed=True)
net.from_nx(G)

# color nodes by community
for node in net.nodes:
    user = node['id']
    size = math.sqrt(mention_count.get(user, 0))*5+5
    node['group'] = partition[node['id']]
    node['value'] = size
    node['title'] = (
        f"User: {user}"
        f"<br>Comments: {comment_count.get(user, 0)}"
        f"<br>Likes: {like_sum.get(user, 0)}"
        f"<br>Mentions: {mention_count.get(user, 0)}"
        f"<br>Community: {partition[user]}"
    )

# save community graph
net.show('../results/mention_community_network.html', notebook=False)
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# ../results/mention_community_network.html

# %% [markdown]
# #### Community Deep Dive

# %%
from collections import Counter

# %%
# create results sub folder if not exists
os.makedirs('../results/sub', exist_ok=True)

# %%
# calculate the edge sum
edge_communities = []
for u, v in G.edges():
    if u in partition and v in partition and partition[u] == partition[v]:
        edge_communities.append(partition[u])

edge_count_per_comm = Counter(edge_communities)

# get community with >= 10 edges
valid_comms = [comm for comm, count in edge_count_per_comm.items() if count >= 10]
valid_comms
# Out:
# [2, 5, 12, 15, 20]

# %%
# create and save subgraph for each valid/big community
for comm in valid_comms:
    
    # create subgraph
    comm_nodes = [n for n, c in partition.items() if c == comm]
    subG = G.subgraph(comm_nodes)

    # create pyvis network
    net = Network(notebook=True, directed=True)
    net.from_nx(subG)

    # color nodes by community
    for node in net.nodes:
        user = node['id']
        size = math.sqrt(mention_count.get(user, 0))*5+5
        node['group'] = comm
        node['value'] = size
        node['title'] = (
            f"User: {user}"
            f"<br>Comments: {comment_count.get(user, 0)}"
            f"<br>Likes: {like_sum.get(user, 0)}"
            f"<br>Mentions: {mention_count.get(user, 0)}"
        )

    # save subgraph
    out_path = f"../results/sub/community_{comm}.html"
    net.show(out_path, notebook=False)
    print(f"Saved {out_path} ({subG.number_of_nodes()} nodes, {subG.number_of_edges()} edges)")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# ../results/sub/community_2.html
# Saved ../results/sub/community_2.html (55 nodes, 86 edges)
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# ../results/sub/community_5.html
# Saved ../results/sub/community_5.html (28 nodes, 45 edges)
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# ../results/sub/community_12.html
# Saved ../results/sub/community_12.html (29 nodes, 34 edges)
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# ../results/sub/community_15.html
# Saved ../results/sub/community_15.html (20 nodes, 21 edges)
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# ../results/sub/community_20.html
# Saved ../results/sub/community_20.html (13 nodes, 13 edges)

# %%
from collections import Counter

for comm in valid_comms:
    comm_nodes = {n for n, c in partition.items() if c == comm}

    sent_counter = Counter()
    received_counter = Counter()

    for u, v, info in G.edges(data=True):
        # only consider edges within the community
        if u in comm_nodes and v in comm_nodes:
            w = info.get('weight', 1)
            sent_counter[u] += w
            received_counter[v] += w

    print(f"Community {comm}")
    print("Top 3 mention (sender):", sent_counter.most_common(3))
    print("Top 3 get mention (receiver):", received_counter.most_common(3))
    print()
# Out:
# Community 2
# Top 3 mention (sender): [('riowahyuda58', 3), ('daffi.azhari', 2), ('asnia_nanta', 2)]
# Top 3 get mention (receiver): [('prabowo', 46), ('kemenpar', 21), ('gerindra', 10)]
#
# Community 5
# Top 3 mention (sender): [('fahria.zxcc', 6), ('alamsyahsubakri', 6), ('prasetyo_emilarie', 4)]
# Top 3 get mention (receiver): [('bahlillahadalia', 12), ('listyosigitprabowo', 8), ('zul', 5)]
#
# Community 12
# Top 3 mention (sender): [('egiiiinn', 3), ('dewan_perwakilan_netizen_ri', 3), ('javanoase', 3)]
# Top 3 get mention (receiver): [('presidenrepublikindonesia', 17), ('sekretariat', 4), ('kemensetneg', 4)]
#
# Community 15
# Top 3 mention (sender): [('hengkiheng98', 2), ('jibriaratna', 2), ('andriawanarif24', 2)]
# Top 3 get mention (receiver): [('smindrawati', 14), ('zulhammuchtar', 1), ('hengkiheng98', 1)]
#
# Community 20
# Top 3 mention (sender): [('yuanitagayatri', 2), ('muhammadkahfi___', 2), ('edisaja1983', 2)]
# Top 3 get mention (receiver): [('mohmahfudmd', 5), ('official', 4), ('kejaksaan', 2)]

# %% [markdown]
# #### Sentiment and Emotion Analysis

# %%
# read data
data = pd.read_csv('../data/comments_data.csv')

# ignore columns parent_id
data = data.drop(columns=['parent_id'])
data.head()
# Out:
#                                        link         comment_id  \
# 0  https://www.instagram.com/p/DOV0Rn2DNf-/  17916292923173899
# 1  https://www.instagram.com/p/DOV0Rn2DNf-/  18095910739726736
# 2  https://www.instagram.com/p/DOV0Rn2DNf-/  17980524434883939
# 3  https://www.instagram.com/p/DOV0Rn2DNf-/  18173137474359052
# 4  https://www.instagram.com/p/DOV0Rn2DNf-/  18038689634666892
#
#          username                                               text  \
# 0     lorenzoabim                   Anjir Dahnil kebagian kue nya :)
# 1          fndnrz  @risqi_aguspianto hahaha bukan pendukung prabo...
# 2   muchlizdarma1                @lorenzoabim kerjanya setaun sekali
# 3  ikbarsinaga999                  @al_hazhouse.land Kaesang hahahha
# 4    rahmadsejati  harapan rakyat sederhana 🙏 kerja nyata, hasil ...
#
#    created_at  like_count  reply_count
# 0  1757333808         192           16
# 1  1757372912           0            0
# 2  1757387323           0            0
# 3  1757676329           0            0
# 4  1757334122         757            2

# %%
# convert comment_time to datetime
data['created_at'] = pd.to_datetime(data['created_at'], unit='s')

# extract date from comment_time
data['date'] = data['created_at'].dt.date
data.head()
# Out:
#                                        link         comment_id  \
# 0  https://www.instagram.com/p/DOV0Rn2DNf-/  17916292923173899
# 1  https://www.instagram.com/p/DOV0Rn2DNf-/  18095910739726736
# 2  https://www.instagram.com/p/DOV0Rn2DNf-/  17980524434883939
# 3  https://www.instagram.com/p/DOV0Rn2DNf-/  18173137474359052
# 4  https://www.instagram.com/p/DOV0Rn2DNf-/  18038689634666892
#
#          username                                               text  \
# 0     lorenzoabim                   Anjir Dahnil kebagian kue nya :)
# 1          fndnrz  @risqi_aguspianto hahaha bukan pendukung prabo...
# 2   muchlizdarma1                @lorenzoabim kerjanya setaun sekali
# 3  ikbarsinaga999                  @al_hazhouse.land Kaesang hahahha
# 4    rahmadsejati  harapan rakyat sederhana 🙏 kerja nyata, hasil ...
#
#            created_at  like_count  reply_count        date
# 0 2025-09-08 12:16:48         192           16  2025-09-08
# 1 2025-09-08 23:08:32           0            0  2025-09-08
# 2 2025-09-09 03:08:43           0            0  2025-09-09
# 3 2025-09-12 11:25:29           0            0  2025-09-12
# 4 2025-09-08 12:22:02         757            2  2025-09-08

# %%
user_comm = pd.read_csv('../results/users_community.csv')
user_comm.head()
# Out:
#          username  community
# 0     lorenzoabim        NaN
# 1          fndnrz        NaN
# 2   muchlizdarma1        NaN
# 3  ikbarsinaga999       17.0
# 4    rahmadsejati        NaN

# %%
# merge
merged = data.merge(user_comm, on='username', how='left')
merged = merged.dropna(subset=['community'])
merged = merged.reset_index(drop=True)
merged.head()
# Out:
#                                        link         comment_id  \
# 0  https://www.instagram.com/p/DOV0Rn2DNf-/  18173137474359052
# 1  https://www.instagram.com/p/DOV0Rn2DNf-/  18066568718464364
# 2  https://www.instagram.com/p/DOV0Rn2DNf-/  18519537625024458
# 3  https://www.instagram.com/p/DOV0Rn2DNf-/  18103206322588474
# 4  https://www.instagram.com/p/DOV0Rn2DNf-/  17921412669139143
#
#          username                                               text  \
# 0  ikbarsinaga999                  @al_hazhouse.land Kaesang hahahha
# 1          io9713                                        Sama aja😂😂😂
# 2    lenirahardja     @ayurachanda bagi Tuhan gak ada yg mustahil ❤️
# 3   denisarimbi06  @prabowo betul itu, orang2 sisaa Mulyono tidak...
# 4  ikbarsinaga999                   Lah rotasi udahan, PKB -> Golkar
#
#            created_at  like_count  reply_count        date  community
# 0 2025-09-12 11:25:29           0            0  2025-09-12       17.0
# 1 2025-09-08 22:38:37           0            0  2025-09-08       16.0
# 2 2025-09-09 03:25:31           0            0  2025-09-09       12.0
# 3 2025-09-10 04:57:51           0            0  2025-09-10        2.0
# 4 2025-09-10 18:44:48           0            0  2025-09-10       17.0

# %%
# clean text
def clean_text(text):
    # delete mention
    text = re.sub(r'@\w+', '', text)

    # lowercase
    text = text.lower()
    
    # delete link
    text = re.sub(r'http\S+|www\S+', '', text)
    
    # delete non-printable characters except emoticons
    text = re.sub(r'[^\x00-\x7F]+', lambda m: m.group(0), text)
    
    # delete whitespace
    text = re.sub(r'\s+', ' ', text).strip()

    # delete emoji
    text = re.sub(r'[^\w\s,]', '', text)
    
    # tokenize
    tokens = text.split()
    return tokens

merged['clean_text'] = merged['text'].astype(str).apply(clean_text)
merged.head()
# Out:
#                                        link         comment_id  \
# 0  https://www.instagram.com/p/DOV0Rn2DNf-/  18173137474359052
# 1  https://www.instagram.com/p/DOV0Rn2DNf-/  18066568718464364
# 2  https://www.instagram.com/p/DOV0Rn2DNf-/  18519537625024458
# 3  https://www.instagram.com/p/DOV0Rn2DNf-/  18103206322588474
# 4  https://www.instagram.com/p/DOV0Rn2DNf-/  17921412669139143
#
#          username                                               text  \
# 0  ikbarsinaga999                  @al_hazhouse.land Kaesang hahahha
# 1          io9713                                        Sama aja😂😂😂
# 2    lenirahardja     @ayurachanda bagi Tuhan gak ada yg mustahil ❤️
# 3   denisarimbi06  @prabowo betul itu, orang2 sisaa Mulyono tidak...
# 4  ikbarsinaga999                   Lah rotasi udahan, PKB -> Golkar
#
#            created_at  like_count  reply_count        date  community  \
# 0 2025-09-12 11:25:29           0            0  2025-09-12       17.0
# 1 2025-09-08 22:38:37           0            0  2025-09-08       16.0
# 2 2025-09-09 03:25:31           0            0  2025-09-09       12.0
# 3 2025-09-10 04:57:51           0            0  2025-09-10        2.0
# 4 2025-09-10 18:44:48           0            0  2025-09-10       17.0
#
#                                           clean_text
# 0                           [land, kaesang, hahahha]
# 1                                        [sama, aja]
# 2              [bagi, tuhan, gak, ada, yg, mustahil]
# 3  [betul, itu,, orang2, sisaa, mulyono, tidak, b...
# 4                [lah, rotasi, udahan,, pkb, golkar]

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   link         479 non-null    object
#  1   comment_id   479 non-null    int64
#  2   username     479 non-null    object
#  3   text         478 non-null    object
#  4   created_at   479 non-null    datetime64[ns]
#  5   like_count   479 non-null    int64
#  6   reply_count  479 non-null    int64
#  7   date         479 non-null    object
#  8   community    479 non-null    float64
#  9   clean_text   479 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(5)
# memory usage: 37.5+ KB

# %%
# load xlsx SenticNet Indo
df = pd.read_excel("../data/senticnet.xlsx")
df.head()
# Out:
#           CONCEPT  INTROSPECTION  TEMPER  ATTITUDE  SENSITIVITY  \
# 0             aah          -0.56     0.0     0.000        0.000
# 1           abadi           0.00     0.0     0.964        0.000
# 2  abdominoplasti           0.00     0.0     0.290        0.000
# 3        aberrate           0.00     0.0    -0.554        0.000
# 4            abey           0.00     0.0     0.000       -0.329
#
#   PRIMARY EMOTION SECONDAY EMOTION POLARITY VALUE  POLARITY INTENSITY  \
# 0        #sadness              NaN       negative              -0.560
# 1        #delight              NaN       positive               0.964
# 2     #acceptance              NaN       positive               0.290
# 3        #disgust              NaN       negative              -0.554
# 4        #anxiety              NaN       negative              -0.329
#
#              SEMANTICS        Unnamed: 10           Unnamed: 11  \
# 0             keawaman              barok  kecemasan_sebelumnya
# 1             istabraq  meluncur_ke_bawah  dari_yang_diperlukan
# 2  bersuku_kata_banyak     ketidakcocokan                   jip
# 3     rompakan_permata           tripoint               formasi
# 4           mengurangi           membasmi            loop_synth
#
#        Unnamed: 12   Unnamed: 13
# 0  kelas_komersial      tertutup
# 1          serpina     kurricule
# 2       gaya_bebas       norelco
# 3            walsh  perang_salib
# 4         pankreas    shabarisha

# %%
# set dictionary
polarity_dict = dict(zip(df["CONCEPT"], df["POLARITY INTENSITY"]))
emotion_dict  = dict(zip(df["CONCEPT"], df["PRIMARY EMOTION"]))

# %%
# function to map tokens to sentiment and emotions
def map_sentiment(tokens):
    polarities = []
    emotions = []
    for t in tokens:
        if t in polarity_dict:
            polarities.append(polarity_dict[t])
        if t in emotion_dict:
            emotions.append(emotion_dict[t])
    # calculate average polarity
    avg_polarity = sum(polarities)/len(polarities) if polarities else 0
    
    # set sentiment based on avg_polarity
    if avg_polarity > 0.05:
        sentiment = "positive"
    elif avg_polarity < -0.05:
        sentiment = "negative"
    else:
        sentiment = "neutral"
    
    return avg_polarity, emotions, sentiment

# %%
# apply the mapping function to get polarity, emotions and sentiment
merged[["avg_polarity", "emotions", "sentiment"]] = merged["clean_text"].apply(lambda x: pd.Series(map_sentiment(x)))

# drop less common emotions
merged["emotions"] = merged["emotions"].apply(lambda x: x[:1])
merged.head()
# Out:
#                                        link         comment_id  \
# 0  https://www.instagram.com/p/DOV0Rn2DNf-/  18173137474359052
# 1  https://www.instagram.com/p/DOV0Rn2DNf-/  18066568718464364
# 2  https://www.instagram.com/p/DOV0Rn2DNf-/  18519537625024458
# 3  https://www.instagram.com/p/DOV0Rn2DNf-/  18103206322588474
# 4  https://www.instagram.com/p/DOV0Rn2DNf-/  17921412669139143
#
#          username                                               text  \
# 0  ikbarsinaga999                  @al_hazhouse.land Kaesang hahahha
# 1          io9713                                        Sama aja😂😂😂
# 2    lenirahardja     @ayurachanda bagi Tuhan gak ada yg mustahil ❤️
# 3   denisarimbi06  @prabowo betul itu, orang2 sisaa Mulyono tidak...
# 4  ikbarsinaga999                   Lah rotasi udahan, PKB -> Golkar
#
#            created_at  like_count  reply_count        date  community  \
# 0 2025-09-12 11:25:29           0            0  2025-09-12       17.0
# 1 2025-09-08 22:38:37           0            0  2025-09-08       16.0
# 2 2025-09-09 03:25:31           0            0  2025-09-09       12.0
# 3 2025-09-10 04:57:51           0            0  2025-09-10        2.0
# 4 2025-09-10 18:44:48           0            0  2025-09-10       17.0
#
#                                           clean_text  avg_polarity  \
# 0                           [land, kaesang, hahahha]      0.000000
# 1                                        [sama, aja]      0.000000
# 2              [bagi, tuhan, gak, ada, yg, mustahil]      0.370333
# 3  [betul, itu,, orang2, sisaa, mulyono, tidak, b...     -0.825000
# 4                [lah, rotasi, udahan,, pkb, golkar]      0.881000
#
#      emotions sentiment
# 0          []   neutral
# 1          []   neutral
# 2  [#ecstasy]  positive
# 3    [#grief]  negative
# 4  [#ecstasy]  positive

# %%
merged.to_csv('../results/senti_emo.csv', index=False)

# %%
merged["sentiment"].value_counts()
# Out:
# sentiment
# positive    241
# neutral     164
# negative     74
# Name: count, dtype: int64

# %%
merged["emotions"].explode().value_counts()
# Out:
# emotions
# #ecstasy           89
# #enthusiasm        44
# #grief             35
# #pleasantness      23
# #serenity          22
# #annoyance         17
# #dislike           11
# #responsiveness    11
# #delight           10
# #acceptance        10
# #joy                8
# #calmness           7
# #eagerness          7
# #sadness            7
# #terror             5
# #rage               5
# #anxiety            5
# #anger              4
# #melancholy         4
# #loathing           3
# #fear               3
# #disgust            2
# #bliss              2
# #contentment        1
# Name: count, dtype: int64

# %%
# filter for valid communities
target_comms = [2, 5, 12, 15, 20]
df = merged[merged["community"].isin(target_comms)].copy()

# explode emotions
df_exploded = df.explode("emotions")

# calculate sentiment distribution per community
sentiment_dist = (
    df_exploded.groupby(["community", "sentiment"])
    .size()
    .unstack(fill_value=0)
)

# calculate emotion distribution per community
emotion_dist = (
    df_exploded.groupby(["community", "emotions"])
    .size()
    .unstack(fill_value=0)
)

# get results
print("Sentiment Distribution by Community:")
display(sentiment_dist)

print("\nEmotion Distribution by Community:")
display(emotion_dist)
# Out:
# Sentiment Distribution by Community:
# sentiment  negative  neutral  positive
# community
# 2.0               8       17        35
# 5.0               1       11        15
# 12.0              3       11        13
# 15.0              9        6        20
# 20.0              2        6         4
# Emotion Distribution by Community:
# emotions   #acceptance  #anger  #annoyance  #bliss  #calmness  #delight  \
# community
# 2.0                  1       2           3       2          1         2
# 5.0                  0       0           0       0          0         0
# 12.0                 0       1           0       0          0         0
# 15.0                 1       0           1       0          0         0
# 20.0                 0       0           1       0          0         0
#
# emotions   #disgust  #dislike  #eagerness  #ecstasy  #enthusiasm  #fear  \
# community
# 2.0               1         4           0        11            7      1
# 5.0               0         0           0         0            5      0
# 12.0              0         0           0         6            3      0
# 15.0              0         1           2         7            2      1
# 20.0              0         0           0         3            0      0
#
# emotions   #grief  #joy  #melancholy  #pleasantness  #rage  #responsiveness  \
# community
# 2.0             5     0            1              2      0                1
# 5.0             1     1            0              6      0                0
# 12.0            1     0            0              2      0                1
# 15.0            6     1            1              1      0                1
# 20.0            0     0            0              2      1                0
#
# emotions   #sadness  #serenity
# community
# 2.0               0          2
# 5.0               0          3
# 12.0              1          1
# 15.0              1          3
# 20.0              0          1
