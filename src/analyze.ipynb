# %%
import pandas as pd
import numpy as np

# %%
# read data
data = pd.read_csv('../data/comments_data.csv')

# ignore columns parent_id
data = data.drop(columns=['parent_id'])

data.head()
# Out:
#                                        link         comment_id  \
# 0  https://www.instagram.com/p/DOV0Rn2DNf-/  17916292923173899
# 1  https://www.instagram.com/p/DOV0Rn2DNf-/  18095910739726736
# 2  https://www.instagram.com/p/DOV0Rn2DNf-/  17980524434883939
# 3  https://www.instagram.com/p/DOV0Rn2DNf-/  18173137474359052
# 4  https://www.instagram.com/p/DOV0Rn2DNf-/  18038689634666892
#
#          username                                               text  \
# 0     lorenzoabim                   Anjir Dahnil kebagian kue nya :)
# 1          fndnrz  @risqi_aguspianto hahaha bukan pendukung prabo...
# 2   muchlizdarma1                @lorenzoabim kerjanya setaun sekali
# 3  ikbarsinaga999                  @al_hazhouse.land Kaesang hahahha
# 4    rahmadsejati  harapan rakyat sederhana 🙏 kerja nyata, hasil ...
#
#    created_at  like_count  reply_count
# 0  1757333808         192           16
# 1  1757372912           0            0
# 2  1757387323           0            0
# 3  1757676329           0            0
# 4  1757334122         757            2

# %%
# convert comment_time to datetime
data['created_at'] = pd.to_datetime(data['created_at'], unit='s')

# extract date from comment_time
data['date'] = data['created_at'].dt.date

data.head()
# Out:
#                                        link         comment_id  \
# 0  https://www.instagram.com/p/DOV0Rn2DNf-/  17916292923173899
# 1  https://www.instagram.com/p/DOV0Rn2DNf-/  18095910739726736
# 2  https://www.instagram.com/p/DOV0Rn2DNf-/  17980524434883939
# 3  https://www.instagram.com/p/DOV0Rn2DNf-/  18173137474359052
# 4  https://www.instagram.com/p/DOV0Rn2DNf-/  18038689634666892
#
#          username                                               text  \
# 0     lorenzoabim                   Anjir Dahnil kebagian kue nya :)
# 1          fndnrz  @risqi_aguspianto hahaha bukan pendukung prabo...
# 2   muchlizdarma1                @lorenzoabim kerjanya setaun sekali
# 3  ikbarsinaga999                  @al_hazhouse.land Kaesang hahahha
# 4    rahmadsejati  harapan rakyat sederhana 🙏 kerja nyata, hasil ...
#
#            created_at  like_count  reply_count        date
# 0 2025-09-08 12:16:48         192           16  2025-09-08
# 1 2025-09-08 23:08:32           0            0  2025-09-08
# 2 2025-09-09 03:08:43           0            0  2025-09-09
# 3 2025-09-12 11:25:29           0            0  2025-09-12
# 4 2025-09-08 12:22:02         757            2  2025-09-08

# %% [markdown]
# #### Clean Text

# %%
import re

def clean_comment(text):
    if pd.isna(text):
        return None
    
    # delete mention (@username)
    # text = re.sub(r'@\w+', '', text)

    # lowercase
    text = text.lower()
    
    # delete link
    text = re.sub(r'http\S+|www\S+', '', text)
    
    # delete non-printable characters except emoticons
    text = re.sub(r'[^\x00-\x7F]+', lambda m: m.group(0), text)
    
    # delete whitespace
    text = re.sub(r'\s+', ' ', text).strip()

    # delete emoji
    text = re.sub(r'[^\w\s,]', '', text)
    
    return text if text else None

# %%
# apply to dataset
data['clean_comment'] = data['text'].apply(clean_comment)

# drop null or empty
data = data.dropna(subset=['clean_comment']).reset_index(drop=True)

data.head()
# Out:
#                                        link         comment_id  \
# 0  https://www.instagram.com/p/DOV0Rn2DNf-/  17916292923173899
# 1  https://www.instagram.com/p/DOV0Rn2DNf-/  18095910739726736
# 2  https://www.instagram.com/p/DOV0Rn2DNf-/  17980524434883939
# 3  https://www.instagram.com/p/DOV0Rn2DNf-/  18173137474359052
# 4  https://www.instagram.com/p/DOV0Rn2DNf-/  18038689634666892
#
#          username                                               text  \
# 0     lorenzoabim                   Anjir Dahnil kebagian kue nya :)
# 1          fndnrz  @risqi_aguspianto hahaha bukan pendukung prabo...
# 2   muchlizdarma1                @lorenzoabim kerjanya setaun sekali
# 3  ikbarsinaga999                  @al_hazhouse.land Kaesang hahahha
# 4    rahmadsejati  harapan rakyat sederhana 🙏 kerja nyata, hasil ...
#
#            created_at  like_count  reply_count        date  \
# 0 2025-09-08 12:16:48         192           16  2025-09-08
# 1 2025-09-08 23:08:32           0            0  2025-09-08
# 2 2025-09-09 03:08:43           0            0  2025-09-09
# 3 2025-09-12 11:25:29           0            0  2025-09-12
# 4 2025-09-08 12:22:02         757            2  2025-09-08
#
#                                        clean_comment
# 0                     anjir dahnil kebagian kue nya
# 1    hahaha bukan pendukung prabowo dari tahun 2014
# 2                             kerjanya setaun sekali
# 3                               land kaesang hahahha
# 4  harapan rakyat sederhana  kerja nyata, hasil t...

# %% [markdown]
# #### Community

# %%
import re
import networkx as nx
import pandas as pd
import community as community_louvain
from pyvis.network import Network

# %%
# --- Build mention edges ---
mention_pattern = re.compile(r'@(\w+)')
edge_weights = {}
comment_count = data['username'].value_counts().to_dict()
like_sum = data.groupby('username')['like_count'].sum().to_dict()

for _, row in data.iterrows():
    author = row['username']
    text = str(row['text'])
    mentions = mention_pattern.findall(text)
    for mentioned in mentions:
        if author != mentioned:  # avoid self-loops
            edge_weights[(author, mentioned)] = edge_weights.get((author, mentioned), 0) + 1

# %%
# --- Build graph ---
G = nx.DiGraph()
for (a, b), w in edge_weights.items():
    G.add_edge(a, b, weight=w)

# --- Only keep users with at least 1 connection ---
connected_nodes = set(G.nodes())
G = G.subgraph(connected_nodes).copy()

# --- Add node attributes ---
for node in G.nodes():
    G.nodes[node]['comment_count'] = comment_count.get(node, 0)
    G.nodes[node]['like_count'] = like_sum.get(node, 0)

# %%
# --- Louvain communities (on undirected version) ---
partition = community_louvain.best_partition(G.to_undirected())
nx.set_node_attributes(G, partition, 'community')

# %%
# only keep users that appear in the graph
users_community = [
    {'username': node,
     'community': G.nodes[node]['community'],
     'comment_count': G.nodes[node]['comment_count'],
     'like_count': G.nodes[node]['like_count']}
    for node in G.nodes()
]

df_users = pd.DataFrame(users_community)
df_users.to_csv("../data/users_community.csv", index=False)

# %%
# --- Build Pyvis network ---
net = Network(height="800px", width="100%", notebook=True, directed=True)
net.force_atlas_2based()

for node in G.nodes():
    net.add_node(
        node,
        label=node,
        size=5 + G.nodes[node]['comment_count']*2,   # scale node size
        title=f"Comments: {G.nodes[node]['comment_count']}<br>Likes: {G.nodes[node]['like_count']}",
        group=G.nodes[node]['community']
    )

for u, v, d in G.edges(data=True):
    net.add_edge(u, v, value=d['weight'], title=f"Mentions: {d['weight']}")

net.show("mention_network.html", notebook=False)
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# mention_network.html

# %%
import re
import networkx as nx
import pandas as pd
import community as community_louvain
from pyvis.network import Network
import numpy as np

def analyze_instagram_mention_network(data, min_mentions=5, output_dir="../data/"):
    """
    Analyze Instagram comment mention network and detect communities
    
    Parameters:
    data: DataFrame with columns ['username', 'text', 'like_count']
    min_mentions: Minimum number of mentions for a user to be included
    output_dir: Directory to save output files
    """
    
    # --- Build mention edges ---
    print("Building mention network...")
    mention_pattern = re.compile(r'@(\w+)')
    edge_weights = {}
    
    # Calculate user statistics
    comment_count = data['username'].value_counts().to_dict()
    like_sum = data.groupby('username')['like_count'].sum().to_dict()
    
    # Extract mentions and build edge weights
    for _, row in data.iterrows():
        author = row['username']
        text = str(row['text']) if pd.notna(row['text']) else ""
        mentions = mention_pattern.findall(text)
        
        for mentioned in mentions:
            if author != mentioned:  # avoid self-loops
                edge_weights[(author, mentioned)] = edge_weights.get((author, mentioned), 0) + 1
    
    print(f"Found {len(edge_weights)} unique mention relationships")
    
    # --- Build initial graph ---
    G = nx.DiGraph()
    for (a, b), w in edge_weights.items():
        G.add_edge(a, b, weight=w)
    
    # --- Filter users with at least min_mentions total mentions (sent + received) ---
    print(f"Filtering users with at least {min_mentions} mentions...")
    
    # Calculate total mentions per user (both sent and received)
    mention_counts = {}
    for (author, mentioned), weight in edge_weights.items():
        mention_counts[author] = mention_counts.get(author, 0) + weight  # mentions sent
        mention_counts[mentioned] = mention_counts.get(mentioned, 0) + weight  # mentions received
    
    # Filter users
    active_users = {user for user, count in mention_counts.items() if count >= min_mentions}
    print(f"Keeping {len(active_users)} users with >= {min_mentions} mentions")
    
    # Create filtered graph
    G_filtered = nx.DiGraph()
    for (a, b), w in edge_weights.items():
        if a in active_users and b in active_users:
            G_filtered.add_edge(a, b, weight=w)
    
    G = G_filtered
    print(f"Final graph: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")
    
    if G.number_of_nodes() == 0:
        print("No users meet the minimum mention criteria!")
        return None, None
    
    # --- Add node attributes ---
    for node in G.nodes():
        G.nodes[node]['comment_count'] = comment_count.get(node, 0)
        G.nodes[node]['like_count'] = like_sum.get(node, 0)
        G.nodes[node]['total_mentions'] = mention_counts.get(node, 0)
    
    # --- Detect communities using Louvain algorithm ---
    print("Detecting communities...")
    partition = community_louvain.best_partition(G.to_undirected())
    nx.set_node_attributes(G, partition, 'community')
    
    # Print community statistics
    communities = {}
    for node, comm in partition.items():
        if comm not in communities:
            communities[comm] = []
        communities[comm].append(node)
    
    print(f"\nFound {len(communities)} communities:")
    for comm_id, members in communities.items():
        print(f"Community {comm_id}: {len(members)} members")
    
    # --- Save community data to CSV ---
    users_community = []
    for node in G.nodes():
        users_community.append({
            'username': node,
            'community': G.nodes[node]['community'],
            'comment_count': G.nodes[node]['comment_count'],
            'like_count': G.nodes[node]['like_count'],
            'total_mentions': G.nodes[node]['total_mentions']
        })
    
    df_users = pd.DataFrame(users_community)
    csv_path = f"{output_dir}users_community.csv"
    df_users.to_csv(csv_path, index=False)
    print(f"Saved community data to {csv_path}")
    
    # --- Build interactive visualization with Pyvis ---
    print("Creating network visualization...")
    net = Network(height="1000px", width="100%", directed=True, bgcolor="#222222", font_color="white")
    
    # Use force-directed layout
    net.force_atlas_2based()
    
    # Define colors for different communities
    colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4', '#FFEAA7', 
              '#DDA0DD', '#98D8C8', '#F7DC6F', '#BB8FCE', '#85C1E9']
    
    # Add nodes
    for node in G.nodes():
        community_id = G.nodes[node]['community']
        color = colors[community_id % len(colors)]
        
        # Scale node size based on total mentions
        size = max(10, min(50, 10 + G.nodes[node]['total_mentions'] * 2))
        
        net.add_node(
            node,
            label=node,
            size=size,
            title=f"User: {node}<br>Community: {community_id}<br>Comments: {G.nodes[node]['comment_count']}<br>Total Likes: {G.nodes[node]['like_count']}<br>Total Mentions: {G.nodes[node]['total_mentions']}",
            color=color,
            group=community_id
        )
    
    # Add edges
    for u, v, d in G.edges(data=True):
        # Scale edge width based on mention frequency
        width = min(10, max(1, d['weight']))
        net.add_edge(u, v, 
                    value=d['weight'], 
                    title=f"Mentions: {d['weight']}",
                    width=width)
    
    # Set physics options for better layout
    net.set_options("""
    var options = {
      "physics": {
        "forceAtlas2Based": {
          "gravitationalConstant": -50,
          "centralGravity": 0.01,
          "springLength": 100,
          "springConstant": 0.08
        },
        "maxVelocity": 50,
        "solver": "forceAtlas2Based",
        "timestep": 0.35,
        "stabilization": {"iterations": 150}
      }
    }
    """)
    
    # Save visualization
    html_path = "mention_network.html"
    net.show(html_path, notebook=False)
    print(f"Saved network visualization to {html_path}")
    
    return G, df_users

# --- Additional Analysis Functions ---

def print_network_stats(G):
    """Print basic network statistics"""
    if G is None:
        return
        
    print("\n=== NETWORK STATISTICS ===")
    print(f"Nodes: {G.number_of_nodes()}")
    print(f"Edges: {G.number_of_edges()}")
    print(f"Density: {nx.density(G):.4f}")
    
    if G.number_of_nodes() > 0:
        # Most mentioned users
        in_degree = dict(G.in_degree(weight='weight'))
        top_mentioned = sorted(in_degree.items(), key=lambda x: x[1], reverse=True)[:5]
        print(f"\nMost mentioned users:")
        for user, mentions in top_mentioned:
            print(f"  @{user}: {mentions} mentions")
        
        # Most active mentioners
        out_degree = dict(G.out_degree(weight='weight'))
        top_mentioners = sorted(out_degree.items(), key=lambda x: x[1], reverse=True)[:5]
        print(f"\nMost active mentioners:")
        for user, mentions in top_mentioners:
            print(f"  @{user}: {mentions} mentions sent")

def analyze_communities(df_users):
    """Analyze community characteristics"""
    if df_users is None or df_users.empty:
        return
        
    print("\n=== COMMUNITY ANALYSIS ===")
    community_stats = df_users.groupby('community').agg({
        'username': 'count',
        'comment_count': 'sum',
        'like_count': 'sum',
        'total_mentions': 'sum'
    }).rename(columns={'username': 'size'})
    
    print(community_stats)
    
    # Find most influential users in each community
    print("\nTop users per community (by total mentions):")
    for comm_id in df_users['community'].unique():
        comm_users = df_users[df_users['community'] == comm_id]
        top_user = comm_users.loc[comm_users['total_mentions'].idxmax()]
        print(f"Community {comm_id}: @{top_user['username']} ({top_user['total_mentions']} mentions)")

# %%
# To run the analysis:
G, df_users = analyze_instagram_mention_network(data, min_mentions=2)
# Out:
# Building mention network...
# Found 1200 unique mention relationships
# Filtering users with at least 2 mentions...
# Keeping 408 users with >= 2 mentions
# Final graph: 342 nodes, 419 edges
# Detecting communities...
#
# Found 87 communities:
# Community 0: 67 members
# Community 1: 2 members
# Community 2: 5 members
# Community 3: 2 members
# Community 4: 2 members
# Community 5: 13 members
# Community 6: 2 members
# Community 7: 13 members
# Community 8: 26 members
# Community 10: 7 members
# Community 11: 2 members
# Community 12: 2 members
# Community 13: 5 members
# Community 14: 2 members
# Community 15: 2 members
# Community 16: 2 members
# Community 17: 7 members
# Community 18: 20 members
# Community 19: 2 members
# Community 20: 2 members
# Community 21: 2 members
# Community 22: 5 members
# Community 23: 2 members
# Community 24: 2 members
# Community 25: 2 members
# Community 26: 2 members
# Community 27: 5 members
# Community 28: 2 members
# Community 29: 2 members
# Community 30: 2 members
# Community 31: 2 members
# Community 32: 2 members
# Community 33: 2 members
# Community 34: 4 members
# Community 35: 2 members
# Community 36: 3 members
# Community 37: 2 members
# Community 38: 3 members
# Community 39: 2 members
# Community 40: 3 members
# Community 41: 2 members
# Community 42: 2 members
# Community 43: 3 members
# Community 44: 2 members
# Community 45: 3 members
# Community 46: 2 members
# Community 47: 2 members
# Community 48: 2 members
# Community 49: 2 members
# Community 50: 2 members
# Community 51: 2 members
# Community 52: 2 members
# Community 53: 2 members
# Community 54: 3 members
# Community 55: 2 members
# Community 56: 2 members
# Community 57: 2 members
# Community 58: 2 members
# Community 59: 2 members
# Community 60: 2 members
# Community 61: 2 members
# Community 62: 2 members
# Community 63: 4 members
# Community 64: 2 members
# Community 65: 2 members
# Community 66: 2 members
# Community 67: 2 members
# Community 68: 5 members
# Community 69: 2 members
# Community 70: 2 members
# Community 71: 2 members
# Community 72: 2 members
# Community 73: 2 members
# Community 74: 2 members
# Community 75: 3 members
# Community 76: 3 members
# Community 77: 3 members
# Community 78: 2 members
# Community 79: 2 members
# Community 80: 2 members
# Community 81: 2 members
# Community 82: 2 members
# Community 83: 2 members
# Community 84: 3 members
# Community 85: 2 members
# Community 86: 2 members
# Community 9: 2 members
# Saved community data to ../data/users_community.csv
# Creating network visualization...
# mention_network.html
# Saved network visualization to mention_network.html

# %%
print_network_stats(G)
# Out:
# === NETWORK STATISTICS ===
# Nodes: 342
# Edges: 419
# Density: 0.0036
#
# Most mentioned users:
#   @prabowo: 97 mentions
#   @kemenpar: 21 mentions
#   @presidenrepublikindonesia: 21 mentions
#   @smindrawati: 16 mentions
#   @gerindra: 14 mentions
#
# Most active mentioners:
#   @prasetyo_emilarie: 9 mentions sent
#   @fahria.zxcc: 7 mentions sent
#   @rafly.wibowo240101: 7 mentions sent
#   @alamsyahsubakri: 7 mentions sent
#   @tomsuryapanji: 6 mentions sent

# %%
analyze_communities(df_users)
# Out:
# === COMMUNITY ANALYSIS ===
#            size  comment_count  like_count  total_mentions
# community
# 0            67             69         100             447
# 1             2              3          31               5
# 2             5              8          40              14
# 3             2              4           0               5
# 4             2              3           2               4
# ...         ...            ...         ...             ...
# 82            2              2           1               4
# 83            2              4           0               6
# 84            3              4           1               6
# 85            2              3           1               4
# 86            2              4          13               5
#
# [87 rows x 4 columns]
#
# Top users per community (by total mentions):
# Community 0: @prabowo (235 mentions)
# Community 1: @plutonioneon (3 mentions)
# Community 2: @syakurhilmy_ (4 mentions)
# Community 3: @bang (3 mentions)
# Community 4: @wongtani_padi (2 mentions)
# Community 5: @egiiiinn (7 mentions)
# Community 6: @berkegiatan (2 mentions)
# Community 7: @official (15 mentions)
# Community 8: @bahlillahadalia (19 mentions)
# Community 10: @wahyu_rajin_menabung_ (3 mentions)
# Community 11: @dwanharun (3 mentions)
# Community 12: @handcraft_bundiy (2 mentions)
# Community 13: @dr (4 mentions)
# Community 14: @heldums (3 mentions)
# Community 15: @donal79 (3 mentions)
# Community 16: @husnahardiana (3 mentions)
# Community 17: @tirexmadep (4 mentions)
# Community 18: @smindrawati (108 mentions)
# Community 19: @ranggaprimadasa (3 mentions)
# Community 20: @bintorosetya (2 mentions)
# Community 21: @idakristagram (3 mentions)
# Community 22: @aldo_adv (3 mentions)
# Community 23: @dewalautaru (2 mentions)
# Community 24: @yuliagrn (2 mentions)
# Community 25: @nmitantika (2 mentions)
# Community 26: @eka_fath (2 mentions)
# Community 27: @sumargodenny (4 mentions)
# Community 28: @farielriz (2 mentions)
# Community 29: @naeliatitik (3 mentions)
# Community 30: @arepngecaprak (2 mentions)
# Community 31: @bambelagi (2 mentions)
# Community 32: @ayrosalia (2 mentions)
# Community 33: @pandu_ozil11 (3 mentions)
# Community 34: @hammmmmmmag09 (4 mentions)
# Community 35: @rdt_prm (3 mentions)
# Community 36: @ttk.project (4 mentions)
# Community 37: @taufikk (3 mentions)
# Community 38: @octhavvia6 (6 mentions)
# Community 39: @apri_isnanto (2 mentions)
# Community 40: @ditoariotedjo (3 mentions)
# Community 41: @satrio3nurcahya (2 mentions)
# Community 42: @mntpppppp111 (2 mentions)
# Community 43: @bandung (3 mentions)
# Community 44: @bonifasius_bima (2 mentions)
# Community 45: @indie_24jam (3 mentions)
# Community 46: @adisilva21 (2 mentions)
# Community 47: @adivnm (3 mentions)
# Community 48: @deni.fitriyanto (3 mentions)
# Community 49: @rvvlnsyah12 (3 mentions)
# Community 50: @brooklyn_cheesee (3 mentions)
# Community 51: @restumujijoyo (2 mentions)
# Community 52: @chllprk (3 mentions)
# Community 53: @afrizalrrx (2 mentions)
# Community 54: @donipurr (2 mentions)
# Community 55: @ihsannnnudin (3 mentions)
# Community 56: @wmfy_ (2 mentions)
# Community 57: @fachminaufal_ (2 mentions)
# Community 58: @bil_lee_ (3 mentions)
# Community 59: @23isaaac (3 mentions)
# Community 60: @faaaaadiiil (3 mentions)
# Community 61: @nisafhzaa (2 mentions)
# Community 62: @erwindjuntak (2 mentions)
# Community 63: @sersanhusen_ (2 mentions)
# Community 64: @rinpast (2 mentions)
# Community 65: @bergkamp_p (2 mentions)
# Community 66: @taniasoktaviani (4 mentions)
# Community 67: @linggachndraaa (2 mentions)
# Community 68: @khoirulfl (5 mentions)
# Community 69: @rhisky.26 (2 mentions)
# Community 70: @bheema11 (2 mentions)
# Community 71: @jokowi (3 mentions)
# Community 72: @bersihsehat88 (2 mentions)
# Community 73: @marjuniaaa (4 mentions)
# Community 74: @xreal_2202 (3 mentions)
# Community 75: @ujangsulaimann (3 mentions)
# Community 76: @aryosamuelhartanto (4 mentions)
# Community 77: @geo.kyboobs (2 mentions)
# Community 78: @bono_0170 (2 mentions)
# Community 79: @panduadiputrawijaya (3 mentions)
# Community 80: @downhill_jaksquad (3 mentions)
# Community 81: @bsxxvn (2 mentions)
# Community 82: @derry_pm05 (2 mentions)
# Community 83: @fiqriiz (3 mentions)
# Community 84: @mel.dharmawan (2 mentions)
# Community 85: @enmyyoshi (2 mentions)
# Community 86: @krnwaan__ (3 mentions)
# Community 9: @khairulhamid28 (2 mentions)
